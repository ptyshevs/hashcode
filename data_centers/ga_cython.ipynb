# %%
import numpy as np
from Server import Server

# %%
# %load_ext Cython

# %%
from ga import input_wrapper
from helpers import parse
from pruner import magic

# %%
path = 'input/dc.in'

# %%
def input_wrapper(inp):
    servers = []
    for i, v in enumerate(inp):
        r, slot = v[0]
        s, cap, id = v[1]
        serv = Server(id, s, cap)
        serv.row = r
        serv.slot = slot
        servers.append(serv)
    return servers

# %%
R, S, U, P, M, unavaiable, servers = parse(path)
servers = input_wrapper(magic(path))

# %%
servers
# Out:
# [S[2]: size=2, capacity=40, row=7, slot=0 | P[-1],
#  S[7]: size=2, capacity=40, row=7, slot=2 | P[-1],
#  S[8]: size=3, capacity=60, row=2, slot=0 | P[-1],
#  S[34]: size=2, capacity=40, row=15, slot=0 | P[-1],
#  S[50]: size=4, capacity=80, row=14, slot=3 | P[-1],
#  S[58]: size=1, capacity=20, row=13, slot=0 | P[-1],
#  S[59]: size=5, capacity=100, row=12, slot=0 | P[-1],
#  S[66]: size=3, capacity=60, row=6, slot=0 | P[-1],
#  S[69]: size=2, capacity=40, row=13, slot=1 | P[-1],
#  S[86]: size=3, capacity=60, row=11, slot=0 | P[-1],
#  S[132]: size=5, capacity=100, row=9, slot=0 | P[-1],
#  S[134]: size=2, capacity=40, row=7, slot=4 | P[-1],
#  S[135]: size=3, capacity=60, row=1, slot=0 | P[-1],
#  S[136]: size=1, capacity=20, row=15, slot=2 | P[-1],
#  S[137]: size=1, capacity=20, row=8, slot=0 | P[-1],
#  S[153]: size=3, capacity=60, row=5, slot=0 | P[-1],
#  S[219]: size=3, capacity=60, row=4, slot=0 | P[-1],
#  S[222]: size=4, capacity=80, row=2, slot=3 | P[-1],
#  S[232]: size=4, capacity=80, row=0, slot=0 | P[-1],
#  S[274]: size=4, capacity=80, row=15, slot=3 | P[-1],
#  S[279]: size=2, capacity=40, row=13, slot=3 | P[-1],
#  S[285]: size=1, capacity=20, row=10, slot=0 | P[-1],
#  S[290]: size=2, capacity=40, row=8, slot=1 | P[-1],
#  S[295]: size=5, capacity=100, row=7, slot=6 | P[-1],
#  S[315]: size=4, capacity=80, row=6, slot=8 | P[-1],
#  S[321]: size=3, capacity=60, row=14, slot=7 | P[-1],
#  S[336]: size=3, capacity=60, row=11, slot=3 | P[-1],
#  S[347]: size=1, capacity=20, row=10, slot=1 | P[-1],
#  S[352]: size=5, capacity=100, row=1, slot=3 | P[-1],
#  S[371]: size=5, capacity=100, row=13, slot=5 | P[-1],
#  S[409]: size=3, capacity=60, row=12, slot=5 | P[-1],
#  S[410]: size=2, capacity=40, row=10, slot=2 | P[-1],
#  S[432]: size=1, capacity=20, row=8, slot=3 | P[-1],
#  S[433]: size=1, capacity=20, row=5, slot=5 | P[-1],
#  S[435]: size=5, capacity=100, row=4, slot=3 | P[-1],
#  S[452]: size=4, capacity=80, row=9, slot=5 | P[-1],
#  S[456]: size=3, capacity=60, row=8, slot=4 | P[-1],
#  S[458]: size=3, capacity=60, row=5, slot=6 | P[-1],
#  S[483]: size=3, capacity=60, row=3, slot=0 | P[-1],
#  S[486]: size=3, capacity=60, row=2, slot=7 | P[-1],
#  S[605]: size=2, capacity=40, row=0, slot=4 | P[-1],
#  S[607]: size=3, capacity=60, row=15, slot=9 | P[-1],
#  S[615]: size=2, capacity=40, row=14, slot=0 | P[-1],
#  S[14]: size=5, capacity=95, row=11, slot=6 | P[-1],
#  S[16]: size=1, capacity=19, row=10, slot=4 | P[-1],
#  S[23]: size=5, capacity=95, row=6, slot=12 | P[-1],
#  S[25]: size=1, capacity=19, row=12, slot=8 | P[-1],
#  S[44]: size=1, capacity=19, row=10, slot=5 | P[-1],
#  S[77]: size=1, capacity=19, row=7, slot=11 | P[-1],
#  S[89]: size=5, capacity=95, row=0, slot=11 | P[-1],
#  S[109]: size=5, capacity=95, row=14, slot=10 | P[-1],
#  S[114]: size=5, capacity=95, row=12, slot=9 | P[-1],
#  S[154]: size=4, capacity=76, row=10, slot=6 | P[-1],
#  S[181]: size=5, capacity=95, row=8, slot=9 | P[-1],
#  S[184]: size=3, capacity=57, row=7, slot=12 | P[-1],
#  S[251]: size=1, capacity=19, row=5, slot=9 | P[-1],
#  S[325]: size=4, capacity=76, row=3, slot=3 | P[-1],
#  S[354]: size=2, capacity=38, row=2, slot=10 | P[-1],
#  S[355]: size=3, capacity=57, row=1, slot=8 | P[-1],
#  S[386]: size=4, capacity=76, row=15, slot=12 | P[-1],
#  S[401]: size=5, capacity=95, row=13, slot=10 | P[-1],
#  S[489]: size=3, capacity=57, row=9, slot=9 | P[-1],
#  S[504]: size=1, capacity=19, row=5, slot=10 | P[-1],
#  S[522]: size=1, capacity=19, row=4, slot=8 | P[-1],
#  S[552]: size=1, capacity=19, row=5, slot=11 | P[-1],
#  S[558]: size=5, capacity=95, row=4, slot=9 | P[-1],
#  S[565]: size=3, capacity=57, row=2, slot=12 | P[-1],
#  S[586]: size=4, capacity=76, row=11, slot=11 | P[-1],
#  S[602]: size=4, capacity=76, row=7, slot=15 | P[-1],
#  S[41]: size=5, capacity=90, row=6, slot=17 | P[-1],
#  S[52]: size=2, capacity=36, row=5, slot=12 | P[-1],
#  S[60]: size=5, capacity=90, row=1, slot=11 | P[-1],
#  S[91]: size=1, capacity=18, row=10, slot=10 | P[-1],
#  S[94]: size=1, capacity=18, row=9, slot=12 | P[-1],
#  S[102]: size=5, capacity=90, row=3, slot=7 | P[-1],
#  S[110]: size=3, capacity=54, row=0, slot=6 | P[-1],
#  S[119]: size=5, capacity=90, row=15, slot=16 | P[-1],
#  S[126]: size=1, capacity=18, row=14, slot=15 | P[-1],
#  S[164]: size=2, capacity=36, row=12, slot=14 | P[-1],
#  S[168]: size=3, capacity=54, row=10, slot=11 | P[-1],
#  S[183]: size=3, capacity=54, row=9, slot=13 | P[-1],
#  S[198]: size=4, capacity=72, row=8, slot=14 | P[-1],
#  S[201]: size=4, capacity=72, row=5, slot=14 | P[-1],
#  S[229]: size=1, capacity=18, row=2, slot=15 | P[-1],
#  S[236]: size=4, capacity=72, row=14, slot=16 | P[-1],
#  S[241]: size=2, capacity=36, row=13, slot=15 | P[-1],
#  S[250]: size=5, capacity=90, row=2, slot=16 | P[-1],
#  S[254]: size=1, capacity=18, row=12, slot=16 | P[-1],
#  S[281]: size=1, capacity=18, row=11, slot=15 | P[-1],
#  S[282]: size=3, capacity=54, row=7, slot=19 | P[-1],
#  S[286]: size=3, capacity=54, row=4, slot=14 | P[-1],
#  S[310]: size=5, capacity=90, row=0, slot=16 | P[-1],
#  S[320]: size=5, capacity=90, row=13, slot=17 | P[-1],
#  S[332]: size=5, capacity=90, row=12, slot=17 | P[-1],
#  S[349]: size=1, capacity=18, row=11, slot=16 | P[-1],
#  S[374]: size=5, capacity=90, row=10, slot=18 | P[-1],
#  S[381]: size=5, capacity=90, row=9, slot=16 | P[-1],
#  S[384]: size=4, capacity=72, row=6, slot=22 | P[-1],
#  S[389]: size=4, capacity=72, row=1, slot=16 | P[-1],
#  S[396]: size=1, capacity=18, row=11, slot=18 | P[-1],
#  S[428]: size=5, capacity=90, row=8, slot=18 | P[-1],
#  S[429]: size=2, capacity=36, row=5, slot=18 | P[-1],
#  S[440]: size=3, capacity=54, row=3, slot=12 | P[-1],
#  S[445]: size=1, capacity=18, row=15, slot=7 | P[-1],
#  S[463]: size=1, capacity=18, row=14, slot=20 | P[-1],
#  S[470]: size=2, capacity=36, row=11, slot=19 | P[-1],
#  S[505]: size=1, capacity=18, row=7, slot=22 | P[-1],
#  S[519]: size=5, capacity=90, row=4, slot=17 | P[-1],
#  S[520]: size=5, capacity=90, row=15, slot=21 | P[-1],
#  S[526]: size=1, capacity=18, row=14, slot=21 | P[-1],
#  S[549]: size=3, capacity=54, row=7, slot=23 | P[-1],
#  S[559]: size=1, capacity=18, row=5, slot=20 | P[-1],
#  S[567]: size=5, capacity=90, row=2, slot=21 | P[-1],
#  S[583]: size=5, capacity=90, row=14, slot=22 | P[-1],
#  S[609]: size=4, capacity=72, row=11, slot=21 | P[-1],
#  S[610]: size=4, capacity=72, row=6, slot=26 | P[-1],
#  S[619]: size=4, capacity=72, row=5, slot=21 | P[-1],
#  S[623]: size=1, capacity=18, row=3, slot=15 | P[-1],
#  S[5]: size=4, capacity=68, row=1, slot=20 | P[-1],
#  S[19]: size=1, capacity=17, row=0, slot=9 | P[-1],
#  S[20]: size=3, capacity=51, row=13, slot=22 | P[-1],
#  S[28]: size=4, capacity=68, row=12, slot=22 | P[-1],
#  S[46]: size=4, capacity=68, row=10, slot=24 | P[-1],
#  S[113]: size=5, capacity=85, row=9, slot=24 | P[-1],
#  S[116]: size=1, capacity=17, row=3, slot=16 | P[-1],
#  S[120]: size=5, capacity=85, row=0, slot=21 | P[-1],
#  S[123]: size=5, capacity=85, row=8, slot=23 | P[-1],
#  S[124]: size=5, capacity=85, row=7, slot=26 | P[-1],
#  S[125]: size=2, capacity=34, row=3, slot=19 | P[-1],
#  S[129]: size=2, capacity=34, row=4, slot=24 | P[-1],
#  S[161]: size=5, capacity=85, row=15, slot=26 | P[-1],
#  S[173]: size=1, capacity=17, row=13, slot=25 | P[-1],
#  S[187]: size=4, capacity=68, row=11, slot=28 | P[-1],
#  S[215]: size=2, capacity=34, row=6, slot=3 | P[-1],
#  S[216]: size=2, capacity=34, row=5, slot=25 | P[-1],
#  S[238]: size=5, capacity=85, row=3, slot=21 | P[-1],
#  S[291]: size=1, capacity=17, row=2, slot=26 | P[-1],
#  S[292]: size=4, capacity=68, row=1, slot=28 | P[-1],
#  S[306]: size=5, capacity=85, row=14, slot=28 | P[-1],
#  S[339]: size=2, capacity=34, row=13, slot=28 | P[-1],
#  S[340]: size=4, capacity=68, row=12, slot=26 | P[-1],
#  S[367]: size=2, capacity=34, row=10, slot=14 | P[-1],
#  S[369]: size=4, capacity=68, row=4, slot=29 | P[-1],
#  S[430]: size=3, capacity=51, row=2, slot=27 | P[-1],
#  S[466]: size=1, capacity=17, row=9, slot=21 | P[-1],
#  S[481]: size=3, capacity=51, row=6, slot=30 | P[-1],
#  S[484]: size=1, capacity=17, row=5, slot=27 | P[-1],
#  S[507]: size=4, capacity=68, row=0, slot=26 | P[-1],
#  S[511]: size=4, capacity=68, row=13, slot=30 | P[-1],
#  S[532]: size=4, capacity=68, row=10, slot=28 | P[-1],
#  S[538]: size=2, capacity=34, row=9, slot=29 | P[-1],
#  S[571]: size=1, capacity=17, row=8, slot=7 | P[-1],
#  S[572]: size=3, capacity=51, row=7, slot=31 | P[-1],
#  S[587]: size=3, capacity=51, row=5, slot=28 | P[-1],
#  S[598]: size=3, capacity=51, row=11, slot=32 | P[-1],
#  S[621]: size=2, capacity=34, row=8, slot=28 | P[-1],
#  S[624]: size=4, capacity=68, row=2, slot=30 | P[-1],
#  S[49]: size=3, capacity=48, row=1, slot=24 | P[-1],
#  S[99]: size=4, capacity=64, row=15, slot=32 | P[-1],
#  S[106]: size=2, capacity=32, row=12, slot=30 | P[-1],
#  S[139]: size=3, capacity=48, row=9, slot=31 | P[-1],
#  S[145]: size=4, capacity=64, row=6, slot=34 | P[-1],
#  S[149]: size=5, capacity=80, row=4, slot=33 | P[-1],
#  S[182]: size=4, capacity=64, row=3, slot=26 | P[-1],
#  S[193]: size=4, capacity=64, row=14, slot=33 | P[-1],
#  S[226]: size=2, capacity=32, row=8, slot=30 | P[-1],
#  S[228]: size=4, capacity=64, row=7, slot=35 | P[-1],
#  S[233]: size=2, capacity=32, row=5, slot=31 | P[-1],
#  S[234]: size=1, capacity=16, row=0, slot=30 | P[-1],
#  S[244]: size=5, capacity=80, row=13, slot=34 | P[-1],
#  S[245]: size=3, capacity=48, row=12, slot=32 | P[-1],
#  S[257]: size=5, capacity=80, row=11, slot=35 | P[-1],
#  S[261]: size=4, capacity=64, row=10, slot=32 | P[-1],
#  S[264]: size=2, capacity=32, row=1, slot=32 | P[-1],
#  S[267]: size=3, capacity=48, row=0, slot=31 | P[-1],
#  S[268]: size=2, capacity=32, row=9, slot=34 | P[-1],
#  S[280]: size=3, capacity=48, row=8, slot=32 | P[-1],
#  S[297]: size=4, capacity=64, row=5, slot=33 | P[-1],
#  S[304]: size=4, capacity=64, row=2, slot=34 | P[-1],
#  S[312]: size=2, capacity=32, row=15, slot=36 | P[-1],
#  S[314]: size=1, capacity=16, row=6, slot=6 | P[-1],
#  S[350]: size=3, capacity=48, row=3, slot=30 | P[-1],
#  S[368]: size=1, capacity=16, row=1, slot=34 | P[-1],
#  S[376]: size=3, capacity=48, row=14, slot=37 | P[-1],
#  S[383]: size=2, capacity=32, row=12, slot=35 | P[-1],
#  S[387]: size=5, capacity=80, row=9, slot=36 | P[-1],
#  S[390]: size=3, capacity=48, row=7, slot=39 | P[-1],
#  S[423]: size=3, capacity=48, row=6, slot=38 | P[-1],
#  S[434]: size=5, capacity=80, row=4, slot=45 | P[-1],
#  S[453]: size=3, capacity=48, row=1, slot=35 | P[-1],
#  S[479]: size=1, capacity=16, row=0, slot=34 | P[-1],
#  S[480]: size=3, capacity=48, row=15, slot=38 | P[-1],
#  S[496]: size=1, capacity=16, row=10, slot=16 | P[-1],
#  S[498]: size=4, capacity=64, row=8, slot=35 | P[-1],
#  S[512]: size=5, capacity=80, row=0, slot=35 | P[-1],
#  S[524]: size=1, capacity=16, row=13, slot=26 | P[-1],
#  S[529]: size=1, capacity=16, row=12, slot=37 | P[-1],
#  S[548]: size=2, capacity=32, row=11, slot=25 | P[-1],
#  S[554]: size=3, capacity=48, row=10, slot=40 | P[-1],
#  S[566]: size=2, capacity=32, row=5, slot=39 | P[-1],
#  S[601]: size=2, capacity=32, row=3, slot=33 | P[-1],
#  S[10]: size=4, capacity=60, row=2, slot=38 | P[-1],
#  S[83]: size=2, capacity=30, row=14, slot=40 | P[-1],
#  S[93]: size=5, capacity=75, row=13, slot=39 | P[-1],
#  S[95]: size=2, capacity=30, row=12, slot=38 | P[-1],
#  S[100]: size=2, capacity=30, row=7, slot=42 | P[-1],
#  S[105]: size=4, capacity=60, row=6, slot=41 | P[-1],
#  S[133]: size=2, capacity=30, row=1, slot=40 | P[-1],
#  S[147]: size=1, capacity=15, row=15, slot=41 | P[-1],
#  S[158]: size=3, capacity=45, row=11, slot=40 | P[-1],
#  S[163]: size=3, capacity=45, row=5, slot=41 | P[-1],
#  S[165]: size=4, capacity=60, row=3, slot=38 | P[-1],
#  S[172]: size=2, capacity=30, row=15, slot=42 | P[-1],
#  S[179]: size=5, capacity=75, row=14, slot=42 | P[-1],
#  S[188]: size=3, capacity=45, row=12, slot=42 | P[-1],
#  S[220]: size=2, capacity=30, row=10, slot=37 | P[-1],
#  S[221]: size=4, capacity=60, row=9, slot=43 | P[-1],
#  S[243]: size=5, capacity=75, row=8, slot=39 | P[-1],
#  S[299]: size=2, capacity=30, row=7, slot=44 | P[-1],
#  S[305]: size=3, capacity=45, row=4, slot=41 | P[-1],
#  S[307]: size=4, capacity=60, row=1, slot=42 | P[-1],
#  S[309]: size=3, capacity=45, row=2, slot=42 | P[-1],
#  S[322]: size=5, capacity=75, row=0, slot=52 | P[-1],
#  S[329]: size=2, capacity=30, row=15, slot=44 | P[-1],
#  S[370]: size=2, capacity=30, row=11, slot=43 | P[-1],
#  S[377]: size=3, capacity=45, row=10, slot=43 | P[-1],
#  S[380]: size=4, capacity=60, row=7, slot=46 | P[-1],
#  S[404]: size=3, capacity=45, row=6, slot=45 | P[-1],
#  S[412]: size=3, capacity=45, row=5, slot=45 | P[-1],
#  S[417]: size=2, capacity=30, row=13, slot=44 | P[-1],
#  S[418]: size=4, capacity=60, row=12, slot=45 | P[-1],
#  S[419]: size=4, capacity=60, row=4, slot=50 | P[-1],
#  S[420]: size=5, capacity=75, row=3, slot=42 | P[-1],
#  S[421]: size=5, capacity=75, row=15, slot=46 | P[-1],
#  S[439]: size=4, capacity=60, row=11, slot=45 | P[-1],
#  S[451]: size=3, capacity=45, row=9, slot=47 | P[-1],
#  S[464]: size=3, capacity=45, row=2, slot=45 | P[-1],
#  S[475]: size=1, capacity=15, row=1, slot=38 | P[-1],
#  S[488]: size=3, capacity=45, row=14, slot=47 | P[-1],
#  S[492]: size=2, capacity=30, row=13, slot=46 | P[-1],
#  S[497]: size=5, capacity=75, row=10, slot=49 | P[-1],
#  S[515]: size=2, capacity=30, row=8, slot=44 | P[-1],
#  S[521]: size=4, capacity=60, row=6, slot=48 | P[-1],
#  S[528]: size=1, capacity=15, row=5, slot=37 | P[-1],
#  S[535]: size=4, capacity=60, row=1, slot=49 | P[-1],
#  S[536]: size=2, capacity=30, row=7, slot=50 | P[-1],
#  S[540]: size=2, capacity=30, row=5, slot=48 | P[-1],
#  S[541]: size=3, capacity=45, row=0, slot=43 | P[-1],
#  S[570]: size=4, capacity=60, row=13, slot=49 | P[-1],
#  S[576]: size=5, capacity=75, row=12, slot=49 | P[-1],
#  S[600]: size=1, capacity=15, row=9, slot=22 | P[-1],
#  S[611]: size=4, capacity=60, row=8, slot=46 | P[-1],
#  S[612]: size=3, capacity=45, row=4, slot=54 | P[-1],
#  S[0]: size=2, capacity=28, row=2, slot=49 | P[-1],
#  S[18]: size=4, capacity=56, row=14, slot=50 | P[-1],
#  S[75]: size=1, capacity=14, row=11, slot=49 | P[-1],
#  S[78]: size=2, capacity=28, row=9, slot=50 | P[-1],
#  S[92]: size=4, capacity=56, row=7, slot=52 | P[-1],
#  S[140]: size=2, capacity=28, row=5, slot=50 | P[-1],
#  S[180]: size=5, capacity=70, row=3, slot=58 | P[-1],
#  S[197]: size=5, capacity=70, row=15, slot=51 | P[-1],
#  S[209]: size=1, capacity=14, row=11, slot=50 | P[-1],
#  S[225]: size=4, capacity=56, row=6, slot=52 | P[-1],
#  S[265]: size=2, capacity=28, row=2, slot=51 | P[-1],
#  S[289]: size=1, capacity=14, row=1, slot=46 | P[-1],
#  S[296]: size=2, capacity=28, row=0, slot=48 | P[-1],
#  S[302]: size=3, capacity=42, row=11, slot=51 | P[-1],
#  S[326]: size=1, capacity=14, row=10, slot=46 | P[-1],
#  S[344]: size=5, capacity=70, row=9, slot=52 | P[-1],
#  S[360]: size=2, capacity=28, row=5, slot=52 | P[-1],
#  S[366]: size=4, capacity=56, row=4, slot=57 | P[-1],
#  S[373]: size=3, capacity=42, row=1, slot=55 | P[-1],
#  S[394]: size=3, capacity=42, row=13, slot=56 | P[-1],
#  S[408]: size=2, capacity=28, row=10, slot=54 | P[-1],
#  S[416]: size=4, capacity=56, row=8, slot=50 | P[-1],
#  S[465]: size=4, capacity=56, row=2, slot=53 | P[-1],
#  S[495]: size=3, capacity=42, row=0, slot=57 | P[-1],
#  S[508]: size=3, capacity=42, row=14, slot=54 | P[-1],
#  S[513]: size=5, capacity=70, row=12, slot=54 | P[-1],
#  S[514]: size=2, capacity=28, row=7, slot=56 | P[-1],
#  S[518]: size=4, capacity=56, row=5, slot=54 | P[-1],
#  S[553]: size=5, capacity=70, row=11, slot=54 | P[-1],
#  S[557]: size=5, capacity=70, row=10, slot=56 | P[-1],
#  S[560]: size=2, capacity=28, row=6, slot=56 | P[-1],
#  S[569]: size=1, capacity=14, row=3, slot=17 | P[-1],
#  S[574]: size=5, capacity=70, row=1, slot=62 | P[-1],
#  S[575]: size=4, capacity=56, row=15, slot=57 | P[-1],
#  S[15]: size=2, capacity=26, row=13, slot=53 | P[-1],
#  S[32]: size=2, capacity=26, row=7, slot=58 | P[-1],
#  S[57]: size=5, capacity=65, row=4, slot=64 | P[-1],
#  S[67]: size=5, capacity=65, row=3, slot=67 | P[-1],
#  S[70]: size=3, capacity=39, row=0, slot=60 | P[-1],
#  S[72]: size=3, capacity=39, row=14, slot=57 | P[-1],
#  S[80]: size=3, capacity=39, row=9, slot=57 | P[-1],
#  S[144]: size=5, capacity=65, row=8, slot=58 | P[-1],
#  S[176]: size=5, capacity=65, row=6, slot=58 | P[-1],
#  S[191]: size=2, capacity=26, row=2, slot=57 | P[-1],
#  S[203]: size=4, capacity=52, row=13, slot=59 | P[-1],
#  S[240]: size=2, capacity=26, row=7, slot=60 | P[-1],
#  S[247]: size=5, capacity=65, row=5, slot=58 | P[-1],
#  S[266]: size=3, capacity=39, row=12, slot=59 | P[-1],
#  S[271]: size=1, capacity=13, row=2, slot=59 | P[-1],
#  S[278]: size=1, capacity=13, row=0, slot=41 | P[-1],
#  S[293]: size=2, capacity=26, row=15, slot=61 | P[-1],
#  S[337]: size=4, capacity=52, row=14, slot=64 | P[-1],
#  S[341]: size=2, capacity=26, row=11, slot=59 | P[-1],
#  S[346]: size=3, capacity=39, row=10, slot=61 | P[-1],
#  S[353]: size=2, capacity=26, row=9, slot=60 | P[-1],
#  S[358]: size=5, capacity=65, row=7, slot=62 | P[-1],
#  S[362]: size=1, capacity=13, row=2, slot=60 | P[-1],
#  S[363]: size=2, capacity=26, row=1, slot=58 | P[-1],
#  S[375]: size=3, capacity=39, row=0, slot=63 | P[-1],
#  S[426]: size=1, capacity=13, row=4, slot=22 | P[-1],
#  S[427]: size=5, capacity=65, row=3, slot=73 | P[-1],
#  S[443]: size=5, capacity=65, row=2, slot=62 | P[-1],
#  S[460]: size=4, capacity=52, row=15, slot=63 | P[-1],
#  S[485]: size=5, capacity=65, row=13, slot=63 | P[-1],
#  S[494]: size=5, capacity=65, row=12, slot=62 | P[-1],
#  S[584]: size=4, capacity=52, row=11, slot=61 | P[-1],
#  S[585]: size=3, capacity=39, row=9, slot=62 | P[-1],
#  S[592]: size=4, capacity=52, row=8, slot=63 | P[-1],
#  S[13]: size=3, capacity=36, row=6, slot=63 | P[-1],
#  S[29]: size=1, capacity=12, row=4, slot=26 | P[-1],
#  S[35]: size=4, capacity=48, row=1, slot=67 | P[-1],
#  S[45]: size=3, capacity=36, row=10, slot=64 | P[-1],
#  S[56]: size=5, capacity=60, row=5, slot=63 | P[-1],
#  S[61]: size=1, capacity=12, row=4, slot=38 | P[-1],
#  S[65]: size=4, capacity=48, row=0, slot=66 | P[-1],
#  S[101]: size=2, capacity=24, row=14, slot=60 | P[-1],
#  S[128]: size=5, capacity=60, row=4, slot=69 | P[-1],
#  S[159]: size=3, capacity=36, row=9, slot=66 | P[-1],
#  S[160]: size=2, capacity=24, row=7, slot=67 | P[-1],
#  S[171]: size=4, capacity=48, row=6, slot=66 | P[-1],
#  S[178]: size=5, capacity=60, row=15, slot=67 | P[-1],
#  S[185]: size=4, capacity=48, row=14, slot=68 | P[-1],
#  S[208]: size=1, capacity=12, row=11, slot=65 | P[-1],
#  S[252]: size=2, capacity=24, row=10, slot=67 | P[-1],
#  S[260]: size=4, capacity=48, row=8, slot=67 | P[-1],
#  S[262]: size=4, capacity=48, row=3, slot=53 | P[-1],
#  S[273]: size=2, capacity=24, row=2, slot=67 | P[-1],
#  S[283]: size=3, capacity=36, row=1, slot=71 | P[-1],
#  S[294]: size=3, capacity=36, row=13, slot=68 | P[-1],
#  S[316]: size=3, capacity=36, row=12, slot=67 | P[-1],
#  S[324]: size=4, capacity=48, row=11, slot=68 | P[-1],
#  S[327]: size=4, capacity=48, row=7, slot=69 | P[-1],
#  S[333]: size=3, capacity=36, row=0, slot=70 | P[-1],
#  S[342]: size=5, capacity=60, row=10, slot=69 | P[-1],
#  S[348]: size=5, capacity=60, row=9, slot=69 | P[-1],
#  S[361]: size=5, capacity=60, row=5, slot=68 | P[-1],
#  S[364]: size=3, capacity=36, row=2, slot=69 | P[-1],
#  S[378]: size=1, capacity=12, row=6, slot=70 | P[-1],
#  S[407]: size=2, capacity=24, row=4, slot=61 | P[-1],
#  S[414]: size=4, capacity=48, row=1, slot=74 | P[-1],
#  S[422]: size=2, capacity=24, row=14, slot=72 | P[-1],
#  S[438]: size=3, capacity=36, row=13, slot=71 | P[-1],
#  S[455]: size=1, capacity=12, row=12, slot=40 | P[-1],
#  S[487]: size=1, capacity=12, row=8, slot=54 | P[-1],
#  S[499]: size=2, capacity=24, row=6, slot=71 | P[-1],
#  S[537]: size=3, capacity=36, row=3, slot=78 | P[-1],
#  S[573]: size=4, capacity=48, row=0, slot=74 | P[-1],
#  S[594]: size=3, capacity=36, row=15, slot=72 | P[-1],
#  S[1]: size=5, capacity=55, row=12, slot=70 | P[-1],
#  S[31]: size=5, capacity=55, row=11, slot=72 | P[-1],
#  S[48]: size=3, capacity=33, row=8, slot=72 | P[-1],
#  S[51]: size=1, capacity=11, row=7, slot=73 | P[-1],
#  S[54]: size=3, capacity=33, row=4, slot=74 | P[-1],
#  S[62]: size=2, capacity=22, row=2, slot=74 | P[-1],
#  S[63]: size=1, capacity=11, row=14, slot=62 | P[-1],
#  S[79]: size=4, capacity=44, row=7, slot=74 | P[-1],
#  S[103]: size=1, capacity=11, row=6, slot=73 | P[-1],
#  S[107]: size=3, capacity=33, row=14, slot=74 | P[-1],
#  S[117]: size=5, capacity=55, row=13, slot=79 | P[-1],
#  S[141]: size=3, capacity=33, row=10, slot=74 | P[-1],
#  S[151]: size=3, capacity=33, row=9, slot=75 | P[-1],
#  S[157]: size=2, capacity=22, row=6, slot=76 | P[-1],
#  S[169]: size=1, capacity=11, row=5, slot=73 | P[-1],
#  S[194]: size=1, capacity=11, row=3, slot=36 | P[-1],
#  S[195]: size=3, capacity=33, row=2, slot=76 | P[-1],
#  S[196]: size=2, capacity=22, row=1, slot=78 | P[-1],
#  S[199]: size=4, capacity=44, row=15, slot=75 | P[-1],
#  S[202]: size=5, capacity=55, row=8, slot=75 | P[-1],
#  S[205]: size=2, capacity=22, row=5, slot=74 | P[-1],
#  S[207]: size=4, capacity=44, row=4, slot=77 | P[-1],
#  S[210]: size=1, capacity=11, row=3, slot=47 | P[-1],
#  S[239]: size=2, capacity=22, row=0, slot=78 | P[-1],
#  S[248]: size=3, capacity=33, row=6, slot=78 | P[-1],
#  S[253]: size=4, capacity=44, row=3, slot=81 | P[-1],
#  S[308]: size=5, capacity=55, row=1, slot=80 | P[-1],
#  S[335]: size=5, capacity=55, row=14, slot=77 | P[-1],
#  S[357]: size=4, capacity=44, row=12, slot=75 | P[-1],
#  S[382]: size=5, capacity=55, row=11, slot=79 | P[-1],
#  S[454]: size=1, capacity=11, row=10, slot=47 | P[-1],
#  S[501]: size=3, capacity=33, row=9, slot=78 | P[-1],
#  S[502]: size=1, capacity=11, row=7, slot=78 | P[-1],
#  S[527]: size=3, capacity=33, row=5, slot=76 | P[-1],
#  S[530]: size=2, capacity=22, row=2, slot=79 | P[-1],
#  S[539]: size=1, capacity=11, row=0, slot=46 | P[-1],
#  S[542]: size=1, capacity=11, row=10, slot=77 | P[-1],
#  S[561]: size=3, capacity=33, row=7, slot=79 | P[-1],
#  S[606]: size=4, capacity=44, row=0, slot=80 | P[-1],
#  S[608]: size=2, capacity=22, row=15, slot=79 | P[-1],
#  S[622]: size=1, capacity=11, row=13, slot=74 | P[-1],
#  S[37]: size=2, capacity=20, row=10, slot=78 | P[-1],
#  S[84]: size=2, capacity=20, row=6, slot=81 | P[-1],
#  S[90]: size=5, capacity=50, row=4, slot=81 | P[-1],
#  S[122]: size=4, capacity=40, row=2, slot=81 | P[-1],
#  S[131]: size=1, capacity=10, row=13, slot=75 | P[-1],
#  S[146]: size=4, capacity=40, row=9, slot=81 | P[-1],
#  S[148]: size=2, capacity=20, row=8, slot=55 | P[-1],
#  S[200]: size=1, capacity=10, row=5, slot=79 | P[-1],
#  S[206]: size=1, capacity=10, row=3, slot=48 | P[-1],
#  S[256]: size=4, capacity=40, row=15, slot=84 | P[-1],
#  S[318]: size=3, capacity=30, row=13, slot=84 | P[-1],
#  S[328]: size=1, capacity=10, row=12, slot=79 | P[-1],
#  S[330]: size=5, capacity=50, row=10, slot=83 | P[-1],
#  S[334]: size=2, capacity=20, row=7, slot=82 | P[-1],
#  S[379]: size=5, capacity=50, row=6, slot=83 | P[-1],
#  S[403]: size=3, capacity=30, row=5, slot=80 | P[-1],
#  S[431]: size=4, capacity=40, row=3, slot=85 | P[-1],
#  S[436]: size=5, capacity=50, row=1, slot=85 | P[-1],
#  S[457]: size=1, capacity=10, row=14, slot=82 | P[-1],
#  S[461]: size=5, capacity=50, row=12, slot=80 | P[-1],
#  S[493]: size=3, capacity=30, row=11, slot=84 | P[-1],
#  S[500]: size=2, capacity=20, row=8, slot=80 | P[-1],
#  S[503]: size=4, capacity=40, row=0, slot=84 | P[-1],
#  S[509]: size=3, capacity=30, row=14, slot=83 | P[-1],
#  S[510]: size=1, capacity=10, row=7, slot=84 | P[-1],
#  S[517]: size=5, capacity=50, row=2, slot=85 | P[-1],
#  S[525]: size=2, capacity=20, row=13, slot=76 | P[-1],
#  S[531]: size=2, capacity=20, row=9, slot=85 | P[-1],
#  S[556]: size=1, capacity=10, row=8, slot=82 | P[-1],
#  S[562]: size=2, capacity=20, row=7, slot=85 | P[-1],
#  S[588]: size=4, capacity=40, row=5, slot=84 | P[-1],
#  S[591]: size=5, capacity=50, row=4, slot=86 | P[-1],
#  S[597]: size=3, capacity=30, row=15, slot=88 | P[-1],
#  S[603]: size=5, capacity=50, row=11, slot=87 | P[-1],
#  S[613]: size=3, capacity=30, row=8, slot=84 | P[-1],
#  S[11]: size=3, capacity=27, row=3, slot=89 | P[-1],
#  S[17]: size=5, capacity=45, row=14, slot=86 | P[-1],
#  S[24]: size=5, capacity=45, row=13, slot=87 | P[-1],
#  S[30]: size=3, capacity=27, row=10, slot=88 | P[-1],
#  S[64]: size=5, capacity=45, row=9, slot=90 | P[-1],
#  S[88]: size=2, capacity=18, row=7, slot=87 | P[-1],
#  S[98]: size=3, capacity=27, row=6, slot=88 | P[-1],
#  S[112]: size=1, capacity=9, row=1, slot=47 | P[-1],
#  S[142]: size=3, capacity=27, row=0, slot=88 | P[-1],
#  S[150]: size=2, capacity=18, row=12, slot=85 | P[-1],
#  S[155]: size=4, capacity=36, row=1, slot=90 | P[-1],
#  S[190]: size=2, capacity=18, row=15, slot=81 | P[-1],
#  S[217]: size=5, capacity=45, row=8, slot=92 | P[-1],
#  S[231]: size=1, capacity=9, row=7, slot=89 | P[-1],
#  S[246]: size=5, capacity=45, row=5, slot=93 | P[-1],
#  S[249]: size=4, capacity=36, row=3, slot=95 | P[-1],
#  S[269]: size=2, capacity=18, row=2, slot=90 | P[-1],
#  S[275]: size=3, capacity=27, row=12, slot=92 | P[-1],
#  S[313]: size=3, capacity=27, row=10, slot=91 | P[-1],
#  S[331]: size=4, capacity=36, row=7, slot=90 | P[-1],
#  S[351]: size=3, capacity=27, row=6, slot=91 | P[-1],
#  S[356]: size=5, capacity=45, row=4, slot=91 | P[-1],
#  S[359]: size=5, capacity=45, row=0, slot=91 | P[-1],
#  S[392]: size=4, capacity=36, row=15, slot=91 | P[-1],
#  S[399]: size=3, capacity=27, row=11, slot=92 | P[-1],
#  S[405]: size=3, capacity=27, row=2, slot=92 | P[-1],
#  S[411]: size=4, capacity=36, row=14, slot=91 | P[-1],
#  S[415]: size=5, capacity=45, row=13, slot=92 | P[-1],
#  S[424]: size=1, capacity=9, row=9, slot=41 | P[-1],
#  S[446]: size=5, capacity=45, row=1, slot=94 | P[-1],
#  S[448]: size=5, capacity=45, row=9, slot=95 | P[-1],
#  S[474]: size=1, capacity=9, row=12, slot=87 | P[-1],
#  S[523]: size=5, capacity=45, row=6, slot=94 | P[-1],
#  S[545]: size=1, capacity=9, row=10, slot=80 | P[-1],
#  S[578]: size=3, capacity=27, row=12, slot=96 | P[-1],
#  S[580]: size=3, capacity=27, row=11, slot=95 | P[-1],
#  S[596]: size=2, capacity=18, row=3, slot=50 | P[-1],
#  S[33]: size=4, capacity=32, row=10, slot=96 | P[-1],
#  S[38]: size=3, capacity=24, row=8, slot=87 | P[-1],
#  S[40]: size=4, capacity=32, row=7, slot=94 | P[-1],
#  S[42]: size=1, capacity=8, row=5, slot=88 | P[-1],
#  S[43]: size=4, capacity=32, row=2, slot=95 | P[-1],
#  S[53]: size=2, capacity=16, row=15, slot=95 | P[-1],
#  S[55]: size=2, capacity=16, row=5, slot=89 | P[-1],
#  S[76]: size=4, capacity=32, row=4, slot=96 | P[-1],
#  S[82]: size=4, capacity=32, row=0, slot=96 | P[-1],
#  S[115]: size=2, capacity=16, row=3, slot=92 | P[-1],
#  S[166]: size=2, capacity=16, row=14, slot=95 | P[-1],
#  S[167]: size=1, capacity=8, row=15, slot=97 | P[-1],
#  S[177]: size=1, capacity=8, row=13, slot=97 | P[-1],
#  S[186]: size=2, capacity=16, row=11, slot=98 | P[-1],
#  S[192]: size=1, capacity=8, row=12, slot=88 | P[-1],
#  S[214]: size=2, capacity=16, row=5, slot=98 | P[-1],
#  S[255]: size=1, capacity=8, row=8, slot=90 | P[-1],
#  S[270]: size=1, capacity=8, row=3, slot=63 | P[-1],
#  S[276]: size=1, capacity=8, row=1, slot=53 | P[-1],
#  S[303]: size=2, capacity=16, row=15, slot=98 | P[-1],
#  S[365]: size=2, capacity=16, row=13, slot=98 | P[-1],
#  S[462]: size=2, capacity=16, row=9, slot=87 | P[-1],
#  S[544]: size=2, capacity=16, row=7, slot=98 | P[-1],
#  S[593]: size=1, capacity=8, row=14, slot=97 | P[-1],
#  S[224]: size=1, capacity=7, row=12, slot=90 | P[-1],
#  S[300]: size=1, capacity=7, row=10, slot=81 | P[-1],
#  S[311]: size=1, capacity=7, row=8, slot=97 | P[-1],
#  S[534]: size=1, capacity=7, row=6, slot=74 | P[-1],
#  S[4]: size=1, capacity=6, row=3, slot=65 | P[-1],
#  S[47]: size=1, capacity=6, row=2, slot=72 | P[-1],
#  S[97]: size=1, capacity=6, row=1, slot=60 | P[-1],
#  S[108]: size=1, capacity=6, row=14, slot=99 | P[-1],
#  S[162]: size=1, capacity=6, row=12, slot=99 | P[-1],
#  S[385]: size=1, capacity=6, row=11, slot=77 | P[-1],
#  S[490]: size=1, capacity=6, row=10, slot=94 | P[-1],
#  S[506]: size=1, capacity=6, row=8, slot=99 | P[-1],
#  S[577]: size=1, capacity=6, row=6, slot=99 | P[-1],
#  S[590]: size=1, capacity=6, row=5, slot=91 | P[-1],
#  S[617]: size=1, capacity=6, row=4, slot=39 | P[-1],
#  S[218]: size=1, capacity=5, row=3, slot=99 | P[-1],
#  S[223]: size=1, capacity=5, row=2, slot=99 | P[-1],
#  S[301]: size=1, capacity=5, row=1, slot=99 | P[-1],
#  S[317]: size=1, capacity=5, row=0, slot=50 | P[-1]]

# %%
def initialize_population(population_size, M, P):
    return [np.random.randint(0, P, size=M) for _ in range(population_size)]

def score_population(population, capacities, rows, M, P, R):
    return [fitness(candidate, capacities, rows, M, P, R) for candidate in population]

def selection(population, scores, retain_frac=0.8, retain_random=0.05):
    retain_len = int(len(scores) * retain_frac)
    sorted_indices = np.argsort(scores)[::-1]
    population = [population[idx] for idx in sorted_indices]
    selected = population[:retain_len]
    leftovers = population[retain_len:]

    for gene in leftovers:
        if np.random.rand() < retain_random:
            selected.append(gene)
    return selected

def mutate(candidate, M, P, mutate_frac=0.1):
    frac = int(M * mutate_frac)
    if frac == 0:
        return
    n_tries = np.random.randint(0, int(len(candidate) * mutate_frac))

    idxs = np.random.randint(0, len(candidate), size=n_tries)
    pools = np.random.randint(0, P, size=n_tries)
    for i in range(n_tries):
        candidate[idxs[i]] = pools[i]

def crossover(mom, dad):
    select_mask = np.random.binomial(1, 0.5, size=len(mom)).astype('bool')
    child1, child2 = np.copy(mom), np.copy(dad)
    child1[select_mask] = dad[select_mask]
    child2[select_mask] = mom[select_mask]
    return child1, child2

def evolve(population, capacities, rows, M, P, R, retain_frac=0.8, retain_random=0.05, mutate_chance=0.05):
    """
    Evolution step
    :param population: list or candidate solutions
    :param target: 20x20 array that represents field in stopping condition
    :param delta: number of steps to revert
    :param retain_frac: percent of top individuals to proceed into the next genetation
    :param retain_random: chance of retaining sub-optimal individual
    :param mutate_chance: chance of mutating the particular individual
    :return: new generation of the same size
    """
    scores = score_population(population, capacities, rows, M, P, R)
    next_population = selection(population, scores, retain_frac=retain_frac, retain_random=retain_random)
    
    # mutate everyone expecting for the best candidate
    for gene in next_population[1:]:
        if np.random.random() < mutate_chance:
            mutate(gene, M, P)

    places_left = len(population) - len(next_population)
    children = []
    parent_max_idx = len(next_population) - 1
    while len(children) < places_left:
        mom_idx, dad_idx = np.random.randint(0, parent_max_idx, 2)
        if mom_idx != dad_idx:
            child1, child2 = crossover(next_population[mom_idx], next_population[dad_idx])
            children.append(child1)
            if len(children) < places_left:
                children.append(child2)
    next_population.extend(children)
    return next_population

def solve(servers, capacities, rows, M, P, R, population_size=10, n_generations=100, init_population=None):
    if init_population is None:
        population = initialize_population(population_size, M, P)
    else:
        population = init_population
    for generation in range(n_generations):
        population = evolve(population, capacities, rows, M, P, R)
        if generation == 0:
            print("Generation #: best score")
        elif generation % 200 == 0:
            print("Generation ", generation, ": ", fitness(population[0], capacities, rows, M, P, R))
    return population[0]

# %%
# %%cython -a
# import numpy as np
# cimport numpy as np
# from Server import Server
#
# cpdef int fitness(np.ndarray[long, ndim=1] pools, np.ndarray[long, ndim=1] capacities, np.ndarray[long, ndim=1] rows, int M, int P, int R):
#     cdef:
#         int least_gc = 1000
#         np.int32_t i, j, gci, cap, r, strike_cap
#     for i in range(P):
#         gci = 1000
#         cap = 0
#         for j in range(M):
#             if pools[j] == i:
#                 cap += capacities[j]
#         for r in range(R):
#             strike_cap = 0
#             for j in range(M):
#                 if pools[j] == i and rows[j] == r:
#                     strike_cap += capacities[j]
#             if gci > (cap - strike_cap):
#                 gci = cap - strike_cap
#         if gci < least_gc:
#             least_gc = gci
#     return least_gc
# Out:
# <!DOCTYPE html>
# <!-- Generated by Cython 0.29.5 -->
# <html>
# <head>
#     <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
#     <title>Cython: _cython_magic_92af825805cef89fe57febb63bbc33c2.pyx</title>
#     <style type="text/css">
#
# body.cython { font-family: courier; font-size: 12; }
#
# .cython.tag  {  }
# .cython.line { margin: 0em }
# .cython.code { font-size: 9; color: #444444; display: none; margin: 0px 0px 0px 8px; border-left: 8px none; }
#
# .cython.line .run { background-color: #B0FFB0; }
# .cython.line .mis { background-color: #FFB0B0; }
# .cython.code.run  { border-left: 8px solid #B0FFB0; }
# .cython.code.mis  { border-left: 8px solid #FFB0B0; }
#
# .cython.code .py_c_api  { color: red; }
# .cython.code .py_macro_api  { color: #FF7000; }
# .cython.code .pyx_c_api  { color: #FF3000; }
# .cython.code .pyx_macro_api  { color: #FF7000; }
# .cython.code .refnanny  { color: #FFA000; }
# .cython.code .trace  { color: #FFA000; }
# .cython.code .error_goto  { color: #FFA000; }
#
# .cython.code .coerce  { color: #008000; border: 1px dotted #008000 }
# .cython.code .py_attr { color: #FF0000; font-weight: bold; }
# .cython.code .c_attr  { color: #0000FF; }
# .cython.code .py_call { color: #FF0000; font-weight: bold; }
# .cython.code .c_call  { color: #0000FF; }
#
# .cython.score-0 {background-color: #FFFFff;}
# .cython.score-1 {background-color: #FFFFe7;}
# .cython.score-2 {background-color: #FFFFd4;}
# .cython.score-3 {background-color: #FFFFc4;}
# .cython.score-4 {background-color: #FFFFb6;}
# .cython.score-5 {background-color: #FFFFaa;}
# .cython.score-6 {background-color: #FFFF9f;}
# .cython.score-7 {background-color: #FFFF96;}
# .cython.score-8 {background-color: #FFFF8d;}
# .cython.score-9 {background-color: #FFFF86;}
# .cython.score-10 {background-color: #FFFF7f;}
# .cython.score-11 {background-color: #FFFF79;}
# .cython.score-12 {background-color: #FFFF73;}
# .cython.score-13 {background-color: #FFFF6e;}
# .cython.score-14 {background-color: #FFFF6a;}
# .cython.score-15 {background-color: #FFFF66;}
# .cython.score-16 {background-color: #FFFF62;}
# .cython.score-17 {background-color: #FFFF5e;}
# .cython.score-18 {background-color: #FFFF5b;}
# .cython.score-19 {background-color: #FFFF57;}
# .cython.score-20 {background-color: #FFFF55;}
# .cython.score-21 {background-color: #FFFF52;}
# .cython.score-22 {background-color: #FFFF4f;}
# .cython.score-23 {background-color: #FFFF4d;}
# .cython.score-24 {background-color: #FFFF4b;}
# .cython.score-25 {background-color: #FFFF48;}
# .cython.score-26 {background-color: #FFFF46;}
# .cython.score-27 {background-color: #FFFF44;}
# .cython.score-28 {background-color: #FFFF43;}
# .cython.score-29 {background-color: #FFFF41;}
# .cython.score-30 {background-color: #FFFF3f;}
# .cython.score-31 {background-color: #FFFF3e;}
# .cython.score-32 {background-color: #FFFF3c;}
# .cython.score-33 {background-color: #FFFF3b;}
# .cython.score-34 {background-color: #FFFF39;}
# .cython.score-35 {background-color: #FFFF38;}
# .cython.score-36 {background-color: #FFFF37;}
# .cython.score-37 {background-color: #FFFF36;}
# .cython.score-38 {background-color: #FFFF35;}
# .cython.score-39 {background-color: #FFFF34;}
# .cython.score-40 {background-color: #FFFF33;}
# .cython.score-41 {background-color: #FFFF32;}
# .cython.score-42 {background-color: #FFFF31;}
# .cython.score-43 {background-color: #FFFF30;}
# .cython.score-44 {background-color: #FFFF2f;}
# .cython.score-45 {background-color: #FFFF2e;}
# .cython.score-46 {background-color: #FFFF2d;}
# .cython.score-47 {background-color: #FFFF2c;}
# .cython.score-48 {background-color: #FFFF2b;}
# .cython.score-49 {background-color: #FFFF2b;}
# .cython.score-50 {background-color: #FFFF2a;}
# .cython.score-51 {background-color: #FFFF29;}
# .cython.score-52 {background-color: #FFFF29;}
# .cython.score-53 {background-color: #FFFF28;}
# .cython.score-54 {background-color: #FFFF27;}
# .cython.score-55 {background-color: #FFFF27;}
# .cython.score-56 {background-color: #FFFF26;}
# .cython.score-57 {background-color: #FFFF26;}
# .cython.score-58 {background-color: #FFFF25;}
# .cython.score-59 {background-color: #FFFF24;}
# .cython.score-60 {background-color: #FFFF24;}
# .cython.score-61 {background-color: #FFFF23;}
# .cython.score-62 {background-color: #FFFF23;}
# .cython.score-63 {background-color: #FFFF22;}
# .cython.score-64 {background-color: #FFFF22;}
# .cython.score-65 {background-color: #FFFF22;}
# .cython.score-66 {background-color: #FFFF21;}
# .cython.score-67 {background-color: #FFFF21;}
# .cython.score-68 {background-color: #FFFF20;}
# .cython.score-69 {background-color: #FFFF20;}
# .cython.score-70 {background-color: #FFFF1f;}
# .cython.score-71 {background-color: #FFFF1f;}
# .cython.score-72 {background-color: #FFFF1f;}
# .cython.score-73 {background-color: #FFFF1e;}
# .cython.score-74 {background-color: #FFFF1e;}
# .cython.score-75 {background-color: #FFFF1e;}
# .cython.score-76 {background-color: #FFFF1d;}
# .cython.score-77 {background-color: #FFFF1d;}
# .cython.score-78 {background-color: #FFFF1c;}
# .cython.score-79 {background-color: #FFFF1c;}
# .cython.score-80 {background-color: #FFFF1c;}
# .cython.score-81 {background-color: #FFFF1c;}
# .cython.score-82 {background-color: #FFFF1b;}
# .cython.score-83 {background-color: #FFFF1b;}
# .cython.score-84 {background-color: #FFFF1b;}
# .cython.score-85 {background-color: #FFFF1a;}
# .cython.score-86 {background-color: #FFFF1a;}
# .cython.score-87 {background-color: #FFFF1a;}
# .cython.score-88 {background-color: #FFFF1a;}
# .cython.score-89 {background-color: #FFFF19;}
# .cython.score-90 {background-color: #FFFF19;}
# .cython.score-91 {background-color: #FFFF19;}
# .cython.score-92 {background-color: #FFFF19;}
# .cython.score-93 {background-color: #FFFF18;}
# .cython.score-94 {background-color: #FFFF18;}
# .cython.score-95 {background-color: #FFFF18;}
# .cython.score-96 {background-color: #FFFF18;}
# .cython.score-97 {background-color: #FFFF17;}
# .cython.score-98 {background-color: #FFFF17;}
# .cython.score-99 {background-color: #FFFF17;}
# .cython.score-100 {background-color: #FFFF17;}
# .cython.score-101 {background-color: #FFFF16;}
# .cython.score-102 {background-color: #FFFF16;}
# .cython.score-103 {background-color: #FFFF16;}
# .cython.score-104 {background-color: #FFFF16;}
# .cython.score-105 {background-color: #FFFF16;}
# .cython.score-106 {background-color: #FFFF15;}
# .cython.score-107 {background-color: #FFFF15;}
# .cython.score-108 {background-color: #FFFF15;}
# .cython.score-109 {background-color: #FFFF15;}
# .cython.score-110 {background-color: #FFFF15;}
# .cython.score-111 {background-color: #FFFF15;}
# .cython.score-112 {background-color: #FFFF14;}
# .cython.score-113 {background-color: #FFFF14;}
# .cython.score-114 {background-color: #FFFF14;}
# .cython.score-115 {background-color: #FFFF14;}
# .cython.score-116 {background-color: #FFFF14;}
# .cython.score-117 {background-color: #FFFF14;}
# .cython.score-118 {background-color: #FFFF13;}
# .cython.score-119 {background-color: #FFFF13;}
# .cython.score-120 {background-color: #FFFF13;}
# .cython.score-121 {background-color: #FFFF13;}
# .cython.score-122 {background-color: #FFFF13;}
# .cython.score-123 {background-color: #FFFF13;}
# .cython.score-124 {background-color: #FFFF13;}
# .cython.score-125 {background-color: #FFFF12;}
# .cython.score-126 {background-color: #FFFF12;}
# .cython.score-127 {background-color: #FFFF12;}
# .cython.score-128 {background-color: #FFFF12;}
# .cython.score-129 {background-color: #FFFF12;}
# .cython.score-130 {background-color: #FFFF12;}
# .cython.score-131 {background-color: #FFFF12;}
# .cython.score-132 {background-color: #FFFF11;}
# .cython.score-133 {background-color: #FFFF11;}
# .cython.score-134 {background-color: #FFFF11;}
# .cython.score-135 {background-color: #FFFF11;}
# .cython.score-136 {background-color: #FFFF11;}
# .cython.score-137 {background-color: #FFFF11;}
# .cython.score-138 {background-color: #FFFF11;}
# .cython.score-139 {background-color: #FFFF11;}
# .cython.score-140 {background-color: #FFFF11;}
# .cython.score-141 {background-color: #FFFF10;}
# .cython.score-142 {background-color: #FFFF10;}
# .cython.score-143 {background-color: #FFFF10;}
# .cython.score-144 {background-color: #FFFF10;}
# .cython.score-145 {background-color

# %%
servs = [serv.copy() for serv in servers]
capacities = np.array([int(serv.capacity) for serv in servers])
rows = np.array([serv.row for serv in servers])

# %%
result = solve(servs, capacities, rows, len(servers), P, R, n_generations=30000)
# Out:
# Generation #: best score
# Generation  200 :  215
# Generation  400 :  248
# Generation  600 :  248
# Generation  800 :  248
# Generation  1000 :  248
# Generation  1200 :  251
# Generation  1400 :  266
# Generation  1600 :  276
# Generation  1800 :  280
# Generation  2000 :  289
# Generation  2200 :  289
# Generation  2400 :  289
# Generation  2600 :  289
# Generation  2800 :  289
# Generation  3000 :  289
# Generation  3200 :  289
# Generation  3400 :  289
# Generation  3600 :  289
# Generation  3800 :  289
# Generation  4000 :  289
# Generation  4200 :  289
# Generation  4400 :  289
# Generation  4600 :  293
# Generation  4800 :  298
# Generation  5000 :  298
# Generation  5200 :  304
# Generation  5400 :  304
# Generation  5600 :  304
# Generation  5800 :  304
# Generation  6000 :  304
# Generation  6200 :  304
# Generation  6400 :  304
# Generation  6600 :  304
# Generation  6800 :  304
# Generation  7000 :  304
# Generation  7200 :  304
# Generation  7400 :  304
# Generation  7600 :  304
# Generation  7800 :  304
# Generation  8000 :  304
# Generation  8200 :  304
# Generation  8400 :  304
# Generation  8600 :  304
# Generation  8800 :  304
# Generation  9000 :  304
# Generation  9200 :  304
# Generation  9400 :  304
# Generation  9600 :  304
# Generation  9800 :  305
# Generation  10000 :  305
# Generation  10200 :  305
# Generation  10400 :  305
# Generation  10600 :  308
# Generation  10800 :  308
# Generation  11000 :  308
# Generation  11200 :  308
# Generation  11400 :  309
# Generation  11600 :  309
# Generation  11800 :  309
# Generation  12000 :  309
# Generation  12200 :  309
# Generation  12400 :  309
# Generation  12600 :  309
# Generation  12800 :  309
# Generation  13000 :  309
# Generation  13200 :  310
# Generation  13400 :  310
# Generation  13600 :  310
# Generation  13800 :  310
# Generation  14000 :  310
# Generation  14200 :  312
# Generation  14400 :  312
# Generation  14600 :  312
# Generation  14800 :  312
# Generation  15000 :  312
# Generation  15200 :  312
# Generation  15400 :  312
# Generation  15600 :  312
# Generation  15800 :  313
# Generation  16000 :  313
# Generation  16200 :  313
# Generation  16400 :  313
# Generation  16600 :  313
# Generation  16800 :  313
# Generation  17000 :  316
# Generation  17200 :  316
# Generation  17400 :  316
# Generation  17600 :  316
# Generation  17800 :  316
# Generation  18000 :  316
# Generation  18200 :  316
# Generation  18400 :  318
# Generation  18600 :  318
# Generation  18800 :  318
# Generation  19000 :  318
# Generation  19200 :  318
# Generation  19400 :  318
# Generation  19600 :  318
# Generation  19800 :  318
# Generation  20000 :  318
# Generation  20200 :  318
# Generation  20400 :  318
# Generation  20600 :  318
# Generation  20800 :  318
# Generation  21000 :  318
# Generation  21200 :  318
# Generation  21400 :  318
# Generation  21600 :  318
# Generation  21800 :  318
# Generation  22000 :  318
# Generation  22200 :  318
# Generation  22400 :  318
# Generation  22600 :  318
# Generation  22800 :  318
# Generation  23000 :  318
# Generation  23200 :  318
# Generation  23400 :  318
# Generation  23600 :  318
# Generation  23800 :  318
# Generation  24000 :  318
# Generation  24200 :  318
# Generation  24400 :  318
# Generation  24600 :  318
# Generation  24800 :  318
# Generation  25000 :  318
# Generation  25200 :  318
# Generation  25400 :  318
# Generation  25600 :  318
# Generation  25800 :  322
# Generation  26000 :  322
# Generation  26200 :  322
# Generation  26400 :  322
# Generation  26600 :  322
# Generation  26800 :  322
# Generation  27000 :  322
# Generation  27200 :  322
# Generation  27400 :  322
# Generation  27600 :  322
# Generation  27800 :  322
# Generation  28000 :  322
# Generation  28200 :  322
# Generation  28400 :  322
# Generation  28600 :  322
# Generation  28800 :  322
# Generation  29000 :  322
# Generation  29200 :  322
# Generation  29400 :  322
# Generation  29600 :  322
# Generation  29800 :  322

# %%
import scipy
import multiprocessing
import os

# %%
def work(servers, capacities, rows, M, P, R, population_size, n_iter):
    scipy.random.seed()
    return solve(servers, capacities, rows, M, P, R, population_size=population_size, n_generations=n_iter)

def multiprocess_solve(servers, capacities, rows, M, P, R, population_size=100, n_iter=3000):
    pool = multiprocessing.Pool(os.cpu_count())
    tasks = [([serv.copy() for serv in servers], capacities, rows, len(servers), P, R, population_size, n_iter) for _ in range(os.cpu_count())]
    results = pool.starmap(work, tasks)
    return results

# %%
total_results = multiprocess_solve(servs, capacities, rows, len(servers), P, R, population_size=200, n_iter=30000)
# Out:
# Generation #: best score
# Generation #: best score
# Generation #: best score
# Generation #: best score
# Generation  200 :  234
# Generation  200 :  230
# Generation  200 :  229
# Generation  200 :  240
# Generation  400 :  249
# Generation  400 :  230
# Generation  400 :  232
# Generation  400 :  244
# Generation  600 :  237
# Generation  600 :  249
# Generation  600 :  244
# Generation  600 :  236
# Generation  800 :  237
# Generation  800 :  244
# Generation  800 :  249
# Generation  800 :  236
# Generation  1000 :  244
# Generation  1000 :  238
# Generation  1000 :  249
# Generation  1000 :  236
# Generation  1200 :  244
# Generation  1200 :  249
# Generation  1200 :  244
# Generation  1200 :  238
# Generation  1400 :  247
# Generation  1400 :  257
# Generation  1400 :  244
# Generation  1400 :  238
# Generation  1600 :  247
# Generation  1600 :  255
# Generation  1600 :  257
# Generation  1600 :  238
# Generation  1800 :  247
# Generation  1800 :  255
# Generation  1800 :  257
# Generation  1800 :  241
# Generation  2000 :  247
# Generation  2000 :  255
# Generation  2000 :  257
# Generation  2000 :  243
# Generation  2200 :  255
# Generation  2200 :  255
# Generation  2200 :  257
# Generation  2200 :  243
# Generation  2400 :  255
# Generation  2400 :  255
# Generation  2400 :  257
# Generation  2400 :  243
# Generation  2600 :  255
# Generation  2600 :  257
# Generation  2600 :  255
# Generation  2600 :  250
# Generation  2800 :  255
# Generation  2800 :  257
# Generation  2800 :  255
# Generation  2800 :  250
# Generation  3000 :  257
# Generation  3000 :  264
# Generation  3000 :  255
# Generation  3000 :  250
# Generation  3200 :  274
# Generation  3200 :  257
# Generation  3200 :  255
# Generation  3200 :  250
# Generation  3400 :  280
# Generation  3400 :  257
# Generation  3400 :  255
# Generation  3400 :  250
# Generation  3600 :  284
# Generation  3600 :  261
# Generation  3600 :  258
# Generation  3600 :  250
# Generation  3800 :  284
# Generation  3800 :  258
# Generation  3800 :  261
# Generation  3800 :  250
# Generation  4000 :  291
# Generation  4000 :  261
# Generation  4000 :  258
# Generation  4000 :  263
# Generation  4200 :  258
# Generation  4200 :  302
# Generation  4200 :  261
# Generation  4200 :  263
# Generation  4400 :  258
# Generation  4400 :  310
# Generation  4400 :  261
# Generation  4400 :  263
# Generation  4600 :  258
# Generation  4600 :  318
# Generation  4600 :  261
# Generation  4600 :  263
# Generation  4800 :  258
# Generation  4800 :  333
# Generation  4800 :  261
# Generation  4800 :  263
# Generation  5000 :  258
# Generation  5000 :  345
# Generation  5000 :  261
# Generation  5000 :  263
# Generation  5200 :  258
# Generation  5200 :  354
# Generation  5200 :  261
# Generation  5200 :  263
# Generation  5400 :  258
# Generation  5400 :  354
# Generation  5400 :  261
# Generation  5400 :  263
# Generation  5600 :  258
# Generation  5600 :  354
# Generation  5600 :  261
# Generation  5600 :  264
# Generation  5800 :  258
# Generation  5800 :  354
# Generation  5800 :  277
# Generation  5800 :  264
# Generation  6000 :  357
# Generation  6000 :  258
# Generation  6000 :  285
# Generation  6000 :  264
# Generation  6200 :  359
# Generation  6200 :  258
# Generation  6200 :  285
# Generation  6200 :  268
# Generation  6400 :  360
# Generation  6400 :  261
# Generation  6400 :  285
# Generation  6400 :  280
# Generation  6600 :  360
# Generation  6600 :  268
# Generation  6600 :  288
# Generation  6600 :  280
# Generation  6800 :  360
# Generation  6800 :  274
# Generation  6800 :  291
# Generation  6800 :  280
# Generation  7000 :  360
# Generation  7000 :  274
# Generation  7000 :  293
# Generation  7000 :  280
# Generation  7200 :  360
# Generation  7200 :  274
# Generation  7200 :  293
# Generation  7200 :  280
# Generation  7400 :  360
# Generation  7400 :  275
# Generation  7400 :  300
# Generation  7400 :  290
# Generation  7600 :  360
# Generation  7600 :  280
# Generation  7600 :  315
# Generation  7600 :  294
# Generation  7800 :  360
# Generation  7800 :  280
# Generation  7800 :  326
# Generation  7800 :  305
# Generation  8000 :  360
# Generation  8000 :  281
# Generation  8000 :  343
# Generation  8000 :  315
# Generation  8200 :  360
# Generation  8200 :  282
# Generation  8200 :  356
# Generation  8200 :  336
# Generation  8400 :  360
# Generation  8400 :  289
# Generation  8400 :  365
# Generation  8400 :  342
# Generation  8600 :  360
# Generation  8600 :  297
# Generation  8600 :  366
# Generation  8600 :  348
# Generation  8800 :  360
# Generation  8800 :  310
# Generation  8800 :  366
# Generation  8800 :  350
# Generation  9000 :  360
# Generation  9000 :  317
# Generation  9000 :  366
# Generation  9000 :  356
# Generation  9200 :  360
# Generation  9200 :  334
# Generation  9200 :  366
# Generation  9200 :  358
# Generation  9400 :  360
# Generation  9400 :  347
# Generation  9400 :  366
# Generation  9400 :  358
# Generation  9600 :  360
# Generation  9600 :  347
# Generation  9600 :  366
# Generation  9600 :  359
# Generation  9800 :  360
# Generation  9800 :  351
# Generation  9800 :  366
# Generation  9800 :  359
# Generation  10000 :  360
# Generation  10000 :  351
# Generation  10000 :  366
# Generation  10000 :  359
# Generation  10200 :  360
# Generation  10200 :  354
# Generation  10200 :  366
# Generation  10200 :  359
# Generation  10400 :  360
# Generation  10400 :  354
# Generation  10400 :  366
# Generation  10400 :  359
# Generation  10600 :  360
# Generation  10600 :  354
# Generation  10600 :  366
# Generation  10600 :  359
# Generation  10800 :  361
# Generation  10800 :  354
# Generation  10800 :  366
# Generation  10800 :  359
# Generation  11000 :  361
# Generation  11000 :  354
# Generation  11000 :  366
# Generation  11000 :  359
# Generation  11200 :  363
# Generation  11200 :  354
# Generation  11200 :  366
# Generation  11200 :  359
# Generation  11400 :  363
# Generation  11400 :  354
# Generation  11400 :  366
# Generation  11400 :  359
# Generation  11600 :  363
# Generation  11600 :  354
# Generation  11600 :  366
# Generation  11600 :  359
# Generation  11800 :  363
# Generation  11800 :  354
# Generation  11800 :  366
# Generation  11800 :  359
# Generation  12000 :  363
# Generation  12000 :  354
# Generation  12000 :  366
# Generation  12000 :  359
# Generation  12200 :  363
# Generation  12200 :  354
# Generation  12200 :  366
# Generation  12200 :  359
# Generation  12400 :  363
# Generation  12400 :  354
# Generation  12400 :  366
# Generation  12400 :  359
# Generation  12600 :  363
# Generation  12600 :  354
# Generation  12600 :  366
# Generation  12600 :  359
# Generation  12800 :  363
# Generation  12800 :  354
# Generation  12800 :  366
# Generation  12800 :  359
# Generation  13000 :  363
# Generation  13000 :  354
# Generation  13000 :  366
# Generation  13000 :  359
# Generation  13200 :  363
# Generation  13200 :  354
# Generation  13200 :  366
# Generation  13200 :  359
# Generation  13400 :  363
# Generation  13400 :  354
# Generation  13400 :  366
# Generation  13400 :  359
# Generation  13600 :  363
# Generation  13600 :  354
# Generation  13600 :  366
# Generation  13600 :  359
# Generation  13800 :  363
# Generation  13800 :  354
# Generation  13800 :  366
# Generation  13800 :  359
# Generation  14000 :  363
# Generation  14000 :  354
# Generation  14000 :  366
# Generation  14000 :  359
# Generation  14200 :  363
# Generation  14200 :  354
# Generation  14200 :  366
# Generation  14200 :  359
# Generation  14400 :  363
# Generation  14400 :  354
# Generation  14400 :  366
# Generation  14400 :  359
# Generation  14600 :  363
# Generation  14600 :  354
# Generation  14600 :  366
# Generation  14600 :  359
# Generation  14800 :  363
# Generation  14800 :  354
# Generation  14800 :  366
# Generation  14800 :  359
# Generation  15000 :  363
# Generation  15000 :  354
# Generation  15000 :  366
# Generation  15000 :  359
# Generation  15200 :  363
# Generation  15200 :  354
# Generation  15200 :  366
# Generation  15200 :  359
# Generation  15400 :  363
# Generation  15400 :  354
# Generation  15400 :  366
# Generation  15400 :  359
# Generation  15600 :  363
# Generation  15600 :  354
# Generation  15600 :  366
# Generation  15600 :  359
# Generation  15800 :  363
# Generation  15800 :  354
# Generation  15800 :  366
# Generation  15800 :  359
# Generation  16000 :  363
# Generation  16000 :  354
# Generation  16000 :  366
# Generation  16000 :  359
# Generation  16200 :  363
# Generation  16200 :  354
# Generation  16200 :  366
# Generation  16200 :  359
# Generation  16400 :  363
# Generation  16400 :  354
# Generation  16400 :  366
# Generation  16400 :  359
# Generation  16600 :  363
# Generation  16600 :  354
# Generation  16600 :  366
# Generation  16600 :  359
# Generation  16800 :  363
# Generation  16800 :  354
# Generation  16800 :  366
# Generation  16800 :  359
# Generation  17000 :  363
# Generation  17000 :  354
# Generation  17000 :  366
# Generation  17000 :  359
# Generation  17200 :  363
# Generation  17200 :  354
# Generation  17200 :  366
# Generation  17200 :  359
# Generation  17400 :  363
# Generation  17400 :  354
# Generation  17400 :  366
# Generation  17400 :  359
# Generation  17600 :  363
# Generation  17600 :  354
# Generation  17600 :  366
# Generation  17600 :  359
# Generation  17800 :  363
# Generation  17800 :  366
# Generation  17800 :  354
# Generation  17800 :  359
# Generation  18000 :  363
# Generation  18000 :  366
# Generation  18000 :  354
# Generation  18000 :  359
# Generation  18200 :  363
# Generation  18200 :  366
# Generation  18200 :  354
# Generation  18200 :  359
# Generation  18400 :  363
# Generation  18400 :  366
# Generation  18400 :  354
# Generation  18400 :  359
# Generation  18600 :  363
# Generation  18600 :  366
# Generation  18600 :  354
# Generation  18600 :  359
# Generation  18800 :  363
# Generation  18800 :  366
# Generation  18800 :  354
# Generation  18800 :  359
# Generation  19000 :  363
# Generation  19000 :  366
# Generation  19000 :  354
# Generation  19000 :  359
# Generation  19200 :  363
# Generation  19200 :  366
# Generation  19200 :  354
# Generation  19200 :  359
# Generation  19400 :  363
# Generation  19400 :  366
# Generation  19400 :  354
# Generation  19400 :  359
# Generation  19600 :  363
# Generation  19600 :  366
# Generation  19600 :  354
# Generation  19600 :  359
# Generation  19800 :  363
# Generation  19800 :  366
# Generation  19800 :  354
# Generation  19800 :  359
# Generation  20000 :  363
# Generation  20000 :  366
# Generation  20000 :  354
# Generation  20000 :  359
# Generation  20200 :  363
# Generation  20200 :  366
# Generation  20200 :  354
# Generation  20200 :  359
# Generation  20400 :  363
# Generation  20400 :  366
# Generation  20400 :  354
# Generation  20400 :  359
# Generation  20600 :  363
# Generation  20600 :  366
# Generation  20600 :  354
# Generation  20600 :  359
# Generation  20800 :  363
# Generation  20800 :  366
# Generation  20800 :  354
# Generation  20800 :  359
# Generation  21000 :  363
# Generation  21000 :  366
# Generation  21000 :  354
# Generation  21000 :  359
# Generation  21200 :  363
# Generation  21200 :  366
# Generation  21200 :  354
# Generation  21200 :  359
# Generation  21400 :  363
# Generation  21400 :  366
# Generation  21400 :  354
# Generation  21400 :  359
# Generation  21600 :  363
# Generation  21600 :  366
# Generation  21600 :  354
# Generation  21600 :  364
# Generation  21800 :  363
# Generation  21800 :  366
# Generation  21800 :  354
# Generation  21800 :  364
# Generation  22000 :  363
# Generation  22000 :  354
# Generation  22000 :  366
# Generation  22000 :  364
# Generation  22200 :  363
# Generation  22200 :  354
# Generation  22200 :  366
# Generation  22200 :  364
# Generation  22400 :  363
# Generation  22400 :  354
# Generation  22400 :  366
# Generation  22400 :  364
# Generation  22600 :  363
# Generation  22600 :  354
# Generation  22600 :  366
# Generation  22600 :  364
# Generation  22800 :  363
# Generation  22800 :  354
# Generation  22800 :  366
# Generation  22800 :  364
# Generation  23000 :  363
# Generation  23000 :  354
# Generation  23000 :  366
# Generation  23000 :  364
# Generation  23200 :  363
# Generation  23200 :  354
# Generation  23200 :  366
# Generation  23200 :  364
# Generation  23400 :  363
# Generation  23400 :  366
# Generation  23400 :  354
# Generation  23400 :  364
# Generation  23600 :  363
# Generation  23600 :  366
# Generation  23600 :  354
# Generation  23600 :  364
# Generation  23800 :  363
# Generation  23800 :  366
# Generation  23800 :  354
# Generation  23800 :  364
# Generation  24000 :  363
# Generation  24000 :  366
# Generation  24000 :  354
# Generation  24000 :  364
# Generation  24200 :  363
# Generation  24200 :  366
# Generation  24200 :  354
# Generation  24200 :  364
# Generation  24400 :  363
# Generation  24400 :  366
# Generation  24400 :  354
# Generation  24400 :  364
# Generation  24600 :  363
# Generation  24600 :  366
# Generation  24600 :  354
# Generation  24600 :  364
# Generation  24800 :  363
# Generation  24800 :  366
# Generation  24800 :  354
# Generation  24800 :  364
# Generation  25000 :  363
# Generation  25000 :  366
# Generation  25000 :  354
# Generation  25000 :  364
# Generation  25200 :  363
# Generation  25200 :  366
# Generation  25200 :  354
# Generation  25200 :  364
# Generation  25400 :  363
# Generation  25400 :  366
# Generation  25400 :  354
# Generation  25400 :  364
# Generation  25600 :  363
# Generation  25600 :  366
# Generation  25600 :  354
# Generation  25600 :  364
# Generation  25800 :  363
# Generation  25800 :  366
# Generation  25800 :  354
# Generation  25800 :  364
# Generation  26000 :  363
# Generation  26000 :  366
# Generation  26000 :  354
# Generation  26000 :  364
# Generation  26200 :  363
# Generation  26200 :  366
# Generation  26200 :  354
# Generation  26200 :  364
# Generation  26400 :  363
# Generation  26400 :  366
# Generation  26400 :  354
# Generation  26400 :  364
# Generation  26600 :  363
# Generation  26600 :  366
# Generation  26600 :  354
# Generation  26600 :  364
# Generation  26800 :  363
# Generation  26800 :  366
# Generation  26800 :  354
# Generation  26800 :  364
# Generation  27000 :  363
# Generation  27000 :  366
# Generation  27000 :  354
# Generation  27000 :  364
# Generation  27200 :  363
# Generation  27200 :  366
# Generation  27200 :  354
# Generation  27200 :  364
# Generation  27400 :  363
# Generation  27400 :  354
# Generation  27400 :  366
# Generation  27400 :  364
# Generation  27600 :  363
# Generation  27600 :  354
# Generation  27600 :  366
# Generation  27600 :  364
# Generation  27800 :  363
# Generation  27800 :  354
# Generation  27800 :  366
# Generation  27800 :  364
# Generation  28000 :  363
# Generation  28000 :  354
# Generation  28000 :  366
# Generation  28000 :  364
# Generation  28200 :  363
# Generation  28200 :  354
# Generation  28200 :  366
# Generation  28200 :  364
# Generation  28400 :  363
# Generation  28400 :  354
# Generation  28400 :  366
# Generation  28400 :  364
# Generation  28600 :  363
# Generation  28600 :  354
# Generation  28600 :  366
# Generation  28600 :  364
# Generation  28800 :  363
# Generation  28800 :  354
# Generation  28800 :  366
# Generation  28800 :  364
# Generation  29000 :  363
# Generation  29000 :  354
# Generation  29000 :  366
# Generation  29000 :  364
# Generation  29200 :  363
# Generation  29200 :  354
# Generation  29200 :  366
# Generation  29200 :  364
# Generation  29400 :  363
# Generation  29400 :  354
# Generation  29400 :  366
# Generation  29400 :  364
# Generation  29600 :  363
# Generation  29600 :  354
# Generation  29600 :  366
# Generation  29600 :  364
# Generation  29800 :  363
# Generation  29800 :  354
# Generation  29800 :  366
# Generation  29800 :  364

# %%
[fitness(pools, capacities, rows, len(pools), P, R) for pools in total_results]
# Out:
# [366, 354, 363, 364]

# %%
best_result = total_results[0]

# %%
def save_result(servers, pools, M, filename='submit.out'):
    for i in range(len(servers)):
        servers[i].pool = pools[i]
    by_id = sorted(servers, key=lambda x: x.id)
    ids = [_.id for _ in by_id]
    map = {id: serv for id, serv in zip(ids, by_id)}
#     for i in range(len(by_id)):
#         print(by_id[i])
    with open(filename, 'w+') as f:
        for i in range(M):
            if i in ids:
                print("{} {} {}".format(map[i].row, map[i].slot, map[i].pool), file=f)
            else:
                print("x", file=f)

# %%
save_result([s.copy() for s in servers], best_result, M, 's366.out')
# Out:
# S[0]: size=2, capacity=28, row=2, slot=49 | P[23]
# S[1]: size=5, capacity=55, row=12, slot=70 | P[20]
# S[2]: size=2, capacity=40, row=7, slot=0 | P[2]
# S[4]: size=1, capacity=6, row=3, slot=65 | P[17]
# S[5]: size=4, capacity=68, row=1, slot=20 | P[44]
# S[7]: size=2, capacity=40, row=7, slot=2 | P[17]
# S[8]: size=3, capacity=60, row=2, slot=0 | P[5]
# S[10]: size=4, capacity=60, row=2, slot=38 | P[30]
# S[11]: size=3, capacity=27, row=3, slot=89 | P[5]
# S[13]: size=3, capacity=36, row=6, slot=63 | P[14]
# S[14]: size=5, capacity=95, row=11, slot=6 | P[29]
# S[15]: size=2, capacity=26, row=13, slot=53 | P[41]
# S[16]: size=1, capacity=19, row=10, slot=4 | P[42]
# S[17]: size=5, capacity=45, row=14, slot=86 | P[13]
# S[18]: size=4, capacity=56, row=14, slot=50 | P[18]
# S[19]: size=1, capacity=17, row=0, slot=9 | P[38]
# S[20]: size=3, capacity=51, row=13, slot=22 | P[20]
# S[23]: size=5, capacity=95, row=6, slot=12 | P[28]
# S[24]: size=5, capacity=45, row=13, slot=87 | P[38]
# S[25]: size=1, capacity=19, row=12, slot=8 | P[31]
# S[28]: size=4, capacity=68, row=12, slot=22 | P[33]
# S[29]: size=1, capacity=12, row=4, slot=26 | P[8]
# S[30]: size=3, capacity=27, row=10, slot=88 | P[1]
# S[31]: size=5, capacity=55, row=11, slot=72 | P[21]
# S[32]: size=2, capacity=26, row=7, slot=58 | P[13]
# S[33]: size=4, capacity=32, row=10, slot=96 | P[28]
# S[34]: size=2, capacity=40, row=15, slot=0 | P[19]
# S[35]: size=4, capacity=48, row=1, slot=67 | P[34]
# S[37]: size=2, capacity=20, row=10, slot=78 | P[44]
# S[38]: size=3, capacity=24, row=8, slot=87 | P[6]
# S[40]: size=4, capacity=32, row=7, slot=94 | P[30]
# S[41]: size=5, capacity=90, row=6, slot=17 | P[3]
# S[42]: size=1, capacity=8, row=5, slot=88 | P[8]
# S[43]: size=4, capacity=32, row=2, slot=95 | P[35]
# S[44]: size=1, capacity=19, row=10, slot=5 | P[26]
# S[45]: size=3, capacity=36, row=10, slot=64 | P[27]
# S[46]: size=4, capacity=68, row=10, slot=24 | P[21]
# S[47]: size=1, capacity=6, row=2, slot=72 | P[15]
# S[48]: size=3, capacity=33, row=8, slot=72 | P[1]
# S[49]: size=3, capacity=48, row=1, slot=24 | P[33]
# S[50]: size=4, capacity=80, row=14, slot=3 | P[36]
# S[51]: size=1, capacity=11, row=7, slot=73 | P[4]
# S[52]: size=2, capacity=36, row=5, slot=12 | P[12]
# S[53]: size=2, capacity=16, row=15, slot=95 | P[31]
# S[54]: size=3, capacity=33, row=4, slot=74 | P[3]
# S[55]: size=2, capacity=16, row=5, slot=89 | P[21]
# S[56]: size=5, capacity=60, row=5, slot=63 | P[9]
# S[57]: size=5, capacity=65, row=4, slot=64 | P[31]
# S[58]: size=1, capacity=20, row=13, slot=0 | P[38]
# S[59]: size=5, capacity=100, row=12, slot=0 | P[40]
# S[60]: size=5, capacity=90, row=1, slot=11 | P[4]
# S[61]: size=1, capacity=12, row=4, slot=38 | P[34]
# S[62]: size=2, capacity=22, row=2, slot=74 | P[34]
# S[63]: size=1, capacity=11, row=14, slot=62 | P[23]
# S[64]: size=5, capacity=45, row=9, slot=90 | P[40]
# S[65]: size=4, capacity=48, row=0, slot=66 | P[16]
# S[66]: size=3, capacity=60, row=6, slot=0 | P[9]
# S[67]: size=5, capacity=65, row=3, slot=67 | P[7]
# S[69]: size=2, capacity=40, row=13, slot=1 | P[44]
# S[70]: size=3, capacity=39, row=0, slot=60 | P[5]
# S[72]: size=3, capacity=39, row=14, slot=57 | P[21]
# S[75]: size=1, capacity=14, row=11, slot=49 | P[25]
# S[76]: size=4, capacity=32, row=4, slot=96 | P[18]
# S[77]: size=1, capacity=19, row=7, slot=11 | P[42]
# S[78]: size=2, capacity=28, row=9, slot=50 | P[25]
# S[79]: size=4, capacity=44, row=7, slot=74 | P[4]
# S[80]: size=3, capacity=39, row=9, slot=57 | P[11]
# S[82]: size=4, capacity=32, row=0, slot=96 | P[39]
# S[83]: size=2, capacity=30, row=14, slot=40 | P[12]
# S[84]: size=2, capacity=20, row=6, slot=81 | P[25]
# S[86]: size=3, capacity=60, row=11, slot=0 | P[36]
# S[88]: size=2, capacity=18, row=7, slot=87 | P[25]
# S[89]: size=5, capacity=95, row=0, slot=11 | P[14]
# S[90]: size=5, capacity=50, row=4, slot=81 | P[41]
# S[91]: size=1, capacity=18, row=10, slot=10 | P[7]
# S[92]: size=4, capacity=56, row=7, slot=52 | P[29]
# S[93]: size=5, capacity=75, row=13, slot=39 | P[0]
# S[94]: size=1, capacity=18, row=9, slot=12 | P[29]
# S[95]: size=2, capacity=30, row=12, slot=38 | P[30]
# S[97]: size=1, capacity=6, row=1, slot=60 | P[14]
# S[98]: size=3, capacity=27, row=6, slot=88 | P[13]
# S[99]: size=4, capacity=64, row=15, slot=32 | P[11]
# S[100]: size=2, capacity=30, row=7, slot=42 | P[1]
# S[101]: size=2, capacity=24, row=14, slot=60 | P[11]
# S[102]: size=5, capacity=90, row=3, slot=7 | P[24]
# S[103]: size=1, capacity=11, row=6, slot=73 | P[18]
# S[105]: size=4, capacity=60, row=6, slot=41 | P[30]
# S[106]: size=2, capacity=32, row=12, slot=30 | P[44]
# S[107]: size=3, capacity=33, row=14, slot=74 | P[2]
# S[108]: size=1, capacity=6, row=14, slot=99 | P[34]
# S[109]: size=5, capacity=95, row=14, slot=10 | P[44]
# S[110]: size=3, capacity=54, row=0, slot=6 | P[37]
# S[112]: size=1, capacity=9, row=1, slot=47 | P[44]
# S[113]: size=5, capacity=85, row=9, slot=24 | P[5]
# S[114]: size=5, capacity=95, row=12, slot=9 | P[27]
# S[115]: size=2, capacity=16, row=3, slot=92 | P[38]
# S[116]: size=1, capacity=17, row=3, slot=16 | P[31]
# S[117]: size=5, capacity=55, row=13, slot=79 | P[18]
# S[119]: size=5, capacity=90, row=15, slot=16 | P[8]
# S[120]: size=5, capacity=85, row=0, slot=21 | P[31]
# S[122]: size=4, capacity=40, row=2, slot=81 | P[16]
# S[123]: size=5, capacity=85, row=8, slot=23 | P[43]
# S[124]: size=5, capacity=85, row=7, slot=26 | P[8]
# S[125]: size=2, capacity=34, row=3, slot=19 | P[2]
# S[126]: size=1, capacity=18, row=14, slot=15 | P[2]
# S[128]: size=5, capacity=60, row=4, slot=69 | P[20]
# S[129]: size=2, capacity=34, row=4, slot=24 | P[26]
# S[131]: size=1, capacity=10, row=13, slot=75 | P[11]
# S[132]: size=5, capacity=100, row=9, slot=0 | P[24]
# S[133]: size=2, capacity=30, row=1, slot=40 | P[24]
# S[134]: size=2, capacity=40, row=7, slot=4 | P[26]
# S[135]: size=3, capacity=60, row=1, slot=0 | P[22]
# S[136]: size=1, capacity=20, row=15, slot=2 | P[23]
# S[137]: size=1, capacity=20, row=8, slot=0 | P[34]
# S[139]: size=3, capacity=48, row=9, slot=31 | P[36]
# S[140]: size=2, capacity=28, row=5, slot=50 | P[38]
# S[141]: size=3, capacity=33, row=10, slot=74 | P[38]
# S[142]: size=3, capacity=27, row=0, slot=88 | P[10]
# S[144]: size=5, capacity=65, row=8, slot=58 | P[11]
# S[145]: size=4, capacity=64, row=6, slot=34 | P[10]
# S[146]: size=4, capacity=40, row=9, slot=81 | P[13]
# S[147]: size=1, capacity=15, row=15, slot=41 | P[24]
# S[148]: size=2, capacity=20, row=8, slot=55 | P[20]
# S[149]: size=5, capacity=80, row=4, slot=33 | P[23]
# S[150]: size=2, capacity=18, row=12, slot=85 | P[21]
# S[151]: size=3, capacity=33, row=9, slot=75 | P[34]
# S[153]: size=3, capacity=60, row=5, slot=0 | P[18]
# S[154]: size=4, capacity=76, row=10, slot=6 | P[0]
# S[155]: size=4, capacity=36, row=1, slot=90 | P[19]
# S[157]: size=2, capacity=22, row=6, slot=76 | P[17]
# S[158]: size=3, capacity=45, row=11, slot=40 | P[8]
# S[159]: size=3, capacity=36, row=9, slot=66 | P[14]
# S[160]: size=2, capacity=24, row=7, slot=67 | P[33]
# S[161]: size=5, capacity=85, row=15, slot=26 | P[0]
# S[162]: size=1, capacity=6, row=12, slot=99 | P[10]
# S[163]: size=3, capacity=45, row=5, slot=41 | P[38]
# S[164]: size=2, capacity=36, row=12, slot=14 | P[26]
# S[165]: size=4, capacity=60, row=3, slot=38 | P[2]
# S[166]: size=2, capacity=16, row=14, slot=95 | P[8]
# S[167]: size=1, capacity=8, row=15, slot=97 | P[6]
# S[168]: size=3, capacity=54, row=10, slot=11 | P[27]
# S[169]: size=1, capacity=11, row=5, slot=73 | P[7]
# S[171]: size=4, capacity=48, row=6, slot=66 | P[34]
# S[172]: size=2, capacity=30, row=15, slot=42 | P[13]
# S[173]: size=1, capacity=17, row=13, slot=25 | P[22]
# S[176]: size=5, capacity=65, row=6, slot=58 | P[23]
# S[177]: size=1, capacity=8, row=13, slot=97 | P[3]
# S[178]: size=5, capacity=60, row=15, slot=67 | P[6]
# S[179]: size=5, capacity=75, row=14, slot=42 | P[25]
# S[180]: size=5, capacity=70, row=3, slot=58 | P[16]
# S[181]: size=5, capacity=95, row=8, slot=9 | P[23]
# S[182]: size=4, capacity=64, row=3, slot=26 | P[0]
# S[183]: size=3, capacity=54, row=9, slot=13 | P[32]
# S[184]: size=3, capacity=57, row=7, slot=12 | P[10]
# S[185]: size=4, capacity=48, row=14, slot=68 | P[12]
# S[186]: size=2, capacity=16, row=11, slot=98 | P[22]
# S[187]: size=4, capacity=68, row=11, slot=28 | P[9]
# S[188]: size=3, capacity=45, row=12, slot=42 | P[0]
# S[190]: size=2, capacity=18, row=15, slot=81 | P[5]
# S[191]: size=2, capacity=26, row=2, slot=57 | P[41]
# S[192]: size=1, capacity=8, row=12, slot=88 | P[43]
# S[193]: size=4, capacity=64, row=14, slot=33 | P[37]
# S[194]: size=1, capacity=11, row=3, slot=36 | P[40]
# S[195]: size=3, capacity=33, row=2, slot=76 | P[35]
# S[196]: size=2, capacity=22, row=1, slot=78 | P[19]
# S[197]: size=5, capacity=70, row=15, slot=51 | P[25]
# S[198]: size=4, capacity=72, row=8, slot=14 | P[19]
# S[199]: size=4, capacity=44, row=15, slot=75 | P[32]
# S[200]: size=1, capacity=10, row=5, slot=79 | P[24]
# S[201]: size=4, capacity=72, row=5, slot=14 | P[4]
# S[202]: size=5, capacity=55, row=8, slot=75 | P[38]
# S[203]: size=4, capacity=52, row=13, slot=59 | P[14]
# S[205]: size=2, capacity=22, row=5, slot=74 | P[20]
# S[206]: size=1, capacity=10, row=3, slot=48 | P[3]
# S[207]: size=4, capacity=44, row=4, slot=77 | P[9]
# S[208]: size=1, capacity=12, row=11, slot=65 | P[25]
# S[209]: size=1, capacity=14, row=11, slot=50 | P[17]
# S[210]: size=1, capacity=11, row=3, slot=47 | P[6]
# S[214]: size=2, capacity=16, row=5, slot=98 | P[29]
# S[215]: size=2, capacity=34, row=6, slot=3 | P[13]
# S[216]: size=2, capacity=34, row=5, slot=25 | P[7]
# S[217]: size=5, capacity=45, row=8, slot=92 | P[6]
# S[218]: size=1, capacity=5, row=3, slot=99 | P[11]
# S[219]: size=3, capacity=60, row=4, slot=0 | P[29]
# S[220]: size=2, capacity=30, row=10, slot=37 | P[3]
# S[221]: size=4, capacity=60, row=9, slot=43 | P[15]
# S[222]: size=4, capacity=80, row=2, slot=3 | P[37]
# S[223]: size=1, capacity=5, row=2, slot=99 | P[35]
# S[224]: size=1, capacity=7, row=12, slot=90 | P[44]
# S[225]: size=4, capacity=56, row=6, slot=52 | P[17]
# S[226]: size=2, capacity=32, row=8, slot=30 | P[2]
# S[228]: size=4, capacity=64, row=7, slot=35 | P[6]
# S[229]: size=1, capacity=18, row=2, slot=15 | P[27]
# S[231]: size=1, capacity=9, row=7, slot=89 | P[14]
# S[232]: size=4, capacity=80, row=0, slot=0 | P[12]
# S[233]: size=2, capacity=32, row=5, slot=31 | P[30]
# S[234]: size=1, capacity=16, row=0, slot=30 | P[7]
# S[236]: size=4, capacity=72, row=14, slot=16 | P[16]
# S[238]: size=5, capacity=85, row=3, slot=21 | P[15]
# S[239]: size=2, capacity=22, row=0, slot=78 | P[44]
# S[240]: size=2, capacity=26, row=7, slot=60 | P[15]
# S[241]: size=2, capacity=36, row=13, slot=15 | P[36]
# S[243]: size=5, capacity=75, row=8, slot=39 | P[18]
# S[244]: size=5, capacity=80, row=13, slot=34 | P[24]
# S[245]: size=3, capacity=48, row=12, slot=32 | P[13]
# S[246]: size=5, capacity=45, row=5, slot=93 | P[0]
# S[247]: size=5, capacity=65, row=5, slot=58 | P[32]
# S[248]: size=3, capacity=33, row=6, slot=78 | P[8]
# S[249]: size=4, capacity=36, row=3, slot=95 | P[33]
# S[250]: size=5, capacity=90, row=2, slot=16 | P[42]
# S[251]: size=1, capacity=19, row=5, slot=9 | P[30]
# S[252]: size=2, capacity=24, row=10, slot=67 | P[8]
# S[253]: size=4, capacity=44, row=3, slot=81 | P[19]
# S[254]: size=1, capacity=18, row=12, slot=16 | P[10]
# S[255]: size=1, capacity=8, row=8, slot=90 | P[44]
# S[256]: size=4, capacity=40, row=15, slot=84 | P[39]
# S[257]: size=5, capacity=80, row=11, slot=35 | P[42]
# S[260]: size=4, capacity=48, row=8, slot=67 | P[7]
# S[261]: size=4, capacity=64, row=10, slot=32 | P[32]
# S[262]: size=4, capacity=48, row=3, slot=53 | P[3]
# S[264]: size=2, capacity=32, row=1, slot=32 | P[25]
# S[265]: size=2, capacity=28, row=2, slot=51 | P[3]
# S[266]: size=3, capacity=39, row=12, slot=59 | P[12]
# S[267]: size=3, capacity=48, row=0, slot=31 | P[40]
# S[268]: size=2, capacity=32, row=9, slot=34 | P[41]
# S[269]: size=2, capacity=18, row=2, slot=90 | P[32]
# S[270]: size=1, capacity=8, row=3, slot=63 | P[44]
# S[271]: size=1, capacity=13, row=2, slot=59 | P[4]
# S[273]: size=2, capacity=24, row=2, slot=67 | P[32]
# S[274]: size=4, capacity=80, row=15, slot=3 | P[14]
# S[275]: size=3, capacity=27, row=12, slot=92 | P[42]
# S[276]: size=1, capacity=8, row=1, slot=53 | P[19]
# S[278]: size=1, capacity=13, row=0, slot=41 | P[29]
# S[279]: size=2, capacity=40, row=13, slot=3 | P[7]
# S[280]: size=3, capacity=48, row=8, slot=32 | P[41]
# S[281]: size=1, capacity=18, row=11, slot=15 | P[7]
# S[282]: size=3, capacity=54, row=7, slot=19 | P[33]
# S[283]: size=3, capacity=36, row=1, slot=71 | P[26]
# S[285]: size=1, capacity=20, row=10, slot=0 | P[8]
# S[286]: size=3, capacity=54, row=4, slot=14 | P[35]
# S[289]: size=1, capacity=14, row=1, slot=46 | P[43]
# S[290]: size=2, capacity=40, row=8, slot=1 | P[2]
# S[291]: size=1, capacity=17, row=2, slot=26 | P[41]
# S[292]: size=4, capacity=68, row=1, slot=28 | P[4]
# S[293]: size=2, capacity=26, row=15, slot=61 | P[12]
# S[294]: size=3, capacity=36, row=13, slot=68 | P[13]
# S[295]: size=5, capacity=100, row=7, slot=6 | P[23]
# S[296]: size=2, capacity=28, row=0, slot=48 | P[9]
# S[297]: size=4, capacity=64, row=5, slot=33 | P[14]
# S[299]: size=2, capacity=30, row=7, slot=44 | P[38]
# S[300]: size=1, capacity=7, row=10, slot=81 | P[43]
# S[301]: size=1, capacity=5, row=1, slot=99 | P[39]
# S[302]: size=3, capacity=42, row=11, slot=51 | P[33]
# S[303]: size=2, capacity=16, row=15, slot=98 | P[41]
# S[304]: size=4, capacity=64, row=2, slot=34 | P[2]
# S[305]: size=3, capacity=45, row=4, slot=41 | P[4]
# S[306]: size=5, capacity=85, row=14, slot=28 | P[40]
# S[307]: size=4, capacity=60, row=1, slot=42 | P[15]
# S[308]: size=5, capacity=55, row=1, slot=80 | P[29]
# S[309]: size=3, capacity=45, row=2, slot=42 | P[12]
# S[310]: size=5, capacity=90, row=0, slot=16 | P[22]
# S[311]: size=1, capacity=7, row=8, slot=97 | P[11]
# S[312]: size=2, capacity=32, row=15, slot=36 | P[40]
# S[313]: size=3, capacity=27, row=10, slot=91 | P[43]
# S[314]: size=1, capacity=16, row=6, slot=6 | P[36]
# S[315]: size=4, capacity=80, row=6, slot=8 | P[20]
# S[316]: size=3, capacity=36, row=12, slot=67 | P[21]
# S[317]: size=1, capacity=5, row=0, slot=50 | P[24]
# S[318]: size=3, capacity=30, row=13, slot=84 | P[41]
# S[320]: size=5, capacity=90, row=13, slot=17 | P[23]
# S[321]: size=3, capacity=60, row=14, slot=7 | P[4]
# S[322]: size=5, capacity=75, row=0, slot=52 | P[6]
# S[324]: size=4, capacity=48, row=11, slot=68 | P[32]
# S[325]: size=4, capacity=76, row=3, slot=3 | P[39]
# S[326]: size=1, capacity=14, row=10, slot=46 | P[22]
# S[327]: size=4, capacity=48, row=7, slot=69 | P[30]
# S[328]: size=1, capacity=10, row=12, slot=79 | P[19]
# S[329]: size=2, capacity=30, row=15, slot=44 | P[18]
# S[330]: size=5, capacity=50, row=10, slot=83 | P[30]
# S[331]: size=4, capacity=36, row=7, slot=90 | P[19]
# S[332]: size=5, capacity=90, row=12, slot=17 | P[8]
# S[333]: size=3, capacity=36, row=0, slot=70 | P[15]
# S[334]: size=2, capacity=20, row=7, slot=82 | P[24]
# S[335]: size=5, capacity=55, row=14, slot=77 | P[43]
# S[336]: size=3, capacity=60, row=11, slot=3 | P[22]
# S[337]: size=4, capacity=52, row=14, slot=64 | P[41]
# S[339]: size=2, capacity=34, row=13, slot=28 | P[35]
# S[340]: size=4, capacity=68, row=12, slot=26 | P[1]
# S[341]: size=2, capacity=26, row=11, slot=59 | P[22]
# S[342]: size=5, capacity=60, row=10, slot=69 | P[29]
# S[344]: size=5, capacity=70, row=9, slot=52 | P[38]
# S[346]: size=3, capacity=39, row=10, slot=61 | P[13]
# S[347]: size=1, capacity=20, row=10, slot=1 | P[6]
# S[348]: size=5, capacity=60, row=9, slot=69 | P[29]
# S[349]: size=1, capacity=18, row=11, slot=16 | P[30]
# S[350]: size=3, capacity=48, row=3, slot=30 | P[37]
# S[351]: size=3, capacity=27, row=6, slot=91 | P[11]
# S[352]: size=5, capacity=100, row=1, slot=3 | P[27]
# S[353]: size=2, capacity=26, row=9, slot=60 | P[37]
# S[354]: size=2, capacity=38, row=2, slot=10 | P[20]
# S[355]: size=3, capacity=57, row=1, slot=8 | P[15]
# S[356]: size=5, capacity=45, row=4, slot=91 | P[18]
# S[357]: size=4, capacity=44, row=12, slot=75 | P[5]
# S[358]: size=5, capacity=65, row=7, slot=62 | P[44]
# S[359]: size=5, capacity=45, row=0, slot=91 | P[13]
# S[360]: size=2, capacity=28, row=5, slot=52 | P[37]
# S[361]: size=5, capacity=60, row=5, slot=68 | P[1]
# S[362]: size=1, capacity=13, row=2, slot=60 | P[20]
# S[363]: size=2, capacity=26, row=1, slot=58 | P[20]
# S[364]: size=3, capacity=36, row=2, slot=69 | P[3]
# S[365]: size=2, capacity=16, row=13, slot=98 | P[43]
# S[366]: size=4, capacity=56, row=4, slot=57 | P[21]
# S[367]: size=2, capacity=34, row=10, slot=14 | P[34]
# S[368]: size=1, capacity=16, row=1, slot=34 | P[21]
# S[369]: size=4, capacity=68, row=4, slot=29 | P[1]
# S[370]: size=2, capacity=30, row=11, slot=43 | P[3]
# S[371]: size=5, capacity=100, row=13, slot=5 | P[37]
# S[373]: size=3, capacity=42, row=1, slot=55 | P[41]
# S[374]: size=5, capacity=90, row=10, slot=18 | P[35]
# S[375]: size=3, capacity=39, row=0, slot=63 | P[32]
# S[376]: size=3, capacity=48, row=14, slot=37 | P[9]
# S[377]: size=3, capacity=45, row=10, slot=43 | P[36]
# S[378]: size=1, capacity=12, row=6, slot=70 | P[11]
# S[379]: size=5, capacity=50, row=6, slot=83 | P[37]
# S[380]: size=4, capacity=60, row=7, slot=46 | P[31]
# S[381]: size=5, capacity=90, row=9, slot=16 | P[16]
# S[382]: size=5, capacity=55, row=11, slot=79 | P[41]
# S[383]: size=2, capacity=32, row=12, slot=35 | P[2]
# S[384]: size=4, capacity=72, row=6, slot=22 | P[43]
# S[385]: size=1, capacity=6, row=11, slot=77 | P[7]
# S[386]: size=4, capacity=76, row=15, slot=12 | P[22]
# S[387]: size=5, capacity=80, row=9, slot=36 | P[17]
# S[389]: size=4, capacity=72, row=1, slot=16 | P[18]
# S[390]: size=3, capacity=48, row=7, slot=39 | P[39]
# S[392]: size=4, capacity=36, row=15, slot=91 | P[4]
# S[394]: size=3, capacity=42, row=13, slot=56 | P[2]
# S[396]: size=1, capacity=18, row=11, slot=18 | P[1]
# S[399]: size=3, capacity=27, row=11, slot=92 | P[18]
# S[401]: size=5, capacity=95, row=13, slot=10 | P[10]
# S[403]: size=3, capacity=30, row=5, slot=80 | P[5]
# S[404]: size=3, capacity=45, row=6, slot=45 | P[4]
# S[405]: size=3, capacity=27, row=2, slot=92 | P[32]
# S[407]: size=2, capacity=24, row=4, slot=61 | P[9]
# S[408]: size=2, capacity=28, row=10, slot=54 | P[27]
# S[409]: size=3, capacity=60, row=12, slot=5 | P[35]
# S[410]: size=2, capacity=40, row=10, slot=2 | P[34]
# S[411]: size=4, capacity=36, row=14, slot=91 | P[42]
# S[412]: size=3, capacity=45, row=5, slot=45 | P[17]
# S[414]: size=4, capacity=48, row=1, slot=74 | P[2]
# S[415]: size=5, capacity=45, row=13, slot=92 | P[20]
# S[416]: size=4, capacity=56, row=8, slot=50 | P[35]
# S[417]: size=2, capacity=30, row=13, slot=44 | P[33]
# S[418]: size=4, capacity=60, row=12, slot=45 | P[31]
# S[419]: size=4, capacity=60, row=4, slot=50 | P[40]
# S[420]: size=5, capacity=75, row=3, slot=42 | P[5]
# S[421]: size=5, capacity=75, row=15, slot=46 | P[9]
# S[422]: size=2, capacity=24, row=14, slot=72 | P[1]
# S[423]: size=3, capacity=48, row=6, slot=38 | P[16]
# S[424]: size=1, capacity=9, row=9, slot=41 | P[10]
# S[426]: size=1, capacity=13, row=4, slot=22 | P[37]
# S[427]: size=5, capacity=65, row=3, slot=73 | P[27]
# S[428]: size=5, capacity=90, row=8, slot=18 | P[27]
# S[429]: size=2, capacity=36, row=5, slot=18 | P[6]
# S[430]: size=3, capacity=51, row=2, slot=27 | P[12]
# S[431]: size=4, capacity=40, row=3, slot=85 | P[32]
# S[432]: size=1, capacity=20, row=8, slot=3 | P[39]
# S[433]: size=1, capacity=20, row=5, slot=5 | P[9]
# S[434]: size=5, capacity=80, row=4, slot=45 | P[10]
# S[435]: size=5, capacity=100, row=4, slot=3 | P[44]
# S[436]: size=5, capacity=50, row=1, slot=85 | P[33]
# S[438]: size=3, capacity=36, row=13, slot=71 | P[11]
# S[439]: size=4, capacity=60, row=11, slot=45 | P[38]
# S[440]: size=3, capacity=54, row=3, slot=12 | P[25]
# S[443]: size=5, capacity=65, row=2, slot=62 | P[14]
# S[445]: size=1, capacity=18, row=15, slot=7 | P[21]
# S[446]: size=5, capacity=45, row=1, slot=94 | P[42]
# S[448]: size=5, capacity=45, row=9, slot=95 | P[28]
# S[451]: size=3, capacity=45, row=9, slot=47 | P[35]
# S[452]: size=4, capacity=80, row=9, slot=5 | P[11]
# S[453]: size=3, capacity=48, row=1, slot=35 | P[17]
# S[454]: size=1, capacity=11, row=10, slot=47 | P[14]
# S[455]: size=1, capacity=12, row=12, slot=40 | P[43]
# S[456]: size=3, capacity=60, row=8, slot=4 | P[22]
# S[457]: size=1, capacity=10, row=14, slot=82 | P[4]
# S[458]: size=3, capacity=60, row=5, slot=6 | P[39]
# S[460]: size=4, capacity=52, row=15, slot=63 | P[21]
# S[461]: size=5, capacity=50, row=12, slot=80 | P[29]
# S[462]: size=2, capacity=16, row=9, slot=87 | P[39]
# S[463]: size=1, capacity=18, row=14, slot=20 | P[35]
# S[464]: size=3, capacity=45, row=2, slot=45 | P[0]
# S[465]: size=4, capacity=56, row=2, slot=53 | P[17]
# S[466]: size=1, capacity=17, row=9, slot=21 | P[33]
# S[470]: size=2, capacity=36, row=11, slot=19 | P[4]
# S[474]: size=1, capacity=9, row=12, slot=87 | P[35]
# S[475]: size=1, capacity=15, row=1, slot=38 | P[19]
# S[479]: size=1, capacity=16, row=0, slot=34 | P[29]
# S[480]: size=3, capacity=48, row=15, slot=38 | P[1]
# S[481]: size=3, capacity=51, row=6, slot=30 | P[26]
# S[483]: size=3, capacity=60, row=3, slot=0 | P[42]
# S[484]: size=1, capacity=17, row=5, slot=27 | P[0]
# S[485]: size=5, capacity=65, row=13, slot=63 | P[28]
# S[486]: size=3, capacity=60, row=2, slot=7 | P[28]
# S[487]: size=1, capacity=12, row=8, slot=54 | P[3]
# S[488]: size=3, capacity=45, row=14, slot=47 | P[10]
# S[489]: size=3, capacity=57, row=9, slot=9 | P[19]
# S[490]: size=1, capacity=6, row=10, slot=94 | P[3]
# S[492]: size=2, capacity=30, row=13, slot=46 | P[2]
# S[493]: size=3, capacity=30, row=11, slot=84 | P[34]
# S[494]: size=5, capacity=65, row=12, slot=62 | P[17]
# S[495]: size=3, capacity=42, row=0, slot=57 | P[41]
# S[496]: size=1, capacity=16, row=10, slot=16 | P[35]
# S[497]: size=5, capacity=75, row=10, slot=49 | P[15]
# S[498]: size=4, capacity=64, row=8, slot=35 | P[30]
# S[499]: size=2, capacity=24, row=6, slot=71 | P[35]
# S[500]: size=2, capacity=20, row=8, slot=80 | P[14]
# S[501]: size=3, capacity=33, row=9, slot=78 | P[36]
# S[502]: size=1, capacity=11, row=7, slot=78 | P[32]
# S[503]: size=4, capacity=40, row=0, slot=84 | P[3]
# S[504]: size=1, capacity=19, row=5, slot=10 | P[12]
# S[505]: size=1, capacity=18, row=7, slot=22 | P[3]
# S[506]: size=1, capacity=6, row=8, slot=99 | P[22]
# S[507]: size=4, capacity=68, row=0, slot=26 | P[26]
# S[508]: size=3, capacity=42, row=14, slot=54 | P[8]
# S[509]: size=3, capacity=30, row=14, slot=83 | P[33]
# S[510]: size=1, capacity=10, row=7, slot=84 | P[11]
# S[511]: size=4, capacity=68, row=13, slot=30 | P[34]
# S[512]: size=5, capacity=80, row=0, slot=35 | P[42]
# S[513]: size=5, capacity=70, row=12, slot=54 | P[6]
# S[514]: size=2, capacity=28, row=7, slot=56 | P[37]
# S[515]: size=2, capacity=30, row=8, slot=44 | P[11]
# S[517]: size=5, capacity=50, row=2, slot=85 | P[21]
# S[518]: size=4, capacity=56, row=5, slot=54 | P[22]
# S[519]: size=5, capacity=90, row=4, slot=17 | P[35]
# S[520]: size=5, capacity=90, row=15, slot=21 | P[33]
# S[521]: size=4, capacity=60, row=6, slot=48 | P[1]
# S[522]: size=1, capacity=19, row=4, slot=8 | P[40]
# S[523]: size=5, capacity=45, row=6, slot=94 | P[24]
# S[524]: size=1, capacity=16, row=13, slot=26 | P[24]
# S[525]: size=2, capacity=20, row=13, slot=76 | P[7]
# S[526]: size=1, capacity=18, row=14, slot=21 | P[8]
# S[527]: size=3, capacity=33, row=5, slot=76 | P[39]
# S[528]: size=1, capacity=15, row=5, slot=37 | P[17]
# S[529]: size=1, capacity=16, row=12, slot=37 | P[41]
# S[530]: size=2, capacity=22, row=2, slot=79 | P[8]
# S[531]: size=2, capacity=20, row=9, slot=85 | P[9]
# S[532]: size=4, capacity=68, row=10, slot=28 | P[11]
# S[534]: size=1, capacity=7, row=6, slot=74 | P[1]
# S[535]: size=4, capacity=60, row=1, slot=49 | P[13]
# S[536]: size=2, capacity=30, row=7, slot=50 | P[5]
# S[537]: size=3, capacity=36, row=3, slot=78 | P[10]
# S[538]: size=2, capacity=34, row=9, slot=29 | P[21]
# S[539]: size=1, capacity=11, row=0, slot=46 | P[2]
# S[540]: size=2, capacity=30, row=5, slot=48 | P[12]
# S[541]: size=3, capacity=45, row=0, slot=43 | P[36]
# S[542]: size=1, capacity=11, row=10, slot=77 | P[3]
# S[544]: size=2, capacity=16, row=7, slot=98 | P[25]
# S[545]: size=1, capacity=9, row=10, slot=80 | P[7]
# S[548]: size=2, capacity=32, row=11, slot=25 | P[28]
# S[549]: size=3, capacity=54, row=7, slot=23 | P[25]
# S[552]: size=1, capacity=19, row=5, slot=11 | P[29]
# S[553]: size=5, capacity=70, row=11, slot=54 | P[31]
# S[554]: size=3, capacity=48, row=10, slot=40 | P[11]
# S[556]: size=1, capacity=10, row=8, slot=82 | P[20]
# S[557]: size=5, capacity=70, row=10, slot=56 | P[24]
# S[558]: size=5, capacity=95, row=4, slot=9 | P[15]
# S[559]: size=1, capacity=18, row=5, slot=20 | P[6]
# S[560]: size=2, capacity=28, row=6, slot=56 | P[39]
# S[561]: size=3, capacity=33, row=7, slot=79 | P[6]
# S[562]: size=2, capacity=20, row=7, slot=85 | P[38]
# S[565]: size=3, capacity=57, row=2, slot=12 | P[28]
# S[566]: size=2, capacity=32, row=5, slot=39 | P[40]
# S[567]: size=5, capacity=90, row=2, slot=21 | P[39]
# S[569]: size=1, capacity=14, row=3, slot=17 | P[36]
# S[570]: size=4, capacity=60, row=13, slot=49 | P[5]
# S[571]: size=1, capacity=17, row=8, slot=7 | P[2]
# S[572]: size=3, capacity=51, row=7, slot=31 | P[28]
# S[573]: size=4, capacity=48, row=0, slot=74 | P[16]
# S[574]: size=5, capacity=70, row=1, slot=62 | P[31]
# S[575]: size=4, capacity=56, row=15, slot=57 | P[30]
# S[576]: size=5, capacity=75, row=12, slot=49 | P[32]
# S[577]: size=1, capacity=6, row=6, slot=99 | P[22]
# S[578]: size=3, capacity=27, row=12, slot=96 | P[9]
# S[580]: size=3, capacity=27, row=11, slot=95 | P[10]
# S[583]: size=5, capacity=90, row=14, slot=22 | P[7]
# S[584]: size=4, capacity=52, row=11, slot=61 | P[19]
# S[585]: size=3, capacity=39, row=9, slot=62 | P[43]
# S[586]: size=4, capacity=76, row=11, slot=11 | P[43]
# S[587]: size=3, capacity=51, row=5, slot=28 | P[20]
# S[588]: size=4, capacity=40, row=5, slot=84 | P[30]
# S[590]: size=1, capacity=6, row=5, slot=91 | P[20]
# S[591]: size=5, capacity=50, row=4, slot=86 | P[3]
# S[592]: size=4, capacity=52, row=8, slot=63 | P[36]
# S[593]: size=1, capacity=8, row=14, slot=97 | P[18]
# S[594]: size=3, capacity=36, row=15, slot=72 | P[34]
# S[596]: size=2, capacity=18, row=3, slot=50 | P[36]
# S[597]: size=3, capacity=30, row=15, slot=88 | P[18]
# S[598]: size=3, capacity=51, row=11, slot=32 | P[26]
# S[600]: size=1, capacity=15, row=9, slot=22 | P[12]
# S[601]: size=2, capacity=32, row=3, slot=33 | P[19]
# S[602]: size=4, capacity=76, row=7, slot=15 | P[34]
# S[603]: size=5, capacity=50, row=11, slot=87 | P[28]
# S[605]: size=2, capacity=40, row=0, slot=4 | P[43]
# S[606]: size=4, capacity=44, row=0, slot=80 | P[18]
# S[607]: size=3, capacity=60, row=15, slot=9 | P[12]
# S[608]: size=2, capacity=22, row=15, slot=79 | P[7]
# S[609]: size=4, capacity=72, row=11, slot=21 | P[40]
# S[610]: size=4, capacity=72, row=6, slot=26 | P[7]
# S[611]: size=4, capacity=60, row=8, slot=46 | P[26]
# S[612]: size=3, capacity=45, row=4, slot=54 | P[19]
# S[613]: size=3, capacity=30, row=8, slot=84 | P[3]
# S[615]: size=2, capacity=40, row=14, slot=0 | P[26]
# S[617]: size=1, capacity=6, row=4, slot=39 | P[23]
# S[619]: size=4, capacity=72, row=5, slot=21 | P[25]
# S[621]: size=2, capacity=34, row=8, slot=28 | P[17]
# S[622]: size=1, capacity=11, row=13, slot=74 | P[0]
# S[623]: size=1, capacity=18, row=3, slot=15 | P[39]
# S[624]: size=4, capacity=68, row=2, slot=30 | P[16]
