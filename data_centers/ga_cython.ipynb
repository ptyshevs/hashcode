# %%
import numpy as np
from Server import Server

# %%
# %load_ext Cython
# Out:
# The Cython extension is already loaded. To reload it, use:
#   %reload_ext Cython

# %%
from ga import input_wrapper, solve
from helpers import parse
from pruner import magic

# %%
path = 'input/dc.in'

# %%
def input_wrapper(inp):
    servers = []
    for i, v in enumerate(inp):
        r, slot, id = v[0]
        s, cap = v[1][0], v[1][1]
        serv = Server(id, s, cap)
        serv.row = r
        serv.slot = slot
        servers.append(serv)
    return servers

# %%
R, S, U, P, M, unavaiable, servers = parse(path)
servers = input_wrapper(magic(path))

# %%
servers
# Out:
# [S[0]: size=2, capacity=40, row=0, slot=0 | P[-1],
#  S[1]: size=2, capacity=40, row=0, slot=2 | P[-1],
#  S[2]: size=3, capacity=60, row=0, slot=4 | P[-1],
#  S[3]: size=2, capacity=40, row=0, slot=7 | P[-1],
#  S[4]: size=4, capacity=80, row=0, slot=11 | P[-1],
#  S[5]: size=1, capacity=20, row=0, slot=9 | P[-1],
#  S[6]: size=5, capacity=100, row=0, slot=15 | P[-1],
#  S[7]: size=3, capacity=60, row=0, slot=20 | P[-1],
#  S[8]: size=2, capacity=40, row=0, slot=23 | P[-1],
#  S[9]: size=3, capacity=60, row=0, slot=25 | P[-1],
#  S[10]: size=5, capacity=100, row=0, slot=28 | P[-1],
#  S[11]: size=2, capacity=40, row=0, slot=33 | P[-1],
#  S[12]: size=3, capacity=60, row=0, slot=35 | P[-1],
#  S[13]: size=1, capacity=20, row=0, slot=38 | P[-1],
#  S[14]: size=1, capacity=20, row=0, slot=39 | P[-1],
#  S[15]: size=3, capacity=60, row=0, slot=43 | P[-1],
#  S[16]: size=3, capacity=60, row=0, slot=48 | P[-1],
#  S[17]: size=4, capacity=80, row=0, slot=52 | P[-1],
#  S[18]: size=4, capacity=80, row=0, slot=56 | P[-1],
#  S[19]: size=4, capacity=80, row=0, slot=60 | P[-1],
#  S[20]: size=2, capacity=40, row=0, slot=64 | P[-1],
#  S[21]: size=1, capacity=20, row=0, slot=41 | P[-1],
#  S[22]: size=2, capacity=40, row=0, slot=66 | P[-1],
#  S[23]: size=5, capacity=100, row=0, slot=68 | P[-1],
#  S[24]: size=4, capacity=80, row=0, slot=74 | P[-1],
#  S[25]: size=3, capacity=60, row=0, slot=78 | P[-1],
#  S[26]: size=3, capacity=60, row=0, slot=81 | P[-1],
#  S[27]: size=1, capacity=20, row=0, slot=46 | P[-1],
#  S[28]: size=5, capacity=100, row=0, slot=84 | P[-1],
#  S[29]: size=5, capacity=100, row=0, slot=89 | P[-1],
#  S[30]: size=3, capacity=60, row=0, slot=94 | P[-1],
#  S[31]: size=2, capacity=40, row=0, slot=97 | P[-1],
#  S[32]: size=1, capacity=20, row=0, slot=99 | P[-1],
#  S[33]: size=1, capacity=20, row=1, slot=0 | P[-1],
#  S[34]: size=5, capacity=100, row=1, slot=1 | P[-1],
#  S[35]: size=4, capacity=80, row=1, slot=6 | P[-1],
#  S[36]: size=3, capacity=60, row=1, slot=10 | P[-1],
#  S[37]: size=3, capacity=60, row=1, slot=13 | P[-1],
#  S[38]: size=3, capacity=60, row=1, slot=16 | P[-1],
#  S[39]: size=3, capacity=60, row=1, slot=19 | P[-1],
#  S[40]: size=2, capacity=40, row=1, slot=22 | P[-1],
#  S[41]: size=3, capacity=60, row=1, slot=24 | P[-1],
#  S[42]: size=2, capacity=40, row=1, slot=28 | P[-1],
#  S[43]: size=5, capacity=95, row=1, slot=30 | P[-1],
#  S[44]: size=1, capacity=19, row=1, slot=35 | P[-1],
#  S[45]: size=5, capacity=95, row=1, slot=40 | P[-1],
#  S[46]: size=1, capacity=19, row=1, slot=36 | P[-1],
#  S[47]: size=1, capacity=19, row=1, slot=37 | P[-1],
#  S[48]: size=1, capacity=19, row=1, slot=38 | P[-1],
#  S[49]: size=5, capacity=95, row=1, slot=49 | P[-1],
#  S[50]: size=5, capacity=95, row=1, slot=55 | P[-1],
#  S[51]: size=5, capacity=95, row=1, slot=62 | P[-1],
#  S[52]: size=4, capacity=76, row=1, slot=67 | P[-1],
#  S[53]: size=5, capacity=95, row=1, slot=71 | P[-1],
#  S[54]: size=3, capacity=57, row=1, slot=45 | P[-1],
#  S[55]: size=1, capacity=19, row=1, slot=60 | P[-1],
#  S[56]: size=4, capacity=76, row=1, slot=76 | P[-1],
#  S[57]: size=2, capacity=38, row=1, slot=80 | P[-1],
#  S[58]: size=3, capacity=57, row=1, slot=82 | P[-1],
#  S[59]: size=4, capacity=76, row=1, slot=85 | P[-1],
#  S[60]: size=5, capacity=95, row=1, slot=89 | P[-1],
#  S[61]: size=3, capacity=57, row=1, slot=94 | P[-1],
#  S[62]: size=1, capacity=19, row=1, slot=97 | P[-1],
#  S[63]: size=1, capacity=19, row=1, slot=98 | P[-1],
#  S[64]: size=1, capacity=19, row=1, slot=99 | P[-1],
#  S[65]: size=5, capacity=95, row=2, slot=0 | P[-1],
#  S[66]: size=3, capacity=57, row=2, slot=5 | P[-1],
#  S[67]: size=4, capacity=76, row=2, slot=8 | P[-1],
#  S[68]: size=4, capacity=76, row=2, slot=12 | P[-1],
#  S[69]: size=5, capacity=90, row=2, slot=16 | P[-1],
#  S[70]: size=2, capacity=36, row=2, slot=21 | P[-1],
#  S[71]: size=5, capacity=90, row=2, slot=23 | P[-1],
#  S[72]: size=1, capacity=18, row=2, slot=28 | P[-1],
#  S[73]: size=1, capacity=18, row=2, slot=29 | P[-1],
#  S[74]: size=5, capacity=90, row=2, slot=30 | P[-1],
#  S[75]: size=3, capacity=54, row=2, slot=35 | P[-1],
#  S[76]: size=5, capacity=90, row=2, slot=38 | P[-1],
#  S[77]: size=1, capacity=18, row=2, slot=43 | P[-1],
#  S[78]: size=2, capacity=36, row=2, slot=44 | P[-1],
#  S[79]: size=3, capacity=54, row=2, slot=49 | P[-1],
#  S[80]: size=3, capacity=54, row=2, slot=52 | P[-1],
#  S[81]: size=4, capacity=72, row=2, slot=55 | P[-1],
#  S[82]: size=4, capacity=72, row=2, slot=62 | P[-1],
#  S[83]: size=1, capacity=18, row=2, slot=46 | P[-1],
#  S[84]: size=4, capacity=72, row=2, slot=66 | P[-1],
#  S[85]: size=2, capacity=36, row=2, slot=59 | P[-1],
#  S[86]: size=5, capacity=90, row=2, slot=74 | P[-1],
#  S[87]: size=1, capacity=18, row=2, slot=47 | P[-1],
#  S[88]: size=1, capacity=18, row=2, slot=70 | P[-1],
#  S[89]: size=3, capacity=54, row=2, slot=79 | P[-1],
#  S[90]: size=3, capacity=54, row=2, slot=82 | P[-1],
#  S[91]: size=5, capacity=90, row=2, slot=85 | P[-1],
#  S[92]: size=5, capacity=90, row=2, slot=90 | P[-1],
#  S[93]: size=5, capacity=90, row=2, slot=95 | P[-1],
#  S[94]: size=1, capacity=18, row=2, slot=71 | P[-1],
#  S[95]: size=5, capacity=90, row=3, slot=0 | P[-1],
#  S[96]: size=5, capacity=90, row=3, slot=5 | P[-1],
#  S[97]: size=4, capacity=72, row=3, slot=10 | P[-1],
#  S[98]: size=4, capacity=72, row=3, slot=14 | P[-1],
#  S[99]: size=1, capacity=18, row=2, slot=72 | P[-1],
#  S[100]: size=5, capacity=90, row=3, slot=19 | P[-1],
#  S[101]: size=2, capacity=36, row=3, slot=24 | P[-1],
#  S[102]: size=3, capacity=54, row=3, slot=26 | P[-1],
#  S[103]: size=1, capacity=18, row=3, slot=29 | P[-1],
#  S[104]: size=1, capacity=18, row=3, slot=30 | P[-1],
#  S[105]: size=2, capacity=36, row=3, slot=31 | P[-1],
#  S[106]: size=1, capacity=18, row=3, slot=33 | P[-1],
#  S[107]: size=5, capacity=90, row=3, slot=38 | P[-1],
#  S[108]: size=5, capacity=90, row=3, slot=43 | P[-1],
#  S[109]: size=1, capacity=18, row=3, slot=34 | P[-1],
#  S[110]: size=3, capacity=54, row=3, slot=53 | P[-1],
#  S[111]: size=1, capacity=18, row=3, slot=36 | P[-1],
#  S[112]: size=5, capacity=90, row=3, slot=58 | P[-1],
#  S[113]: size=5, capacity=90, row=3, slot=67 | P[-1],
#  S[114]: size=4, capacity=72, row=3, slot=73 | P[-1],
#  S[115]: size=4, capacity=72, row=3, slot=77 | P[-1],
#  S[116]: size=4, capacity=72, row=3, slot=81 | P[-1],
#  S[117]: size=1, capacity=18, row=3, slot=48 | P[-1],
#  S[118]: size=4, capacity=68, row=3, slot=85 | P[-1],
#  S[119]: size=1, capacity=17, row=3, slot=50 | P[-1],
#  S[120]: size=3, capacity=51, row=3, slot=89 | P[-1],
#  S[121]: size=4, capacity=68, row=3, slot=95 | P[-1],
#  S[122]: size=4, capacity=68, row=4, slot=0 | P[-1],
#  S[123]: size=5, capacity=85, row=4, slot=4 | P[-1],
#  S[124]: size=1, capacity=17, row=3, slot=51 | P[-1],
#  S[125]: size=5, capacity=85, row=4, slot=9 | P[-1],
#  S[126]: size=5, capacity=85, row=4, slot=14 | P[-1],
#  S[127]: size=5, capacity=85, row=4, slot=29 | P[-1],
#  S[128]: size=2, capacity=34, row=3, slot=92 | P[-1],
#  S[129]: size=2, capacity=34, row=4, slot=19 | P[-1],
#  S[130]: size=5, capacity=85, row=4, slot=34 | P[-1],
#  S[131]: size=1, capacity=17, row=3, slot=56 | P[-1],
#  S[132]: size=4, capacity=68, row=4, slot=45 | P[-1],
#  S[133]: size=2, capacity=34, row=4, slot=21 | P[-1],
#  S[134]: size=2, capacity=34, row=4, slot=24 | P[-1],
#  S[135]: size=5, capacity=85, row=4, slot=49 | P[-1],
#  S[136]: size=1, capacity=17, row=3, slot=63 | P[-1],
#  S[137]: size=4, capacity=68, row=4, slot=54 | P[-1],
#  S[138]: size=5, capacity=85, row=4, slot=58 | P[-1],
#  S[139]: size=2, capacity=34, row=4, slot=41 | P[-1],
#  S[140]: size=4, capacity=68, row=4, slot=64 | P[-1],
#  S[141]: size=2, capacity=34, row=4, slot=68 | P[-1],
#  S[142]: size=4, capacity=68, row=4, slot=70 | P[-1],
#  S[143]: size=3, capacity=51, row=4, slot=74 | P[-1],
#  S[144]: size=1, capacity=17, row=3, slot=65 | P[-1],
#  S[145]: size=3, capacity=51, row=4, slot=77 | P[-1],
#  S[146]: size=1, capacity=17, row=3, slot=99 | P[-1],
#  S[147]: size=4, capacity=68, row=4, slot=80 | P[-1],
#  S[148]: size=4, capacity=68, row=4, slot=84 | P[-1],
#  S[149]: size=4, capacity=68, row=4, slot=88 | P[-1],
#  S[150]: size=2, capacity=34, row=4, slot=92 | P[-1],
#  S[151]: size=1, capacity=17, row=4, slot=26 | P[-1],
#  S[152]: size=3, capacity=51, row=4, slot=94 | P[-1],
#  S[153]: size=3, capacity=51, row=4, slot=97 | P[-1],
#  S[154]: size=3, capacity=51, row=5, slot=0 | P[-1],
#  S[155]: size=2, capacity=34, row=5, slot=5 | P[-1],
#  S[156]: size=4, capacity=68, row=5, slot=7 | P[-1],
#  S[157]: size=3, capacity=48, row=5, slot=11 | P[-1],
#  S[158]: size=4, capacity=64, row=5, slot=14 | P[-1],
#  S[159]: size=2, capacity=32, row=5, slot=18 | P[-1],
#  S[160]: size=3, capacity=48, row=5, slot=20 | P[-1],
#  S[161]: size=4, capacity=64, row=5, slot=23 | P[-1],
#  S[162]: size=5, capacity=80, row=5, slot=27 | P[-1],
#  S[163]: size=4, capacity=64, row=5, slot=32 | P[-1],
#  S[164]: size=4, capacity=64, row=5, slot=39 | P[-1],
#  S[165]: size=2, capacity=32, row=5, slot=36 | P[-1],
#  S[166]: size=4, capacity=64, row=5, slot=45 | P[-1],
#  S[167]: size=2, capacity=32, row=5, slot=49 | P[-1],
#  S[168]: size=1, capacity=16, row=4, slot=39 | P[-1],
#  S[169]: size=5, capacity=80, row=5, slot=51 | P[-1],
#  S[170]: size=3, capacity=48, row=5, slot=56 | P[-1],
#  S[171]: size=5, capacity=80, row=5, slot=59 | P[-1],
#  S[172]: size=4, capacity=64, row=5, slot=64 | P[-1],
#  S[173]: size=2, capacity=32, row=5, slot=68 | P[-1],
#  S[174]: size=3, capacity=48, row=5, slot=70 | P[-1],
#  S[175]: size=2, capacity=32, row=5, slot=73 | P[-1],
#  S[176]: size=3, capacity=48, row=5, slot=75 | P[-1],
#  S[177]: size=4, capacity=64, row=5, slot=78 | P[-1],
#  S[178]: size=4, capacity=64, row=5, slot=84 | P[-1],
#  S[179]: size=2, capacity=32, row=5, slot=88 | P[-1],
#  S[180]: size=1, capacity=16, row=4, slot=43 | P[-1],
#  S[181]: size=3, capacity=48, row=5, slot=93 | P[-1],
#  S[182]: size=1, capacity=16, row=5, slot=43 | P[-1],
#  S[183]: size=3, capacity=48, row=5, slot=96 | P[-1],
#  S[184]: size=2, capacity=32, row=5, slot=90 | P[-1],
#  S[185]: size=5, capacity=80, row=6, slot=0 | P[-1],
#  S[186]: size=3, capacity=48, row=6, slot=8 | P[-1],
#  S[187]: size=3, capacity=48, row=6, slot=11 | P[-1],
#  S[188]: size=5, capacity=80, row=6, slot=14 | P[-1],
#  S[189]: size=3, capacity=48, row=6, slot=19 | P[-1],
#  S[190]: size=1, capacity=16, row=5, slot=82 | P[-1],
#  S[191]: size=3, capacity=48, row=6, slot=22 | P[-1],
#  S[192]: size=1, capacity=16, row=5, slot=99 | P[-1],
#  S[193]: size=4, capacity=64, row=6, slot=25 | P[-1],
#  S[194]: size=5, capacity=80, row=6, slot=34 | P[-1],
#  S[195]: size=1, capacity=16, row=6, slot=6 | P[-1],
#  S[196]: size=1, capacity=16, row=6, slot=29 | P[-1],
#  S[197]: size=2, capacity=32, row=6, slot=30 | P[-1],
#  S[198]: size=3, capacity=48, row=6, slot=39 | P[-1],
#  S[199]: size=2, capacity=32, row=6, slot=42 | P[-1],
#  S[200]: size=2, capacity=32, row=6, slot=44 | P[-1],
#  S[201]: size=4, capacity=60, row=6, slot=46 | P[-1],
#  S[202]: size=2, capacity=30, row=6, slot=50 | P[-1],
#  S[203]: size=5, capacity=75, row=6, slot=52 | P[-1],
#  S[204]: size=2, capacity=30, row=6, slot=57 | P[-1],
#  S[205]: size=2, capacity=30, row=6, slot=59 | P[-1],
#  S[206]: size=4, capacity=60, row=6, slot=61 | P[-1],
#  S[207]: size=2, capacity=30, row=6, slot=65 | P[-1],
#  S[208]: size=1, capacity=15, row=6, slot=32 | P[-1],
#  S[209]: size=3, capacity=45, row=6, slot=67 | P[-1],
#  S[210]: size=3, capacity=45, row=6, slot=70 | P[-1],
#  S[211]: size=4, capacity=60, row=6, slot=76 | P[-1],
#  S[212]: size=2, capacity=30, row=6, slot=73 | P[-1],
#  S[213]: size=5, capacity=75, row=6, slot=80 | P[-1],
#  S[214]: size=3, capacity=45, row=6, slot=85 | P[-1],
#  S[215]: size=2, capacity=30, row=6, slot=88 | P[-1],
#  S[216]: size=4, capacity=60, row=6, slot=90 | P[-1],
#  S[217]: size=5, capacity=75, row=6, slot=94 | P[-1],
#  S[218]: size=2, capacity=30, row=7, slot=0 | P[-1],
#  S[219]: size=3, capacity=45, row=7, slot=2 | P[-1],
#  S[220]: size=4, capacity=60, row=7, slot=5 | P[-1],
#  S[221]: size=3, capacity=45, row=7, slot=9 | P[-1],
#  S[222]: size=5, capacity=75, row=7, slot=12 | P[-1],
#  S[223]: size=2, capacity=30, row=7, slot=17 | P[-1],
#  S[224]: size=2, capacity=30, row=7, slot=19 | P[-1],
#  S[225]: size=3, capacity=45, row=7, slot=21 | P[-1],
#  S[226]: size=4, capacity=60, row=7, slot=24 | P[-1],
#  S[227]: size=3, capacity=45, row=7, slot=28 | P[-1],
#  S[228]: size=3, capacity=45, row=7, slot=31 | P[-1],
#  S[229]: size=2, capacity=30, row=7, slot=35 | P[-1],
#  S[230]: size=4, capacity=60, row=7, slot=37 | P[-1],
#  S[231]: size=4, capacity=60, row=7, slot=41 | P[-1],
#  S[232]: size=5, capacity=75, row=7, slot=45 | P[-1],
#  S[233]: size=5, capacity=75, row=7, slot=50 | P[-1],
#  S[234]: size=4, capacity=60, row=7, slot=55 | P[-1],
#  S[235]: size=3, capacity=45, row=7, slot=59 | P[-1],
#  S[236]: size=3, capacity=45, row=7, slot=62 | P[-1],
#  S[237]: size=1, capacity=15, row=6, slot=99 | P[-1],
#  S[238]: size=3, capacity=45, row=7, slot=65 | P[-1],
#  S[239]: size=2, capacity=30, row=7, slot=68 | P[-1],
#  S[240]: size=5, capacity=75, row=7, slot=70 | P[-1],
#  S[241]: size=2, capacity=30, row=7, slot=75 | P[-1],
#  S[242]: size=4, capacity=60, row=7, slot=77 | P[-1],
#  S[243]: size=1, capacity=15, row=7, slot=81 | P[-1],
#  S[244]: size=4, capacity=60, row=7, slot=82 | P[-1],
#  S[245]: size=2, capacity=30, row=7, slot=86 | P[-1],
#  S[246]: size=2, capacity=30, row=7, slot=88 | P[-1],
#  S[247]: size=3, capacity=45, row=7, slot=90 | P[-1],
#  S[248]: size=4, capacity=60, row=7, slot=93 | P[-1],
#  S[249]: size=5, capacity=75, row=8, slot=0 | P[-1],
#  S[250]: size=1, capacity=15, row=7, slot=97 | P[-1],
#  S[251]: size=4, capacity=60, row=8, slot=9 | P[-1],
#  S[252]: size=3, capacity=45, row=8, slot=5 | P[-1],
#  S[253]: size=2, capacity=28, row=7, slot=98 | P[-1],
#  S[254]: size=4, capacity=56, row=8, slot=13 | P[-1],
#  S[255]: size=1, capacity=14, row=8, slot=17 | P[-1],
#  S[256]: size=2, capacity=28, row=8, slot=18 | P[-1],
#  S[257]: size=4, capacity=56, row=8, slot=20 | P[-1],
#  S[258]: size=2, capacity=28, row=8, slot=24 | P[-1],
#  S[259]: size=5, capacity=70, row=8, slot=26 | P[-1],
#  S[260]: size=5, capacity=70, row=8, slot=31 | P[-1],
#  S[261]: size=1, capacity=14, row=8, slot=36 | P[-1],
#  S[262]: size=4, capacity=56, row=8, slot=37 | P[-1],
#  S[263]: size=2, capacity=28, row=8, slot=41 | P[-1],
#  S[264]: size=1, capacity=14, row=8, slot=43 | P[-1],
#  S[265]: size=2, capacity=28, row=8, slot=44 | P[-1],
#  S[266]: size=3, capacity=42, row=8, slot=46 | P[-1],
#  S[267]: size=1, capacity=14, row=8, slot=49 | P[-1],
#  S[268]: size=5, capacity=70, row=8, slot=50 | P[-1],
#  S[269]: size=2, capacity=28, row=8, slot=55 | P[-1],
#  S[270]: size=4, capacity=56, row=8, slot=58 | P[-1],
#  S[271]: size=3, capacity=42, row=8, slot=62 | P[-1],
#  S[272]: size=3, capacity=42, row=8, slot=65 | P[-1],
#  S[273]: size=2, capacity=28, row=8, slot=68 | P[-1],
#  S[274]: size=4, capacity=56, row=8, slot=72 | P[-1],
#  S[275]: size=4, capacity=56, row=8, slot=76 | P[-1],
#  S[276]: size=3, capacity=42, row=8, slot=80 | P[-1],
#  S[277]: size=3, capacity=42, row=8, slot=84 | P[-1],
#  S[278]: size=5, capacity=70, row=8, slot=92 | P[-1],
#  S[279]: size=2, capacity=28, row=8, slot=87 | P[-1],
#  S[280]: size=4, capacity=56, row=9, slot=0 | P[-1],
#  S[281]: size=5, capacity=70, row=9, slot=4 | P[-1],
#  S[282]: size=5, capacity=70, row=9, slot=9 | P[-1],
#  S[283]: size=2, capacity=28, row=8, slot=89 | P[-1],
#  S[284]: size=1, capacity=14, row=8, slot=70 | P[-1],
#  S[285]: size=5, capacity=70, row=9, slot=14 | P[-1],
#  S[286]: size=4, capacity=56, row=9, slot=19 | P[-1],
#  S[287]: size=2, capacity=26, row=9, slot=24 | P[-1],
#  S[288]: size=2, capacity=26, row=9, slot=26 | P[-1],
#  S[289]: size=5, capacity=65, row=9, slot=28 | P[-1],
#  S[290]: size=5, capacity=65, row=9, slot=33 | P[-1],
#  S[291]: size=3, capacity=39, row=9, slot=38 | P[-1],
#  S[292]: size=3, capacity=39, row=9, slot=43 | P[-1],
#  S[293]: size=3, capacity=39, row=9, slot=46 | P[-1],
#  S[294]: size=5, capacity=65, row=9, slot=49 | P[-1],
#  S[295]: size=5, capacity=65, row=9, slot=54 | P[-1],
#  S[296]: size=2, capacity=26, row=9, slot=59 | P[-1],
#  S[297]: size=4, capacity=52, row=9, slot=61 | P[-1],
#  S[298]: size=2, capacity=26, row=9, slot=66 | P[-1],
#  S[299]: size=5, capacity=65, row=9, slot=68 | P[-1],
#  S[300]: size=3, capacity=39, row=9, slot=75 | P[-1],
#  S[301]: size=1, capacity=13, row=8, slot=97 | P[-1],
#  S[302]: size=1, capacity=13, row=8, slot=99 | P[-1],
#  S[303]: size=2, capacity=26, row=9, slot=78 | P[-1],
#  S[304]: size=4, capacity=52, row=9, slot=80 | P[-1],
#  S[305]: size=2, capacity=26, row=9, slot=84 | P[-1],
#  S[306]: size=3, capacity=39, row=9, slot=86 | P[-1],
#  S[307]: size=2, capacity=26, row=9, slot=90 | P[-1],
#  S[308]: size=5, capacity=65, row=9, slot=92 | P[-1],
#  S[309]: size=1, capacity=13, row=9, slot=41 | P[-1],
#  S[310]: size=2, capacity=26, row=9, slot=97 | P[-1],
#  S[311]: size=3, capacity=39, row=10, slot=0 | P[-1],
#  S[312]: size=1, capacity=13, row=9, slot=73 | P[-1],
#  S[313]: size=5, capacity=65, row=10, slot=3 | P[-1],
#  S[314]: size=5, capacity=65, row=10, slot=8 | P[-1],
#  S[315]: size=4, capacity=52, row=10, slot=13 | P[-1],
#  S[316]: size=5, capacity=65, row=10, slot=18 | P[-1],
#  S[317]: size=5, capacity=65, row=10, slot=24 | P[-1],
#  S[318]: size=4, capacity=52, row=10, slot=29 | P[-1],
#  S[319]: size=3, capacity=39, row=10, slot=33 | P[-1],
#  S[320]: size=4, capacity=52, row=10, slot=40 | P[-1],
#  S[321]: size=3, capacity=36, row=10, slot=44 | P[-1],
#  S[322]: size=1, capacity=12, row=9, slot=99 | P[-1],
#  S[323]: size=4, capacity=48, row=10, slot=49 | P[-1],
#  S[324]: size=3, capacity=36, row=10, slot=53 | P[-1],
#  S[325]: size=5, capacity=60, row=10, slot=56 | P[-1],
#  S[326]: size=1, capacity=12, row=10, slot=37 | P[-1],
#  S[327]: size=4, capacity=48, row=10, slot=61 | P[-1],
#  S[328]: size=2, capacity=24, row=10, slot=65 | P[-1],
#  S[329]: size=5, capacity=60, row=10, slot=67 | P[-1],
#  S[330]: size=3, capacity=36, row=10, slot=72 | P[-1],
#  S[331]: size=2, capacity=24, row=10, slot=75 | P[-1],
#  S[332]: size=4, capacity=48, row=10, slot=77 | P[-1],
#  S[333]: size=5, capacity=60, row=10, slot=83 | P[-1],
#  S[334]: size=4, capacity=48, row=10, slot=88 | P[-1],
#  S[335]: size=1, capacity=12, row=10, slot=38 | P[-1],
#  S[336]: size=2, capacity=24, row=10, slot=92 | P[-1],
#  S[337]: size=4, capacity=48, row=10, slot=96 | P[-1],
#  S[338]: size=4, capacity=48, row=11, slot=0 | P[-1],
#  S[339]: size=2, capacity=24, row=11, slot=4 | P[-1],
#  S[340]: size=3, capacity=36, row=11, slot=6 | P[-1],
#  S[341]: size=3, capacity=36, row=11, slot=9 | P[-1],
#  S[342]: size=3, capacity=36, row=11, slot=12 | P[-1],
#  S[343]: size=4, capacity=48, row=11, slot=18 | P[-1],
#  S[344]: size=4, capacity=48, row=11, slot=22 | P[-1],
#  S[345]: size=3, capacity=36, row=11, slot=28 | P[-1],
#  S[346]: size=5, capacity=60, row=11, slot=31 | P[-1],
#  S[347]: size=5, capacity=60, row=11, slot=36 | P[-1],
#  S[348]: size=5, capacity=60, row=11, slot=41 | P[-1],
#  S[349]: size=3, capacity=36, row=11, slot=46 | P[-1],
#  S[350]: size=1, capacity=12, row=10, slot=47 | P[-1],
#  S[351]: size=2, capacity=24, row=11, slot=15 | P[-1],
#  S[352]: size=4, capacity=48, row=11, slot=49 | P[-1],
#  S[353]: size=2, capacity=24, row=11, slot=53 | P[-1],
#  S[354]: size=3, capacity=36, row=11, slot=55 | P[-1],
#  S[355]: size=1, capacity=12, row=10, slot=81 | P[-1],
#  S[356]: size=1, capacity=12, row=10, slot=94 | P[-1],
#  S[357]: size=2, capacity=24, row=11, slot=58 | P[-1],
#  S[358]: size=3, capacity=36, row=11, slot=60 | P[-1],
#  S[359]: size=4, capacity=48, row=11, slot=68 | P[-1],
#  S[360]: size=3, capacity=36, row=11, slot=63 | P[-1],
#  S[361]: size=5, capacity=55, row=11, slot=72 | P[-1],
#  S[362]: size=5, capacity=55, row=11, slot=79 | P[-1],
#  S[363]: size=3, capacity=33, row=11, slot=84 | P[-1],
#  S[364]: size=1, capacity=11, row=11, slot=26 | P[-1],
#  S[365]: size=3, capacity=33, row=11, slot=87 | P[-1],
#  S[366]: size=2, capacity=22, row=11, slot=90 | P[-1],
#  S[367]: size=1, capacity=11, row=11, slot=77 | P[-1],
#  S[368]: size=4, capacity=44, row=11, slot=92 | P[-1],
#  S[369]: size=1, capacity=11, row=11, slot=96 | P[-1],
#  S[370]: size=3, capacity=33, row=11, slot=97 | P[-1],
#  S[371]: size=5, capacity=55, row=12, slot=0 | P[-1],
#  S[372]: size=3, capacity=33, row=12, slot=5 | P[-1],
#  S[373]: size=3, capacity=33, row=12, slot=8 | P[-1],
#  S[374]: size=2, capacity=22, row=12, slot=11 | P[-1],
#  S[375]: size=1, capacity=11, row=12, slot=13 | P[-1],
#  S[376]: size=1, capacity=11, row=12, slot=14 | P[-1],
#  S[377]: size=3, capacity=33, row=12, slot=15 | P[-1],
#  S[378]: size=2, capacity=22, row=12, slot=18 | P[-1],
#  S[379]: size=4, capacity=44, row=12, slot=20 | P[-1],
#  S[380]: size=5, capacity=55, row=12, slot=24 | P[-1],
#  S[381]: size=2, capacity=22, row=12, slot=29 | P[-1],
#  S[382]: size=4, capacity=44, row=12, slot=31 | P[-1],
#  S[383]: size=1, capacity=11, row=12, slot=35 | P[-1],
#  S[384]: size=2, capacity=22, row=12, slot=36 | P[-1],
#  S[385]: size=3, capacity=33, row=12, slot=38 | P[-1],
#  S[386]: size=4, capacity=44, row=12, slot=42 | P[-1],
#  S[387]: size=5, capacity=55, row=12, slot=46 | P[-1],
#  S[388]: size=5, capacity=55, row=12, slot=51 | P[-1],
#  S[389]: size=4, capacity=44, row=12, slot=56 | P[-1],
#  S[390]: size=5, capacity=55, row=12, slot=60 | P[-1],
#  S[391]: size=1, capacity=11, row=12, slot=65 | P[-1],
#  S[392]: size=3, capacity=33, row=12, slot=66 | P[-1],
#  S[393]: size=1, capacity=11, row=12, slot=69 | P[-1],
#  S[394]: size=3, capacity=33, row=12, slot=70 | P[-1],
#  S[395]: size=2, capacity=22, row=12, slot=73 | P[-1],
#  S[396]: size=1, capacity=11, row=12, slot=75 | P[-1],
#  S[397]: size=1, capacity=11, row=12, slot=76 | P[-1],
#  S[398]: size=3, capacity=33, row=12, slot=77 | P[-1],
#  S[399]: size=4, capacity=44, row=12, slot=80 | P[-1],
#  S[400]: size=2, capacity=22, row=12, slot=84 | P[-1],
#  S[401]: size=1, capacity=11, row=12, slot=86 | P[-1],
#  S[402]: size=2, capacity=20, row=12, slot=87 | P[-1],
#  S[403]: size=2, capacity=20, row=12, slot=92 | P[-1],
#  S[404]: size=5, capacity=50, row=13, slot=0 | P[-1],
#  S[405]: size=4, capacity=40, row=12, slot=96 | P[-1],
#  S[406]: size=1, capacity=10, row=12, slot=90 | P[-1],
#  S[407]: size=4, capacity=40, row=13, slot=5 | P[-1],
#  S[408]: size=2, capacity=20, row=13, slot=9 | P[-1],
#  S[409]: size=1, capacity=10, row=12, slot=94 | P[-1],
#  S[410]: size=1, capacity=10, row=13, slot=11 | P[-1],
#  S[411]: size=4, capacity=40, row=13, slot=12 | P[-1],
#  S[412]: size=3, capacity=30, row=13, slot=16 | P[-1],
#  S[413]: size=1, capacity=10, row=13, slot=19 | P[-1],
#  S[414]: size=5, capacity=50, row=13, slot=20 | P[-1],
#  S[415]: size=2, capacity=20, row=13, slot=25 | P[-1],
#  S[416]: size=5, capacity=50, row=13, slot=28 | P[-1],
#  S[417]: size=3, capacity=30, row=13, slot=33 | P[-1],
#  S[418]: size=4, capacity=40, row=13, slot=36 | P[-1],
#  S[419]: size=5, capacity=50, row=13, slot=40 | P[-1],
#  S[420]: size=1, capacity=10, row=13, slot=45 | P[-1],
#  S[421]: size=5, capacity=50, row=13, slot=49 | P[-1],
#  S[422]: size=3, capacity=30, row=13, slot=56 | P[-1],
#  S[423]: size=2, capacity=20, row=13, slot=46 | P[-1],
#  S[424]: size=4, capacity=40, row=13, slot=59 | P[-1],
#  S[425]: size=3, capacity=30, row=13, slot=63 | P[-1],
#  S[426]: size=1, capacity=10, row=13, slot=54 | P[-1],
#  S[427]: size=5, capacity=50, row=13, slot=66 | P[-1],
#  S[428]: size=2, capacity=20, row=13, slot=71 | P[-1],
#  S[429]: size=2, capacity=20, row=13, slot=73 | P[-1],
#  S[430]: size=1, capacity=10, row=13, slot=75 | P[-1],
#  S[431]: size=2, capacity=20, row=13, slot=76 | P[-1],
#  S[432]: size=4, capacity=40, row=13, slot=79 | P[-1],
#  S[433]: size=5, capacity=50, row=13, slot=83 | P[-1],
#  S[434]: size=3, capacity=30, row=13, slot=88 | P[-1],
#  S[435]: size=5, capacity=50, row=13, slot=91 | P[-1],
#  S[436]: size=3, capacity=30, row=13, slot=96 | P[-1],
#  S[437]: size=3, capacity=27, row=14, slot=3 | P[-1],
#  S[438]: size=5, capacity=45, row=14, slot=6 | P[-1],
#  S[439]: size=5, capacity=45, row=14, slot=11 | P[-1],
#  S[440]: size=3, capacity=27, row=14, slot=16 | P[-1],
#  S[441]: size=5, capacity=45, row=14, slot=19 | P[-1],
#  S[442]: size=2, capacity=18, row=14, slot=0 | P[-1],
#  S[443]: size=3, capacity=27, row=14, slot=24 | P[-1],
#  S[444]: size=1, capacity=9, row=13, slot=99 | P[-1],
#  S[445]: size=3, capacity=27, row=14, slot=28 | P[-1],
#  S[446]: size=2, capacity=18, row=14, slot=31 | P[-1],
#  S[447]: size=4, capacity=36, row=14, slot=33 | P[-1],
#  S[448]: size=2, capacity=18, row=14, slot=37 | P[-1],
#  S[449]: size=5, capacity=45, row=14, slot=39 | P[-1],
#  S[450]: size=1, capacity=9, row=14, slot=44 | P[-1],
#  S[451]: size=5, capacity=45, row=14, slot=45 | P[-1],
#  S[452]: size=4, capacity=36, row=14, slot=50 | P[-1],
#  S[453]: size=2, capacity=18, row=14, slot=54 | P[-1],
#  S[454]: size=3, capacity=27, row=14, slot=56 | P[-1],
#  S[455]: size=3, capacity=27, row=14, slot=59 | P[-1],
#  S[456]: size=4, capacity=36, row=14, slot=64 | P[-1],
#  S[457]: size=3, capacity=27, row=14, slot=68 | P[-1],
#  S[458]: size=5, capacity=45, row=14, slot=71 | P[-1],
#  S[459]: size=5, capacity=45, row=14, slot=76 | P[-1],
#  S[460]: size=4, capacity=36, row=14, slot=81 | P[-1],
#  S[461]: size=3, capacity=27, row=14, slot=85 | P[-1],
#  S[462]: size=3, capacity=27, row=14, slot=88 | P[-1],
#  S[463]: size=4, capacity=36, row=14, slot=91 | P[-1],
#  S[464]: size=5, capacity=45, row=15, slot=0 | P[-1],
#  S[465]: size=1, capacity=9, row=14, slot=62 | P[-1],
#  S[466]: size=5, capacity=45, row=15, slot=9 | P[-1],
#  S[467]: size=5, capacity=45, row=15, slot=14 | P[-1],
#  S[468]: size=1, capacity=9, row=14, slot=95 | P[-1],
#  S[469]: size=5, capacity=45, row=15, slot=19 | P[-1],
#  S[470]: size=1, capacity=9, row=14, slot=96 | P[-1],
#  S[471]: size=3, capacity=27, row=15, slot=5 | P[-1],
#  S[472]: size=3, capacity=27, row=15, slot=24 | P[-1],
#  S[473]: size=2, capacity=18, row=15, slot=27 | P[-1],
#  S[474]: size=4, capacity=32, row=15, slot=32 | P[-1],
#  S[475]: size=3, capacity=24, row=15, slot=36 | P[-1],
#  S[476]: size=4, capacity=32, row=15, slot=39 | P[-1],
#  S[477]: size=1, capacity=8, row=14, slot=97 | P[-1],
#  S[478]: size=4, capacity=32, row=15, slot=43 | P[-1],
#  S[479]: size=2, capacity=16, row=15, slot=29 | P[-1],
#  S[480]: size=2, capacity=16, row=15, slot=47 | P[-1],
#  S[481]: size=4, capacity=32, row=15, slot=49 | P[-1],
#  S[482]: size=5, capacity=40, row=15, slot=57 | P[-1],
#  S[483]: size=4, capacity=32, row=15, slot=62 | P[-1],
#  S[484]: size=2, capacity=16, row=15, slot=53 | P[-1],
#  S[485]: size=5, capacity=40, row=15, slot=66 | P[-1],
#  S[486]: size=2, capacity=16, row=15, slot=71 | P[-1],
#  S[487]: size=1, capacity=8, row=14, slot=99 | P[-1],
#  S[488]: size=4, capacity=32, row=15, slot=73 | P[-1],
#  S[489]: size=1, capacity=8, row=15, slot=55 | P[-1],
#  S[490]: size=2, capacity=16, row=15, slot=77 | P[-1],
#  S[491]: size=1, capacity=8, row=15, slot=79 | P[-1],
#  S[492]: size=4, capacity=32, row=15, slot=84 | P[-1],
#  S[493]: size=2, capacity=16, row=15, slot=80 | P[-1],
#  S[494]: size=1, capacity=8, row=15, slot=82 | P[-1],
#  S[495]: size=1, capacity=8, row=15, slot=88 | P[-1],
#  S[496]: size=1, capacity=8, row=15, slot=89 | P[-1],
#  S[497]: size=5, capacity=40, row=15, slot=90 | P[-1],
#  S[498]: size=2, capacity=16, row=15, slot=95 | P[-1],
#  S[499]: size=3, capacity=24, row=15, slot=97 | P[-1]]

# %%
def initialize_population(population_size, M, P):
    return [np.random.randint(0, P, size=M) for _ in range(population_size)]

def score_population(population, capacities, rows, M, P, R):
    return [fitness(candidate, capacities, rows, M, P, R) for candidate in population]

def selection(population, scores, retain_frac=0.8, retain_random=0.05):
    retain_len = int(len(scores) * retain_frac)
    sorted_indices = np.argsort(scores)[::-1]
    population = [population[idx] for idx in sorted_indices]
    selected = population[:retain_len]
    leftovers = population[retain_len:]

    for gene in leftovers:
        if np.random.rand() < retain_random:
            selected.append(gene)
    return selected

def mutate(candidate, M, P, mutate_frac=0.1):
    frac = int(M * mutate_frac)
    if frac == 0:
        return
    n_tries = np.random.randint(0, int(len(candidate) * mutate_frac))

    idxs = np.random.randint(0, len(candidate), size=n_tries)
    pools = np.random.randint(0, P, size=n_tries)
    for i in range(n_tries):
        candidate[idxs[i]] = pools[i]

def crossover(mom, dad):
    select_mask = np.random.binomial(1, 0.5, size=len(mom)).astype('bool')
    child1, child2 = np.copy(mom), np.copy(dad)
    child1[select_mask] = dad[select_mask]
    child2[select_mask] = mom[select_mask]
    return child1, child2

def evolve(population, capacities, rows, M, P, R, retain_frac=0.8, retain_random=0.05, mutate_chance=0.05):
    """
    Evolution step
    :param population: list or candidate solutions
    :param target: 20x20 array that represents field in stopping condition
    :param delta: number of steps to revert
    :param retain_frac: percent of top individuals to proceed into the next genetation
    :param retain_random: chance of retaining sub-optimal individual
    :param mutate_chance: chance of mutating the particular individual
    :return: new generation of the same size
    """
    scores = score_population(population, capacities, rows, M, P, R)
    next_population = selection(population, scores, retain_frac=retain_frac, retain_random=retain_random)
    
    # mutate everyone expecting for the best candidate
    for gene in next_population[1:]:
        if np.random.random() < mutate_chance:
            mutate(gene, M, P)

    places_left = len(population) - len(next_population)
    children = []
    parent_max_idx = len(next_population) - 1
    while len(children) < places_left:
        mom_idx, dad_idx = np.random.randint(0, parent_max_idx, 2)
        if mom_idx != dad_idx:
            child1, child2 = crossover(next_population[mom_idx], next_population[dad_idx])
            children.append(child1)
            if len(children) < places_left:
                children.append(child2)
    next_population.extend(children)
    return next_population

def solve(servers, capacities, rows, M, P, R, population_size=10, n_generations=100):
    population = initialize_population(population_size, M, P)
    for generation in range(n_generations):
        population = evolve(population, capacities, rows, M, P, R)
        if generation == 0:
            print("Generation #: best score")
        elif generation % 200 == 0:
            print("Generation ", generation, ": ", fitness(population[0], capacities, rows, M, P, R))
    return population[0]

# %%
# %%cython -a
# import numpy as np
# cimport numpy as np
# from Server import Server
#
# cpdef int fitness(np.ndarray[long, ndim=1] pools, np.ndarray[long, ndim=1] capacities, np.ndarray[long, ndim=1] rows, int M, int P, int R):
#     cdef:
#         int least_gc = 1000
#         np.int32_t i, j, gci, cap, r, strike_cap
#     for i in range(P):
#         gci = 1000
#         cap = 0
#         for j in range(M):
#             if pools[j] == i:
#                 cap += capacities[j]
#         for r in range(R):
#             strike_cap = 0
#             for j in range(M):
#                 if pools[j] == i and rows[j] == r:
#                     strike_cap += capacities[j]
#             if gci > (cap - strike_cap):
#                 gci = cap - strike_cap
#         if gci < least_gc:
#             least_gc = gci
#     return least_gc
# Out:
# <!DOCTYPE html>
# <!-- Generated by Cython 0.29.5 -->
# <html>
# <head>
#     <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
#     <title>Cython: _cython_magic_92af825805cef89fe57febb63bbc33c2.pyx</title>
#     <style type="text/css">
#
# body.cython { font-family: courier; font-size: 12; }
#
# .cython.tag  {  }
# .cython.line { margin: 0em }
# .cython.code { font-size: 9; color: #444444; display: none; margin: 0px 0px 0px 8px; border-left: 8px none; }
#
# .cython.line .run { background-color: #B0FFB0; }
# .cython.line .mis { background-color: #FFB0B0; }
# .cython.code.run  { border-left: 8px solid #B0FFB0; }
# .cython.code.mis  { border-left: 8px solid #FFB0B0; }
#
# .cython.code .py_c_api  { color: red; }
# .cython.code .py_macro_api  { color: #FF7000; }
# .cython.code .pyx_c_api  { color: #FF3000; }
# .cython.code .pyx_macro_api  { color: #FF7000; }
# .cython.code .refnanny  { color: #FFA000; }
# .cython.code .trace  { color: #FFA000; }
# .cython.code .error_goto  { color: #FFA000; }
#
# .cython.code .coerce  { color: #008000; border: 1px dotted #008000 }
# .cython.code .py_attr { color: #FF0000; font-weight: bold; }
# .cython.code .c_attr  { color: #0000FF; }
# .cython.code .py_call { color: #FF0000; font-weight: bold; }
# .cython.code .c_call  { color: #0000FF; }
#
# .cython.score-0 {background-color: #FFFFff;}
# .cython.score-1 {background-color: #FFFFe7;}
# .cython.score-2 {background-color: #FFFFd4;}
# .cython.score-3 {background-color: #FFFFc4;}
# .cython.score-4 {background-color: #FFFFb6;}
# .cython.score-5 {background-color: #FFFFaa;}
# .cython.score-6 {background-color: #FFFF9f;}
# .cython.score-7 {background-color: #FFFF96;}
# .cython.score-8 {background-color: #FFFF8d;}
# .cython.score-9 {background-color: #FFFF86;}
# .cython.score-10 {background-color: #FFFF7f;}
# .cython.score-11 {background-color: #FFFF79;}
# .cython.score-12 {background-color: #FFFF73;}
# .cython.score-13 {background-color: #FFFF6e;}
# .cython.score-14 {background-color: #FFFF6a;}
# .cython.score-15 {background-color: #FFFF66;}
# .cython.score-16 {background-color: #FFFF62;}
# .cython.score-17 {background-color: #FFFF5e;}
# .cython.score-18 {background-color: #FFFF5b;}
# .cython.score-19 {background-color: #FFFF57;}
# .cython.score-20 {background-color: #FFFF55;}
# .cython.score-21 {background-color: #FFFF52;}
# .cython.score-22 {background-color: #FFFF4f;}
# .cython.score-23 {background-color: #FFFF4d;}
# .cython.score-24 {background-color: #FFFF4b;}
# .cython.score-25 {background-color: #FFFF48;}
# .cython.score-26 {background-color: #FFFF46;}
# .cython.score-27 {background-color: #FFFF44;}
# .cython.score-28 {background-color: #FFFF43;}
# .cython.score-29 {background-color: #FFFF41;}
# .cython.score-30 {background-color: #FFFF3f;}
# .cython.score-31 {background-color: #FFFF3e;}
# .cython.score-32 {background-color: #FFFF3c;}
# .cython.score-33 {background-color: #FFFF3b;}
# .cython.score-34 {background-color: #FFFF39;}
# .cython.score-35 {background-color: #FFFF38;}
# .cython.score-36 {background-color: #FFFF37;}
# .cython.score-37 {background-color: #FFFF36;}
# .cython.score-38 {background-color: #FFFF35;}
# .cython.score-39 {background-color: #FFFF34;}
# .cython.score-40 {background-color: #FFFF33;}
# .cython.score-41 {background-color: #FFFF32;}
# .cython.score-42 {background-color: #FFFF31;}
# .cython.score-43 {background-color: #FFFF30;}
# .cython.score-44 {background-color: #FFFF2f;}
# .cython.score-45 {background-color: #FFFF2e;}
# .cython.score-46 {background-color: #FFFF2d;}
# .cython.score-47 {background-color: #FFFF2c;}
# .cython.score-48 {background-color: #FFFF2b;}
# .cython.score-49 {background-color: #FFFF2b;}
# .cython.score-50 {background-color: #FFFF2a;}
# .cython.score-51 {background-color: #FFFF29;}
# .cython.score-52 {background-color: #FFFF29;}
# .cython.score-53 {background-color: #FFFF28;}
# .cython.score-54 {background-color: #FFFF27;}
# .cython.score-55 {background-color: #FFFF27;}
# .cython.score-56 {background-color: #FFFF26;}
# .cython.score-57 {background-color: #FFFF26;}
# .cython.score-58 {background-color: #FFFF25;}
# .cython.score-59 {background-color: #FFFF24;}
# .cython.score-60 {background-color: #FFFF24;}
# .cython.score-61 {background-color: #FFFF23;}
# .cython.score-62 {background-color: #FFFF23;}
# .cython.score-63 {background-color: #FFFF22;}
# .cython.score-64 {background-color: #FFFF22;}
# .cython.score-65 {background-color: #FFFF22;}
# .cython.score-66 {background-color: #FFFF21;}
# .cython.score-67 {background-color: #FFFF21;}
# .cython.score-68 {background-color: #FFFF20;}
# .cython.score-69 {background-color: #FFFF20;}
# .cython.score-70 {background-color: #FFFF1f;}
# .cython.score-71 {background-color: #FFFF1f;}
# .cython.score-72 {background-color: #FFFF1f;}
# .cython.score-73 {background-color: #FFFF1e;}
# .cython.score-74 {background-color: #FFFF1e;}
# .cython.score-75 {background-color: #FFFF1e;}
# .cython.score-76 {background-color: #FFFF1d;}
# .cython.score-77 {background-color: #FFFF1d;}
# .cython.score-78 {background-color: #FFFF1c;}
# .cython.score-79 {background-color: #FFFF1c;}
# .cython.score-80 {background-color: #FFFF1c;}
# .cython.score-81 {background-color: #FFFF1c;}
# .cython.score-82 {background-color: #FFFF1b;}
# .cython.score-83 {background-color: #FFFF1b;}
# .cython.score-84 {background-color: #FFFF1b;}
# .cython.score-85 {background-color: #FFFF1a;}
# .cython.score-86 {background-color: #FFFF1a;}
# .cython.score-87 {background-color: #FFFF1a;}
# .cython.score-88 {background-color: #FFFF1a;}
# .cython.score-89 {background-color: #FFFF19;}
# .cython.score-90 {background-color: #FFFF19;}
# .cython.score-91 {background-color: #FFFF19;}
# .cython.score-92 {background-color: #FFFF19;}
# .cython.score-93 {background-color: #FFFF18;}
# .cython.score-94 {background-color: #FFFF18;}
# .cython.score-95 {background-color: #FFFF18;}
# .cython.score-96 {background-color: #FFFF18;}
# .cython.score-97 {background-color: #FFFF17;}
# .cython.score-98 {background-color: #FFFF17;}
# .cython.score-99 {background-color: #FFFF17;}
# .cython.score-100 {background-color: #FFFF17;}
# .cython.score-101 {background-color: #FFFF16;}
# .cython.score-102 {background-color: #FFFF16;}
# .cython.score-103 {background-color: #FFFF16;}
# .cython.score-104 {background-color: #FFFF16;}
# .cython.score-105 {background-color: #FFFF16;}
# .cython.score-106 {background-color: #FFFF15;}
# .cython.score-107 {background-color: #FFFF15;}
# .cython.score-108 {background-color: #FFFF15;}
# .cython.score-109 {background-color: #FFFF15;}
# .cython.score-110 {background-color: #FFFF15;}
# .cython.score-111 {background-color: #FFFF15;}
# .cython.score-112 {background-color: #FFFF14;}
# .cython.score-113 {background-color: #FFFF14;}
# .cython.score-114 {background-color: #FFFF14;}
# .cython.score-115 {background-color: #FFFF14;}
# .cython.score-116 {background-color: #FFFF14;}
# .cython.score-117 {background-color: #FFFF14;}
# .cython.score-118 {background-color: #FFFF13;}
# .cython.score-119 {background-color: #FFFF13;}
# .cython.score-120 {background-color: #FFFF13;}
# .cython.score-121 {background-color: #FFFF13;}
# .cython.score-122 {background-color: #FFFF13;}
# .cython.score-123 {background-color: #FFFF13;}
# .cython.score-124 {background-color: #FFFF13;}
# .cython.score-125 {background-color: #FFFF12;}
# .cython.score-126 {background-color: #FFFF12;}
# .cython.score-127 {background-color: #FFFF12;}
# .cython.score-128 {background-color: #FFFF12;}
# .cython.score-129 {background-color: #FFFF12;}
# .cython.score-130 {background-color: #FFFF12;}
# .cython.score-131 {background-color: #FFFF12;}
# .cython.score-132 {background-color: #FFFF11;}
# .cython.score-133 {background-color: #FFFF11;}
# .cython.score-134 {background-color: #FFFF11;}
# .cython.score-135 {background-color: #FFFF11;}
# .cython.score-136 {background-color: #FFFF11;}
# .cython.score-137 {background-color: #FFFF11;}
# .cython.score-138 {background-color: #FFFF11;}
# .cython.score-139 {background-color: #FFFF11;}
# .cython.score-140 {background-color: #FFFF11;}
# .cython.score-141 {background-color: #FFFF10;}
# .cython.score-142 {background-color: #FFFF10;}
# .cython.score-143 {background-color: #FFFF10;}
# .cython.score-144 {background-color: #FFFF10;}
# .cython.score-145 {background-color

# %%
servs = [serv.copy() for serv in servers]
capacities = np.array([int(serv.capacity) for serv in servers])
rows = np.array([serv.row for serv in servers])

# %%
result = solve(servs, capacities, rows, len(servers), P, R, n_generations=30000)
# Out:
# Generation #: best score
# Generation  200 :  255
# Generation  400 :  255
# Generation  600 :  255
# Generation  800 :  255
# Generation  1000 :  255
# Generation  1200 :  259
# Generation  1400 :  259
# Generation  1600 :  266
# Generation  1800 :  285
# Generation  2000 :  287
# Generation  2200 :  287
# Generation  2400 :  287
# Generation  2600 :  292
# Generation  2800 :  292
# Generation  3000 :  292
# Generation  3200 :  292
# Generation  3400 :  293
# Generation  3600 :  293
# Generation  3800 :  293
# Generation  4000 :  296
# Generation  4200 :  296
# Generation  4400 :  296
# Generation  4600 :  296
# Generation  4800 :  296
# Generation  5000 :  296
# Generation  5200 :  296
# Generation  5400 :  296
# Generation  5600 :  296
# Generation  5800 :  296
# Generation  6000 :  296
# Generation  6200 :  296
# Generation  6400 :  296
# Generation  6600 :  296
# Generation  6800 :  296
# Generation  7000 :  296
# Generation  7200 :  296
# Generation  7400 :  296
# Generation  7600 :  296
# Generation  7800 :  296
# Generation  8000 :  296
# Generation  8200 :  296
# Generation  8400 :  296
# Generation  8600 :  298
# Generation  8800 :  298
# Generation  9000 :  298
# Generation  9200 :  298
# Generation  9400 :  298
# Generation  9600 :  299
# Generation  9800 :  299
# Generation  10000 :  299
# Generation  10200 :  299
# Generation  10400 :  299
# Generation  10600 :  301
# Generation  10800 :  301
# Generation  11000 :  301
# Generation  11200 :  301
# Generation  11400 :  301
# Generation  11600 :  303
# Generation  11800 :  303
# Generation  12000 :  304
# Generation  12200 :  304
# Generation  12400 :  304
# Generation  12600 :  304
# Generation  12800 :  306
# Generation  13000 :  306
# Generation  13200 :  306
# Generation  13400 :  306
# Generation  13600 :  306
# Generation  13800 :  308
# Generation  14000 :  308
# Generation  14200 :  308
# Generation  14400 :  308
# Generation  14600 :  309
# Generation  14800 :  309
# Generation  15000 :  309
# Generation  15200 :  309
# Generation  15400 :  310
# Generation  15600 :  310
# Generation  15800 :  310
# Generation  16000 :  311
# Generation  16200 :  311
# Generation  16400 :  311
# Generation  16600 :  311
# Generation  16800 :  311
# Generation  17000 :  311
# Generation  17200 :  311
# Generation  17400 :  311
# Generation  17600 :  311
# Generation  17800 :  312
# Generation  18000 :  312
# Generation  18200 :  312
# Generation  18400 :  312
# Generation  18600 :  312
# Generation  18800 :  312
# Generation  19000 :  312
# Generation  19200 :  312
# Generation  19400 :  312
# Generation  19600 :  312
# Generation  19800 :  312
# Generation  20000 :  312
# Generation  20200 :  312
# Generation  20400 :  312
# Generation  20600 :  312
# Generation  20800 :  312
# Generation  21000 :  312
# Generation  21200 :  312
# Generation  21400 :  312
# Generation  21600 :  312
# Generation  21800 :  314
# Generation  22000 :  314
# Generation  22200 :  314
# Generation  22400 :  314
# Generation  22600 :  317
# Generation  22800 :  317
# Generation  23000 :  317
# Generation  23200 :  317
# Generation  23400 :  317
# Generation  23600 :  318
# Generation  23800 :  318
# Generation  24000 :  318
# Generation  24200 :  318
# Generation  24400 :  318
# Generation  24600 :  318
# Generation  24800 :  318
# Generation  25000 :  318
# Generation  25200 :  318
# Generation  25400 :  318
# Generation  25600 :  318
# Generation  25800 :  318
# Generation  26000 :  318
# Generation  26200 :  318
# Generation  26400 :  318
# Generation  26600 :  318
# Generation  26800 :  318
# Generation  27000 :  318
# Generation  27200 :  318
# Generation  27400 :  318
# Generation  27600 :  318
# Generation  27800 :  318
# Generation  28000 :  318
# Generation  28200 :  318
# Generation  28400 :  318
# Generation  28600 :  318
# Generation  28800 :  318
# Generation  29000 :  318
# Generation  29200 :  318
# Generation  29400 :  318
# Generation  29600 :  318
# Generation  29800 :  318

# %%
result
# Out:
# array([10,  2, 17, 12,  0,  9, 40, 22, 25, 20, 42,  9, 18, 23, 25, 44,  3,
#         8, 20, 30,  8, 23,  4, 13, 31, 39, 23, 24,  5, 21, 36,  4, 27, 39,
#        14, 41, 14, 38, 19, 24, 19, 33, 19, 29, 11, 19, 27, 44, 43, 27, 34,
#        37,  1, 15,  3, 29, 34, 39, 28, 32, 43, 12, 38, 11, 22,  0, 31,  7,
#        32, 19, 15, 22,  1, 40, 12, 21, 35, 15, 20, 38, 26, 36, 43, 36, 36,
#        19, 31, 32,  3,  2, 22,  2,  4, 14, 24,  2, 26, 24, 14,  7, 11, 37,
#        26, 23, 12, 42,  0, 33, 18,  1, 26, 24,  4, 34, 10, 30,  0, 26, 13,
#        29, 25, 40, 32, 40,  4,  5, 43, 40, 23, 23, 15, 33, 17, 13, 30, 35,
#        22, 26, 16, 42, 22, 20, 28,  1,  1,  8, 32, 34, 37, 31,  4, 10, 15,
#        23, 29,  4, 26, 21,  8,  1, 26, 44, 14,  3, 33, 31, 39, 26, 21, 29,
#         3, 26, 11, 44,  1, 18, 27, 13, 30, 18, 19, 16,  9, 26,  6,  1, 36,
#        38, 44,  9, 11, 12, 20, 41, 26,  3,  8, 37,  5,  6,  7, 42, 43,  8,
#        36, 32, 30, 29, 32, 28, 24,  2, 42, 16,  0,  2, 44, 10, 13, 25, 38,
#        12, 17, 39, 35,  5,  2, 27, 21, 36, 20, 22,  3, 19, 23, 15, 13, 21,
#        21, 20, 27, 11, 25, 12, 39, 38, 41, 15, 18, 41,  9, 35, 28, 31, 17,
#        42, 34, 29,  0,  6, 32, 35,  7,  8,  5, 16, 25, 30, 12, 32,  7,  7,
#         9, 43, 30, 11, 13,  7, 18, 37,  7, 17, 10, 34, 21,  5,  0, 38, 37,
#        37, 33, 28, 28, 44, 22, 14, 11, 39,  6,  3, 16,  9, 33, 17,  0, 15,
#        33, 26, 39, 27, 35, 29,  1, 42, 21, 41, 25, 22, 40,  6, 35,  9, 14,
#        31, 18, 19, 40, 40, 36, 36,  1,  8, 20, 24, 17,  7, 18, 35, 34, 10,
#        38, 14, 11, 36, 37,  8, 16,  7, 19, 43,  5, 41, 16, 27, 25,  1,  7,
#        41, 44, 33, 35,  9,  6,  9, 12, 25, 19, 33, 20, 16, 12, 14, 12, 42,
#        17, 37, 24, 19, 12, 20,  6, 29, 32, 27, 21, 14, 26, 34, 32,  7, 23,
#        34,  2, 44, 33, 15,  1, 43, 24, 11,  9,  6,  4, 40,  8,  9, 15, 28,
#        33, 28,  2, 18, 44, 32, 19, 41, 34, 36, 31, 28,  8, 27,  4, 42, 10,
#        31, 15, 42, 44, 32, 41, 38, 23, 18, 10, 15, 20,  9, 43, 30, 34, 14,
#        39, 43,  6, 12, 25, 24, 15, 34,  8, 39, 10, 30, 24, 18,  7, 24,  6,
#        23,  3, 33, 13, 38, 43, 10, 26, 16, 11, 27, 19,  5, 36, 25, 34,  6,
#        44, 30, 41, 28, 37,  4, 20,  5, 44, 38,  2, 16, 38, 30, 16, 29, 29,
#        13, 32,  2,  6, 15,  4, 21])

# %%
servers
# Out:
# [S[0]: size=2, capacity=40, row=0, slot=0 | P[-1],
#  S[1]: size=2, capacity=40, row=0, slot=2 | P[-1],
#  S[2]: size=3, capacity=60, row=0, slot=4 | P[-1],
#  S[3]: size=2, capacity=40, row=0, slot=7 | P[-1],
#  S[4]: size=4, capacity=80, row=0, slot=11 | P[-1],
#  S[5]: size=1, capacity=20, row=0, slot=9 | P[-1],
#  S[6]: size=5, capacity=100, row=0, slot=15 | P[-1],
#  S[7]: size=3, capacity=60, row=0, slot=20 | P[-1],
#  S[8]: size=2, capacity=40, row=0, slot=23 | P[-1],
#  S[9]: size=3, capacity=60, row=0, slot=25 | P[-1],
#  S[10]: size=5, capacity=100, row=0, slot=28 | P[-1],
#  S[11]: size=2, capacity=40, row=0, slot=33 | P[-1],
#  S[12]: size=3, capacity=60, row=0, slot=35 | P[-1],
#  S[13]: size=1, capacity=20, row=0, slot=38 | P[-1],
#  S[14]: size=1, capacity=20, row=0, slot=39 | P[-1],
#  S[15]: size=3, capacity=60, row=0, slot=43 | P[-1],
#  S[16]: size=3, capacity=60, row=0, slot=48 | P[-1],
#  S[17]: size=4, capacity=80, row=0, slot=52 | P[-1],
#  S[18]: size=4, capacity=80, row=0, slot=56 | P[-1],
#  S[19]: size=4, capacity=80, row=0, slot=60 | P[-1],
#  S[20]: size=2, capacity=40, row=0, slot=64 | P[-1],
#  S[21]: size=1, capacity=20, row=0, slot=41 | P[-1],
#  S[22]: size=2, capacity=40, row=0, slot=66 | P[-1],
#  S[23]: size=5, capacity=100, row=0, slot=68 | P[-1],
#  S[24]: size=4, capacity=80, row=0, slot=74 | P[-1],
#  S[25]: size=3, capacity=60, row=0, slot=78 | P[-1],
#  S[26]: size=3, capacity=60, row=0, slot=81 | P[-1],
#  S[27]: size=1, capacity=20, row=0, slot=46 | P[-1],
#  S[28]: size=5, capacity=100, row=0, slot=84 | P[-1],
#  S[29]: size=5, capacity=100, row=0, slot=89 | P[-1],
#  S[30]: size=3, capacity=60, row=0, slot=94 | P[-1],
#  S[31]: size=2, capacity=40, row=0, slot=97 | P[-1],
#  S[32]: size=1, capacity=20, row=0, slot=99 | P[-1],
#  S[33]: size=1, capacity=20, row=1, slot=0 | P[-1],
#  S[34]: size=5, capacity=100, row=1, slot=1 | P[-1],
#  S[35]: size=4, capacity=80, row=1, slot=6 | P[-1],
#  S[36]: size=3, capacity=60, row=1, slot=10 | P[-1],
#  S[37]: size=3, capacity=60, row=1, slot=13 | P[-1],
#  S[38]: size=3, capacity=60, row=1, slot=16 | P[-1],
#  S[39]: size=3, capacity=60, row=1, slot=19 | P[-1],
#  S[40]: size=2, capacity=40, row=1, slot=22 | P[-1],
#  S[41]: size=3, capacity=60, row=1, slot=24 | P[-1],
#  S[42]: size=2, capacity=40, row=1, slot=28 | P[-1],
#  S[43]: size=5, capacity=95, row=1, slot=30 | P[-1],
#  S[44]: size=1, capacity=19, row=1, slot=35 | P[-1],
#  S[45]: size=5, capacity=95, row=1, slot=40 | P[-1],
#  S[46]: size=1, capacity=19, row=1, slot=36 | P[-1],
#  S[47]: size=1, capacity=19, row=1, slot=37 | P[-1],
#  S[48]: size=1, capacity=19, row=1, slot=38 | P[-1],
#  S[49]: size=5, capacity=95, row=1, slot=49 | P[-1],
#  S[50]: size=5, capacity=95, row=1, slot=55 | P[-1],
#  S[51]: size=5, capacity=95, row=1, slot=62 | P[-1],
#  S[52]: size=4, capacity=76, row=1, slot=67 | P[-1],
#  S[53]: size=5, capacity=95, row=1, slot=71 | P[-1],
#  S[54]: size=3, capacity=57, row=1, slot=45 | P[-1],
#  S[55]: size=1, capacity=19, row=1, slot=60 | P[-1],
#  S[56]: size=4, capacity=76, row=1, slot=76 | P[-1],
#  S[57]: size=2, capacity=38, row=1, slot=80 | P[-1],
#  S[58]: size=3, capacity=57, row=1, slot=82 | P[-1],
#  S[59]: size=4, capacity=76, row=1, slot=85 | P[-1],
#  S[60]: size=5, capacity=95, row=1, slot=89 | P[-1],
#  S[61]: size=3, capacity=57, row=1, slot=94 | P[-1],
#  S[62]: size=1, capacity=19, row=1, slot=97 | P[-1],
#  S[63]: size=1, capacity=19, row=1, slot=98 | P[-1],
#  S[64]: size=1, capacity=19, row=1, slot=99 | P[-1],
#  S[65]: size=5, capacity=95, row=2, slot=0 | P[-1],
#  S[66]: size=3, capacity=57, row=2, slot=5 | P[-1],
#  S[67]: size=4, capacity=76, row=2, slot=8 | P[-1],
#  S[68]: size=4, capacity=76, row=2, slot=12 | P[-1],
#  S[69]: size=5, capacity=90, row=2, slot=16 | P[-1],
#  S[70]: size=2, capacity=36, row=2, slot=21 | P[-1],
#  S[71]: size=5, capacity=90, row=2, slot=23 | P[-1],
#  S[72]: size=1, capacity=18, row=2, slot=28 | P[-1],
#  S[73]: size=1, capacity=18, row=2, slot=29 | P[-1],
#  S[74]: size=5, capacity=90, row=2, slot=30 | P[-1],
#  S[75]: size=3, capacity=54, row=2, slot=35 | P[-1],
#  S[76]: size=5, capacity=90, row=2, slot=38 | P[-1],
#  S[77]: size=1, capacity=18, row=2, slot=43 | P[-1],
#  S[78]: size=2, capacity=36, row=2, slot=44 | P[-1],
#  S[79]: size=3, capacity=54, row=2, slot=49 | P[-1],
#  S[80]: size=3, capacity=54, row=2, slot=52 | P[-1],
#  S[81]: size=4, capacity=72, row=2, slot=55 | P[-1],
#  S[82]: size=4, capacity=72, row=2, slot=62 | P[-1],
#  S[83]: size=1, capacity=18, row=2, slot=46 | P[-1],
#  S[84]: size=4, capacity=72, row=2, slot=66 | P[-1],
#  S[85]: size=2, capacity=36, row=2, slot=59 | P[-1],
#  S[86]: size=5, capacity=90, row=2, slot=74 | P[-1],
#  S[87]: size=1, capacity=18, row=2, slot=47 | P[-1],
#  S[88]: size=1, capacity=18, row=2, slot=70 | P[-1],
#  S[89]: size=3, capacity=54, row=2, slot=79 | P[-1],
#  S[90]: size=3, capacity=54, row=2, slot=82 | P[-1],
#  S[91]: size=5, capacity=90, row=2, slot=85 | P[-1],
#  S[92]: size=5, capacity=90, row=2, slot=90 | P[-1],
#  S[93]: size=5, capacity=90, row=2, slot=95 | P[-1],
#  S[94]: size=1, capacity=18, row=2, slot=71 | P[-1],
#  S[95]: size=5, capacity=90, row=3, slot=0 | P[-1],
#  S[96]: size=5, capacity=90, row=3, slot=5 | P[-1],
#  S[97]: size=4, capacity=72, row=3, slot=10 | P[-1],
#  S[98]: size=4, capacity=72, row=3, slot=14 | P[-1],
#  S[99]: size=1, capacity=18, row=2, slot=72 | P[-1],
#  S[100]: size=5, capacity=90, row=3, slot=19 | P[-1],
#  S[101]: size=2, capacity=36, row=3, slot=24 | P[-1],
#  S[102]: size=3, capacity=54, row=3, slot=26 | P[-1],
#  S[103]: size=1, capacity=18, row=3, slot=29 | P[-1],
#  S[104]: size=1, capacity=18, row=3, slot=30 | P[-1],
#  S[105]: size=2, capacity=36, row=3, slot=31 | P[-1],
#  S[106]: size=1, capacity=18, row=3, slot=33 | P[-1],
#  S[107]: size=5, capacity=90, row=3, slot=38 | P[-1],
#  S[108]: size=5, capacity=90, row=3, slot=43 | P[-1],
#  S[109]: size=1, capacity=18, row=3, slot=34 | P[-1],
#  S[110]: size=3, capacity=54, row=3, slot=53 | P[-1],
#  S[111]: size=1, capacity=18, row=3, slot=36 | P[-1],
#  S[112]: size=5, capacity=90, row=3, slot=58 | P[-1],
#  S[113]: size=5, capacity=90, row=3, slot=67 | P[-1],
#  S[114]: size=4, capacity=72, row=3, slot=73 | P[-1],
#  S[115]: size=4, capacity=72, row=3, slot=77 | P[-1],
#  S[116]: size=4, capacity=72, row=3, slot=81 | P[-1],
#  S[117]: size=1, capacity=18, row=3, slot=48 | P[-1],
#  S[118]: size=4, capacity=68, row=3, slot=85 | P[-1],
#  S[119]: size=1, capacity=17, row=3, slot=50 | P[-1],
#  S[120]: size=3, capacity=51, row=3, slot=89 | P[-1],
#  S[121]: size=4, capacity=68, row=3, slot=95 | P[-1],
#  S[122]: size=4, capacity=68, row=4, slot=0 | P[-1],
#  S[123]: size=5, capacity=85, row=4, slot=4 | P[-1],
#  S[124]: size=1, capacity=17, row=3, slot=51 | P[-1],
#  S[125]: size=5, capacity=85, row=4, slot=9 | P[-1],
#  S[126]: size=5, capacity=85, row=4, slot=14 | P[-1],
#  S[127]: size=5, capacity=85, row=4, slot=29 | P[-1],
#  S[128]: size=2, capacity=34, row=3, slot=92 | P[-1],
#  S[129]: size=2, capacity=34, row=4, slot=19 | P[-1],
#  S[130]: size=5, capacity=85, row=4, slot=34 | P[-1],
#  S[131]: size=1, capacity=17, row=3, slot=56 | P[-1],
#  S[132]: size=4, capacity=68, row=4, slot=45 | P[-1],
#  S[133]: size=2, capacity=34, row=4, slot=21 | P[-1],
#  S[134]: size=2, capacity=34, row=4, slot=24 | P[-1],
#  S[135]: size=5, capacity=85, row=4, slot=49 | P[-1],
#  S[136]: size=1, capacity=17, row=3, slot=63 | P[-1],
#  S[137]: size=4, capacity=68, row=4, slot=54 | P[-1],
#  S[138]: size=5, capacity=85, row=4, slot=58 | P[-1],
#  S[139]: size=2, capacity=34, row=4, slot=41 | P[-1],
#  S[140]: size=4, capacity=68, row=4, slot=64 | P[-1],
#  S[141]: size=2, capacity=34, row=4, slot=68 | P[-1],
#  S[142]: size=4, capacity=68, row=4, slot=70 | P[-1],
#  S[143]: size=3, capacity=51, row=4, slot=74 | P[-1],
#  S[144]: size=1, capacity=17, row=3, slot=65 | P[-1],
#  S[145]: size=3, capacity=51, row=4, slot=77 | P[-1],
#  S[146]: size=1, capacity=17, row=3, slot=99 | P[-1],
#  S[147]: size=4, capacity=68, row=4, slot=80 | P[-1],
#  S[148]: size=4, capacity=68, row=4, slot=84 | P[-1],
#  S[149]: size=4, capacity=68, row=4, slot=88 | P[-1],
#  S[150]: size=2, capacity=34, row=4, slot=92 | P[-1],
#  S[151]: size=1, capacity=17, row=4, slot=26 | P[-1],
#  S[152]: size=3, capacity=51, row=4, slot=94 | P[-1],
#  S[153]: size=3, capacity=51, row=4, slot=97 | P[-1],
#  S[154]: size=3, capacity=51, row=5, slot=0 | P[-1],
#  S[155]: size=2, capacity=34, row=5, slot=5 | P[-1],
#  S[156]: size=4, capacity=68, row=5, slot=7 | P[-1],
#  S[157]: size=3, capacity=48, row=5, slot=11 | P[-1],
#  S[158]: size=4, capacity=64, row=5, slot=14 | P[-1],
#  S[159]: size=2, capacity=32, row=5, slot=18 | P[-1],
#  S[160]: size=3, capacity=48, row=5, slot=20 | P[-1],
#  S[161]: size=4, capacity=64, row=5, slot=23 | P[-1],
#  S[162]: size=5, capacity=80, row=5, slot=27 | P[-1],
#  S[163]: size=4, capacity=64, row=5, slot=32 | P[-1],
#  S[164]: size=4, capacity=64, row=5, slot=39 | P[-1],
#  S[165]: size=2, capacity=32, row=5, slot=36 | P[-1],
#  S[166]: size=4, capacity=64, row=5, slot=45 | P[-1],
#  S[167]: size=2, capacity=32, row=5, slot=49 | P[-1],
#  S[168]: size=1, capacity=16, row=4, slot=39 | P[-1],
#  S[169]: size=5, capacity=80, row=5, slot=51 | P[-1],
#  S[170]: size=3, capacity=48, row=5, slot=56 | P[-1],
#  S[171]: size=5, capacity=80, row=5, slot=59 | P[-1],
#  S[172]: size=4, capacity=64, row=5, slot=64 | P[-1],
#  S[173]: size=2, capacity=32, row=5, slot=68 | P[-1],
#  S[174]: size=3, capacity=48, row=5, slot=70 | P[-1],
#  S[175]: size=2, capacity=32, row=5, slot=73 | P[-1],
#  S[176]: size=3, capacity=48, row=5, slot=75 | P[-1],
#  S[177]: size=4, capacity=64, row=5, slot=78 | P[-1],
#  S[178]: size=4, capacity=64, row=5, slot=84 | P[-1],
#  S[179]: size=2, capacity=32, row=5, slot=88 | P[-1],
#  S[180]: size=1, capacity=16, row=4, slot=43 | P[-1],
#  S[181]: size=3, capacity=48, row=5, slot=93 | P[-1],
#  S[182]: size=1, capacity=16, row=5, slot=43 | P[-1],
#  S[183]: size=3, capacity=48, row=5, slot=96 | P[-1],
#  S[184]: size=2, capacity=32, row=5, slot=90 | P[-1],
#  S[185]: size=5, capacity=80, row=6, slot=0 | P[-1],
#  S[186]: size=3, capacity=48, row=6, slot=8 | P[-1],
#  S[187]: size=3, capacity=48, row=6, slot=11 | P[-1],
#  S[188]: size=5, capacity=80, row=6, slot=14 | P[-1],
#  S[189]: size=3, capacity=48, row=6, slot=19 | P[-1],
#  S[190]: size=1, capacity=16, row=5, slot=82 | P[-1],
#  S[191]: size=3, capacity=48, row=6, slot=22 | P[-1],
#  S[192]: size=1, capacity=16, row=5, slot=99 | P[-1],
#  S[193]: size=4, capacity=64, row=6, slot=25 | P[-1],
#  S[194]: size=5, capacity=80, row=6, slot=34 | P[-1],
#  S[195]: size=1, capacity=16, row=6, slot=6 | P[-1],
#  S[196]: size=1, capacity=16, row=6, slot=29 | P[-1],
#  S[197]: size=2, capacity=32, row=6, slot=30 | P[-1],
#  S[198]: size=3, capacity=48, row=6, slot=39 | P[-1],
#  S[199]: size=2, capacity=32, row=6, slot=42 | P[-1],
#  S[200]: size=2, capacity=32, row=6, slot=44 | P[-1],
#  S[201]: size=4, capacity=60, row=6, slot=46 | P[-1],
#  S[202]: size=2, capacity=30, row=6, slot=50 | P[-1],
#  S[203]: size=5, capacity=75, row=6, slot=52 | P[-1],
#  S[204]: size=2, capacity=30, row=6, slot=57 | P[-1],
#  S[205]: size=2, capacity=30, row=6, slot=59 | P[-1],
#  S[206]: size=4, capacity=60, row=6, slot=61 | P[-1],
#  S[207]: size=2, capacity=30, row=6, slot=65 | P[-1],
#  S[208]: size=1, capacity=15, row=6, slot=32 | P[-1],
#  S[209]: size=3, capacity=45, row=6, slot=67 | P[-1],
#  S[210]: size=3, capacity=45, row=6, slot=70 | P[-1],
#  S[211]: size=4, capacity=60, row=6, slot=76 | P[-1],
#  S[212]: size=2, capacity=30, row=6, slot=73 | P[-1],
#  S[213]: size=5, capacity=75, row=6, slot=80 | P[-1],
#  S[214]: size=3, capacity=45, row=6, slot=85 | P[-1],
#  S[215]: size=2, capacity=30, row=6, slot=88 | P[-1],
#  S[216]: size=4, capacity=60, row=6, slot=90 | P[-1],
#  S[217]: size=5, capacity=75, row=6, slot=94 | P[-1],
#  S[218]: size=2, capacity=30, row=7, slot=0 | P[-1],
#  S[219]: size=3, capacity=45, row=7, slot=2 | P[-1],
#  S[220]: size=4, capacity=60, row=7, slot=5 | P[-1],
#  S[221]: size=3, capacity=45, row=7, slot=9 | P[-1],
#  S[222]: size=5, capacity=75, row=7, slot=12 | P[-1],
#  S[223]: size=2, capacity=30, row=7, slot=17 | P[-1],
#  S[224]: size=2, capacity=30, row=7, slot=19 | P[-1],
#  S[225]: size=3, capacity=45, row=7, slot=21 | P[-1],
#  S[226]: size=4, capacity=60, row=7, slot=24 | P[-1],
#  S[227]: size=3, capacity=45, row=7, slot=28 | P[-1],
#  S[228]: size=3, capacity=45, row=7, slot=31 | P[-1],
#  S[229]: size=2, capacity=30, row=7, slot=35 | P[-1],
#  S[230]: size=4, capacity=60, row=7, slot=37 | P[-1],
#  S[231]: size=4, capacity=60, row=7, slot=41 | P[-1],
#  S[232]: size=5, capacity=75, row=7, slot=45 | P[-1],
#  S[233]: size=5, capacity=75, row=7, slot=50 | P[-1],
#  S[234]: size=4, capacity=60, row=7, slot=55 | P[-1],
#  S[235]: size=3, capacity=45, row=7, slot=59 | P[-1],
#  S[236]: size=3, capacity=45, row=7, slot=62 | P[-1],
#  S[237]: size=1, capacity=15, row=6, slot=99 | P[-1],
#  S[238]: size=3, capacity=45, row=7, slot=65 | P[-1],
#  S[239]: size=2, capacity=30, row=7, slot=68 | P[-1],
#  S[240]: size=5, capacity=75, row=7, slot=70 | P[-1],
#  S[241]: size=2, capacity=30, row=7, slot=75 | P[-1],
#  S[242]: size=4, capacity=60, row=7, slot=77 | P[-1],
#  S[243]: size=1, capacity=15, row=7, slot=81 | P[-1],
#  S[244]: size=4, capacity=60, row=7, slot=82 | P[-1],
#  S[245]: size=2, capacity=30, row=7, slot=86 | P[-1],
#  S[246]: size=2, capacity=30, row=7, slot=88 | P[-1],
#  S[247]: size=3, capacity=45, row=7, slot=90 | P[-1],
#  S[248]: size=4, capacity=60, row=7, slot=93 | P[-1],
#  S[249]: size=5, capacity=75, row=8, slot=0 | P[-1],
#  S[250]: size=1, capacity=15, row=7, slot=97 | P[-1],
#  S[251]: size=4, capacity=60, row=8, slot=9 | P[-1],
#  S[252]: size=3, capacity=45, row=8, slot=5 | P[-1],
#  S[253]: size=2, capacity=28, row=7, slot=98 | P[-1],
#  S[254]: size=4, capacity=56, row=8, slot=13 | P[-1],
#  S[255]: size=1, capacity=14, row=8, slot=17 | P[-1],
#  S[256]: size=2, capacity=28, row=8, slot=18 | P[-1],
#  S[257]: size=4, capacity=56, row=8, slot=20 | P[-1],
#  S[258]: size=2, capacity=28, row=8, slot=24 | P[-1],
#  S[259]: size=5, capacity=70, row=8, slot=26 | P[-1],
#  S[260]: size=5, capacity=70, row=8, slot=31 | P[-1],
#  S[261]: size=1, capacity=14, row=8, slot=36 | P[-1],
#  S[262]: size=4, capacity=56, row=8, slot=37 | P[-1],
#  S[263]: size=2, capacity=28, row=8, slot=41 | P[-1],
#  S[264]: size=1, capacity=14, row=8, slot=43 | P[-1],
#  S[265]: size=2, capacity=28, row=8, slot=44 | P[-1],
#  S[266]: size=3, capacity=42, row=8, slot=46 | P[-1],
#  S[267]: size=1, capacity=14, row=8, slot=49 | P[-1],
#  S[268]: size=5, capacity=70, row=8, slot=50 | P[-1],
#  S[269]: size=2, capacity=28, row=8, slot=55 | P[-1],
#  S[270]: size=4, capacity=56, row=8, slot=58 | P[-1],
#  S[271]: size=3, capacity=42, row=8, slot=62 | P[-1],
#  S[272]: size=3, capacity=42, row=8, slot=65 | P[-1],
#  S[273]: size=2, capacity=28, row=8, slot=68 | P[-1],
#  S[274]: size=4, capacity=56, row=8, slot=72 | P[-1],
#  S[275]: size=4, capacity=56, row=8, slot=76 | P[-1],
#  S[276]: size=3, capacity=42, row=8, slot=80 | P[-1],
#  S[277]: size=3, capacity=42, row=8, slot=84 | P[-1],
#  S[278]: size=5, capacity=70, row=8, slot=92 | P[-1],
#  S[279]: size=2, capacity=28, row=8, slot=87 | P[-1],
#  S[280]: size=4, capacity=56, row=9, slot=0 | P[-1],
#  S[281]: size=5, capacity=70, row=9, slot=4 | P[-1],
#  S[282]: size=5, capacity=70, row=9, slot=9 | P[-1],
#  S[283]: size=2, capacity=28, row=8, slot=89 | P[-1],
#  S[284]: size=1, capacity=14, row=8, slot=70 | P[-1],
#  S[285]: size=5, capacity=70, row=9, slot=14 | P[-1],
#  S[286]: size=4, capacity=56, row=9, slot=19 | P[-1],
#  S[287]: size=2, capacity=26, row=9, slot=24 | P[-1],
#  S[288]: size=2, capacity=26, row=9, slot=26 | P[-1],
#  S[289]: size=5, capacity=65, row=9, slot=28 | P[-1],
#  S[290]: size=5, capacity=65, row=9, slot=33 | P[-1],
#  S[291]: size=3, capacity=39, row=9, slot=38 | P[-1],
#  S[292]: size=3, capacity=39, row=9, slot=43 | P[-1],
#  S[293]: size=3, capacity=39, row=9, slot=46 | P[-1],
#  S[294]: size=5, capacity=65, row=9, slot=49 | P[-1],
#  S[295]: size=5, capacity=65, row=9, slot=54 | P[-1],
#  S[296]: size=2, capacity=26, row=9, slot=59 | P[-1],
#  S[297]: size=4, capacity=52, row=9, slot=61 | P[-1],
#  S[298]: size=2, capacity=26, row=9, slot=66 | P[-1],
#  S[299]: size=5, capacity=65, row=9, slot=68 | P[-1],
#  S[300]: size=3, capacity=39, row=9, slot=75 | P[-1],
#  S[301]: size=1, capacity=13, row=8, slot=97 | P[-1],
#  S[302]: size=1, capacity=13, row=8, slot=99 | P[-1],
#  S[303]: size=2, capacity=26, row=9, slot=78 | P[-1],
#  S[304]: size=4, capacity=52, row=9, slot=80 | P[-1],
#  S[305]: size=2, capacity=26, row=9, slot=84 | P[-1],
#  S[306]: size=3, capacity=39, row=9, slot=86 | P[-1],
#  S[307]: size=2, capacity=26, row=9, slot=90 | P[-1],
#  S[308]: size=5, capacity=65, row=9, slot=92 | P[-1],
#  S[309]: size=1, capacity=13, row=9, slot=41 | P[-1],
#  S[310]: size=2, capacity=26, row=9, slot=97 | P[-1],
#  S[311]: size=3, capacity=39, row=10, slot=0 | P[-1],
#  S[312]: size=1, capacity=13, row=9, slot=73 | P[-1],
#  S[313]: size=5, capacity=65, row=10, slot=3 | P[-1],
#  S[314]: size=5, capacity=65, row=10, slot=8 | P[-1],
#  S[315]: size=4, capacity=52, row=10, slot=13 | P[-1],
#  S[316]: size=5, capacity=65, row=10, slot=18 | P[-1],
#  S[317]: size=5, capacity=65, row=10, slot=24 | P[-1],
#  S[318]: size=4, capacity=52, row=10, slot=29 | P[-1],
#  S[319]: size=3, capacity=39, row=10, slot=33 | P[-1],
#  S[320]: size=4, capacity=52, row=10, slot=40 | P[-1],
#  S[321]: size=3, capacity=36, row=10, slot=44 | P[-1],
#  S[322]: size=1, capacity=12, row=9, slot=99 | P[-1],
#  S[323]: size=4, capacity=48, row=10, slot=49 | P[-1],
#  S[324]: size=3, capacity=36, row=10, slot=53 | P[-1],
#  S[325]: size=5, capacity=60, row=10, slot=56 | P[-1],
#  S[326]: size=1, capacity=12, row=10, slot=37 | P[-1],
#  S[327]: size=4, capacity=48, row=10, slot=61 | P[-1],
#  S[328]: size=2, capacity=24, row=10, slot=65 | P[-1],
#  S[329]: size=5, capacity=60, row=10, slot=67 | P[-1],
#  S[330]: size=3, capacity=36, row=10, slot=72 | P[-1],
#  S[331]: size=2, capacity=24, row=10, slot=75 | P[-1],
#  S[332]: size=4, capacity=48, row=10, slot=77 | P[-1],
#  S[333]: size=5, capacity=60, row=10, slot=83 | P[-1],
#  S[334]: size=4, capacity=48, row=10, slot=88 | P[-1],
#  S[335]: size=1, capacity=12, row=10, slot=38 | P[-1],
#  S[336]: size=2, capacity=24, row=10, slot=92 | P[-1],
#  S[337]: size=4, capacity=48, row=10, slot=96 | P[-1],
#  S[338]: size=4, capacity=48, row=11, slot=0 | P[-1],
#  S[339]: size=2, capacity=24, row=11, slot=4 | P[-1],
#  S[340]: size=3, capacity=36, row=11, slot=6 | P[-1],
#  S[341]: size=3, capacity=36, row=11, slot=9 | P[-1],
#  S[342]: size=3, capacity=36, row=11, slot=12 | P[-1],
#  S[343]: size=4, capacity=48, row=11, slot=18 | P[-1],
#  S[344]: size=4, capacity=48, row=11, slot=22 | P[-1],
#  S[345]: size=3, capacity=36, row=11, slot=28 | P[-1],
#  S[346]: size=5, capacity=60, row=11, slot=31 | P[-1],
#  S[347]: size=5, capacity=60, row=11, slot=36 | P[-1],
#  S[348]: size=5, capacity=60, row=11, slot=41 | P[-1],
#  S[349]: size=3, capacity=36, row=11, slot=46 | P[-1],
#  S[350]: size=1, capacity=12, row=10, slot=47 | P[-1],
#  S[351]: size=2, capacity=24, row=11, slot=15 | P[-1],
#  S[352]: size=4, capacity=48, row=11, slot=49 | P[-1],
#  S[353]: size=2, capacity=24, row=11, slot=53 | P[-1],
#  S[354]: size=3, capacity=36, row=11, slot=55 | P[-1],
#  S[355]: size=1, capacity=12, row=10, slot=81 | P[-1],
#  S[356]: size=1, capacity=12, row=10, slot=94 | P[-1],
#  S[357]: size=2, capacity=24, row=11, slot=58 | P[-1],
#  S[358]: size=3, capacity=36, row=11, slot=60 | P[-1],
#  S[359]: size=4, capacity=48, row=11, slot=68 | P[-1],
#  S[360]: size=3, capacity=36, row=11, slot=63 | P[-1],
#  S[361]: size=5, capacity=55, row=11, slot=72 | P[-1],
#  S[362]: size=5, capacity=55, row=11, slot=79 | P[-1],
#  S[363]: size=3, capacity=33, row=11, slot=84 | P[-1],
#  S[364]: size=1, capacity=11, row=11, slot=26 | P[-1],
#  S[365]: size=3, capacity=33, row=11, slot=87 | P[-1],
#  S[366]: size=2, capacity=22, row=11, slot=90 | P[-1],
#  S[367]: size=1, capacity=11, row=11, slot=77 | P[-1],
#  S[368]: size=4, capacity=44, row=11, slot=92 | P[-1],
#  S[369]: size=1, capacity=11, row=11, slot=96 | P[-1],
#  S[370]: size=3, capacity=33, row=11, slot=97 | P[-1],
#  S[371]: size=5, capacity=55, row=12, slot=0 | P[-1],
#  S[372]: size=3, capacity=33, row=12, slot=5 | P[-1],
#  S[373]: size=3, capacity=33, row=12, slot=8 | P[-1],
#  S[374]: size=2, capacity=22, row=12, slot=11 | P[-1],
#  S[375]: size=1, capacity=11, row=12, slot=13 | P[-1],
#  S[376]: size=1, capacity=11, row=12, slot=14 | P[-1],
#  S[377]: size=3, capacity=33, row=12, slot=15 | P[-1],
#  S[378]: size=2, capacity=22, row=12, slot=18 | P[-1],
#  S[379]: size=4, capacity=44, row=12, slot=20 | P[-1],
#  S[380]: size=5, capacity=55, row=12, slot=24 | P[-1],
#  S[381]: size=2, capacity=22, row=12, slot=29 | P[-1],
#  S[382]: size=4, capacity=44, row=12, slot=31 | P[-1],
#  S[383]: size=1, capacity=11, row=12, slot=35 | P[-1],
#  S[384]: size=2, capacity=22, row=12, slot=36 | P[-1],
#  S[385]: size=3, capacity=33, row=12, slot=38 | P[-1],
#  S[386]: size=4, capacity=44, row=12, slot=42 | P[-1],
#  S[387]: size=5, capacity=55, row=12, slot=46 | P[-1],
#  S[388]: size=5, capacity=55, row=12, slot=51 | P[-1],
#  S[389]: size=4, capacity=44, row=12, slot=56 | P[-1],
#  S[390]: size=5, capacity=55, row=12, slot=60 | P[-1],
#  S[391]: size=1, capacity=11, row=12, slot=65 | P[-1],
#  S[392]: size=3, capacity=33, row=12, slot=66 | P[-1],
#  S[393]: size=1, capacity=11, row=12, slot=69 | P[-1],
#  S[394]: size=3, capacity=33, row=12, slot=70 | P[-1],
#  S[395]: size=2, capacity=22, row=12, slot=73 | P[-1],
#  S[396]: size=1, capacity=11, row=12, slot=75 | P[-1],
#  S[397]: size=1, capacity=11, row=12, slot=76 | P[-1],
#  S[398]: size=3, capacity=33, row=12, slot=77 | P[-1],
#  S[399]: size=4, capacity=44, row=12, slot=80 | P[-1],
#  S[400]: size=2, capacity=22, row=12, slot=84 | P[-1],
#  S[401]: size=1, capacity=11, row=12, slot=86 | P[-1],
#  S[402]: size=2, capacity=20, row=12, slot=87 | P[-1],
#  S[403]: size=2, capacity=20, row=12, slot=92 | P[-1],
#  S[404]: size=5, capacity=50, row=13, slot=0 | P[-1],
#  S[405]: size=4, capacity=40, row=12, slot=96 | P[-1],
#  S[406]: size=1, capacity=10, row=12, slot=90 | P[-1],
#  S[407]: size=4, capacity=40, row=13, slot=5 | P[-1],
#  S[408]: size=2, capacity=20, row=13, slot=9 | P[-1],
#  S[409]: size=1, capacity=10, row=12, slot=94 | P[-1],
#  S[410]: size=1, capacity=10, row=13, slot=11 | P[-1],
#  S[411]: size=4, capacity=40, row=13, slot=12 | P[-1],
#  S[412]: size=3, capacity=30, row=13, slot=16 | P[-1],
#  S[413]: size=1, capacity=10, row=13, slot=19 | P[-1],
#  S[414]: size=5, capacity=50, row=13, slot=20 | P[-1],
#  S[415]: size=2, capacity=20, row=13, slot=25 | P[-1],
#  S[416]: size=5, capacity=50, row=13, slot=28 | P[-1],
#  S[417]: size=3, capacity=30, row=13, slot=33 | P[-1],
#  S[418]: size=4, capacity=40, row=13, slot=36 | P[-1],
#  S[419]: size=5, capacity=50, row=13, slot=40 | P[-1],
#  S[420]: size=1, capacity=10, row=13, slot=45 | P[-1],
#  S[421]: size=5, capacity=50, row=13, slot=49 | P[-1],
#  S[422]: size=3, capacity=30, row=13, slot=56 | P[-1],
#  S[423]: size=2, capacity=20, row=13, slot=46 | P[-1],
#  S[424]: size=4, capacity=40, row=13, slot=59 | P[-1],
#  S[425]: size=3, capacity=30, row=13, slot=63 | P[-1],
#  S[426]: size=1, capacity=10, row=13, slot=54 | P[-1],
#  S[427]: size=5, capacity=50, row=13, slot=66 | P[-1],
#  S[428]: size=2, capacity=20, row=13, slot=71 | P[-1],
#  S[429]: size=2, capacity=20, row=13, slot=73 | P[-1],
#  S[430]: size=1, capacity=10, row=13, slot=75 | P[-1],
#  S[431]: size=2, capacity=20, row=13, slot=76 | P[-1],
#  S[432]: size=4, capacity=40, row=13, slot=79 | P[-1],
#  S[433]: size=5, capacity=50, row=13, slot=83 | P[-1],
#  S[434]: size=3, capacity=30, row=13, slot=88 | P[-1],
#  S[435]: size=5, capacity=50, row=13, slot=91 | P[-1],
#  S[436]: size=3, capacity=30, row=13, slot=96 | P[-1],
#  S[437]: size=3, capacity=27, row=14, slot=3 | P[-1],
#  S[438]: size=5, capacity=45, row=14, slot=6 | P[-1],
#  S[439]: size=5, capacity=45, row=14, slot=11 | P[-1],
#  S[440]: size=3, capacity=27, row=14, slot=16 | P[-1],
#  S[441]: size=5, capacity=45, row=14, slot=19 | P[-1],
#  S[442]: size=2, capacity=18, row=14, slot=0 | P[-1],
#  S[443]: size=3, capacity=27, row=14, slot=24 | P[-1],
#  S[444]: size=1, capacity=9, row=13, slot=99 | P[-1],
#  S[445]: size=3, capacity=27, row=14, slot=28 | P[-1],
#  S[446]: size=2, capacity=18, row=14, slot=31 | P[-1],
#  S[447]: size=4, capacity=36, row=14, slot=33 | P[-1],
#  S[448]: size=2, capacity=18, row=14, slot=37 | P[-1],
#  S[449]: size=5, capacity=45, row=14, slot=39 | P[-1],
#  S[450]: size=1, capacity=9, row=14, slot=44 | P[-1],
#  S[451]: size=5, capacity=45, row=14, slot=45 | P[-1],
#  S[452]: size=4, capacity=36, row=14, slot=50 | P[-1],
#  S[453]: size=2, capacity=18, row=14, slot=54 | P[-1],
#  S[454]: size=3, capacity=27, row=14, slot=56 | P[-1],
#  S[455]: size=3, capacity=27, row=14, slot=59 | P[-1],
#  S[456]: size=4, capacity=36, row=14, slot=64 | P[-1],
#  S[457]: size=3, capacity=27, row=14, slot=68 | P[-1],
#  S[458]: size=5, capacity=45, row=14, slot=71 | P[-1],
#  S[459]: size=5, capacity=45, row=14, slot=76 | P[-1],
#  S[460]: size=4, capacity=36, row=14, slot=81 | P[-1],
#  S[461]: size=3, capacity=27, row=14, slot=85 | P[-1],
#  S[462]: size=3, capacity=27, row=14, slot=88 | P[-1],
#  S[463]: size=4, capacity=36, row=14, slot=91 | P[-1],
#  S[464]: size=5, capacity=45, row=15, slot=0 | P[-1],
#  S[465]: size=1, capacity=9, row=14, slot=62 | P[-1],
#  S[466]: size=5, capacity=45, row=15, slot=9 | P[-1],
#  S[467]: size=5, capacity=45, row=15, slot=14 | P[-1],
#  S[468]: size=1, capacity=9, row=14, slot=95 | P[-1],
#  S[469]: size=5, capacity=45, row=15, slot=19 | P[-1],
#  S[470]: size=1, capacity=9, row=14, slot=96 | P[-1],
#  S[471]: size=3, capacity=27, row=15, slot=5 | P[-1],
#  S[472]: size=3, capacity=27, row=15, slot=24 | P[-1],
#  S[473]: size=2, capacity=18, row=15, slot=27 | P[-1],
#  S[474]: size=4, capacity=32, row=15, slot=32 | P[-1],
#  S[475]: size=3, capacity=24, row=15, slot=36 | P[-1],
#  S[476]: size=4, capacity=32, row=15, slot=39 | P[-1],
#  S[477]: size=1, capacity=8, row=14, slot=97 | P[-1],
#  S[478]: size=4, capacity=32, row=15, slot=43 | P[-1],
#  S[479]: size=2, capacity=16, row=15, slot=29 | P[-1],
#  S[480]: size=2, capacity=16, row=15, slot=47 | P[-1],
#  S[481]: size=4, capacity=32, row=15, slot=49 | P[-1],
#  S[482]: size=5, capacity=40, row=15, slot=57 | P[-1],
#  S[483]: size=4, capacity=32, row=15, slot=62 | P[-1],
#  S[484]: size=2, capacity=16, row=15, slot=53 | P[-1],
#  S[485]: size=5, capacity=40, row=15, slot=66 | P[-1],
#  S[486]: size=2, capacity=16, row=15, slot=71 | P[-1],
#  S[487]: size=1, capacity=8, row=14, slot=99 | P[-1],
#  S[488]: size=4, capacity=32, row=15, slot=73 | P[-1],
#  S[489]: size=1, capacity=8, row=15, slot=55 | P[-1],
#  S[490]: size=2, capacity=16, row=15, slot=77 | P[-1],
#  S[491]: size=1, capacity=8, row=15, slot=79 | P[-1],
#  S[492]: size=4, capacity=32, row=15, slot=84 | P[-1],
#  S[493]: size=2, capacity=16, row=15, slot=80 | P[-1],
#  S[494]: size=1, capacity=8, row=15, slot=82 | P[-1],
#  S[495]: size=1, capacity=8, row=15, slot=88 | P[-1],
#  S[496]: size=1, capacity=8, row=15, slot=89 | P[-1],
#  S[497]: size=5, capacity=40, row=15, slot=90 | P[-1],
#  S[498]: size=2, capacity=16, row=15, slot=95 | P[-1],
#  S[499]: size=3, capacity=24, row=15, slot=97 | P[-1]]

# %%
def save_result(servers, pools)
